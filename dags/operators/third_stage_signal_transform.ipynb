# %%
import os
import io
import numpy as np
import matplotlib.pyplot as plt
import duckdb
import pyarrow as pa
import pyarrow.parquet as pq
import pyarrowfs_adlgen2 as pa_adl
import logging

from deltalake import DeltaTable, write_deltalake
from dotenv import load_dotenv
from pathlib import Path
from typing import Callable

from azure.identity import DefaultAzureCredential, ClientSecretCredential
from azure.storage.filedatalake import DataLakeServiceClient
from azure.keyvault.secrets import SecretClient
from azure.core.exceptions import ResourceNotFoundError

# %load_ext autoreload
# %autoreload 2

# %%
def setup_logging():
    logger = logging.getLogger('SGX_Downloader')
    logger.setLevel(logging.DEBUG) # Catch everything at the logger level

    # 2. Console/Stream Handler (for user feedback)
    console_handler = logging.StreamHandler()
    console_handler.setLevel(logging.INFO) # Only show INFO, ERROR, CRITICAL
    console_formatter = logging.Formatter('%(levelname)s: %(message)s')
    console_handler.setFormatter(console_formatter)
    logger.addHandler(console_handler)

    return logger

# %%
logger = setup_logging()
logger.info("Script started.") # Will appear on console and file
logger.debug("Attempting to extract forum data.") # Will only appear in the file'
# Out:
# INFO: Script started.

# %%
# local
DATA_DIR = "../../include/data"

# %%
# local
SILVER_FOLDER_NAME = "silver"
SUB_FOLDER_NAME = "stage-02"
SILVER_DATA_DIR = os.path.join("{DATA_DIR}", "{FOLDER_NAME}", "{SUB_FOLDER_NAME}").replace("\\", "/")
SILVER_DATA_DIR
# Out:
# '{DATA_DIR}/{FOLDER_NAME}/{SUB_FOLDER_NAME}'

# %%
subjects_features_paths = [
    str(signal_features_path).replace("\\", "/")
    for signal_features_path in Path(
        SILVER_DATA_DIR.format(
            DATA_DIR=DATA_DIR, 
            FOLDER_NAME=SILVER_FOLDER_NAME, 
            SUB_FOLDER_NAME=SUB_FOLDER_NAME
        )
    ).rglob("*")
    if signal_features_path.is_file()
]

# %%
subjects_features_paths
# Out:
# ['../../include/data/silver/stage-02/1028-20100710-hne/ar-01.parquet',
#  '../../include/data/silver/stage-02/1028-20100710-hne/ar-02.parquet',
#  '../../include/data/silver/stage-02/1028-20100710-hne/ar-03.parquet',
#  '../../include/data/silver/stage-02/1028-20100710-hne/ar-04.parquet',
#  '../../include/data/silver/stage-02/1028-20100710-hne/ar-05.parquet',
#  '../../include/data/silver/stage-02/1028-20100710-hne/ar-06.parquet',
#  '../../include/data/silver/stage-02/1028-20100710-hne/ar-07.parquet',
#  '../../include/data/silver/stage-02/1028-20100710-hne/rp-29.parquet',
#  '../../include/data/silver/stage-02/1028-20100710-hne/rp-30.parquet',
#  '../../include/data/silver/stage-02/1028-20100710-hne/rp-31.parquet',
#  '../../include/data/silver/stage-02/1337ad-20170321-ajg/en-0532.parquet',
#  '../../include/data/silver/stage-02/1337ad-20170321-ajg/en-0533.parquet',
#  '../../include/data/silver/stage-02/1337ad-20170321-ajg/en-0534.parquet',
# ...

# %%
# Retrieve credentials from environment variables
# this is strictly used only in development
# load env variables
env_dir = Path('../../').resolve()
load_dotenv(os.path.join(env_dir, '.env'))
# Out:
# True

# %%
storage_account_name = os.environ.get("STORAGE_ACCOUNT_NAME")
storage_account_key = os.environ.get("STORAGE_ACCOUNT_KEY")
storage_account_conn_str = os.environ.get("STORAGE_ACCOUNT_CONN_STR")

# %%
# cloud
URL = "abfss://{FOLDER_NAME}@sgppipelinesa.dfs.core.windows.net"
SILVER_FOLDER_NAME = "sgppipelinesa-silver"
SUB_FOLDER_NAME = "stage-02"
SILVER_DATA_DIR = os.path.join(URL, "{SUB_FOLDER_NAME}").replace("\\", "/")
SILVER_DATA_DIR
# Out:
# 'abfss://{FOLDER_NAME}@sgppipelinesa.dfs.core.windows.net/{SUB_FOLDER_NAME}'

# %%
# cloud
# create client with generated sas token
datalake_service_client = DataLakeServiceClient(
    account_url=f"https://{storage_account_name}.dfs.core.windows.net", 
    credential=storage_account_key
)

# retrieves file system client/container client 
# to retrieve datalake client
silver_container_client = datalake_service_client.get_file_system_client(f"{storage_account_name}-silver")

# we only get the directories in the first level of 
# the container, if it has a "/" then it means it is not
# an immediate folder in the container. This only really
# gets the subject folders 
subjects_features_paths = [
    os.path.join(
        URL.format(
            FOLDER_NAME=SILVER_FOLDER_NAME
        ), 
        path.name
    ).replace("\\", "/")
    for path in silver_container_client.get_paths(path=SUB_FOLDER_NAME)
]
subjects_features_paths
# Out:
# ['abfss://sgppipelinesa-silver@sgppipelinesa.dfs.core.windows.net/stage-02/1028-20100710-hne_features.parquet',
#  'abfss://sgppipelinesa-silver@sgppipelinesa.dfs.core.windows.net/stage-02/1337ad-20170321-ajg_features.parquet',
#  'abfss://sgppipelinesa-silver@sgppipelinesa.dfs.core.windows.net/stage-02/1337ad-20170321-tkg_features.parquet',
#  'abfss://sgppipelinesa-silver@sgppipelinesa.dfs.core.windows.net/stage-02/1snoke-20120412-hge_features.parquet',
#  'abfss://sgppipelinesa-silver@sgppipelinesa.dfs.core.windows.net/stage-02/23yipikaye-20100807-ujm_features.parquet',
#  'abfss://sgppipelinesa-silver@sgppipelinesa.dfs.core.windows.net/stage-02/Aaron-20080318-kdl_features.parquet',
#  'abfss://sgppipelinesa-silver@sgppipelinesa.dfs.core.windows.net/stage-02/Anniepoo-20140308-bft_features.parquet',
#  'abfss://sgppipelinesa-silver@sgppipelinesa.dfs.core.windows.net/stage-02/Anniepoo-20140308-cqj_features.parquet',
# ...

# %% [markdown]
# load all the single parquet files into one giant table (we won't need pyarrow for this one anymore as we won't need to convert between tables, numpy arrays, and pyarrow dataframes). This will now be easier to load as these only contain the relevant row of features from each subjects signals after windowing. We will also be loading the labels of different data splits so we can use it as basis to what subjects in this giant dataframe will be part of the train, val, and test set

# %%
conn = duckdb.connect()

# %%
# for cloud only
# installing dependencies and creating secrets object
conn.sql(f"""INSTALL azure""")
conn.sql(f"""LOAD azure""")
conn.sql(f"""
    CREATE OR REPLACE SECRET az_sgp (
        TYPE azure,
        CONNECTION_STRING '{storage_account_conn_str}'
    );
""")
# the is required if this notebook is run in linux environment
# like airflow container
conn.sql("SET azure_transport_option_type = 'curl'")

# %%
conn.sql(f"""
    CREATE OR REPLACE TEMPORARY TABLE features_imp AS (
        SELECT * EXCLUDE(file_name) FROM read_parquet({subjects_features_paths}, union_by_name=True, filename=True)
    );
""")

# %%
conn.sql("""
    SELECT COUNT(1) FROM features_imp
""")
# Out:
# ┌──────────┐
# │ count(1) │
# │  int64   │
# ├──────────┤
# │      496 │
# └──────────┘

# %%
conn.sql("""
    (SELECT * FROM features_imp ORDER BY loaded_at DESC LIMIT 5)
    UNION ALL BY NAME
    (SELECT * FROM features_imp ORDER BY loaded_at ASC LIMIT 5)
""")
# Out:
# ┌────────────────────┬────────────────┬─────────────────────┬────────────────────────────┬─────────────────────┬──────────────────────┬────────────────────┬────────────────────────┬────────────────────┬────────────────────┬────────────────────┬───────────────────┬────────────────────────┬────────────────────────┬──────────────────────┬─────────────────────┬───────────────────┬────────────────────────┬──────────────────────┬─────────────────────────┬────────────────────┬────────────────────┬────────────────────┬──────────────────────┬────────────────────┬────────────────────┬────────────────────┬───────────────────────┬───────────────────┬───────────────────────┬────────────────────┬────────────────────┬────────────────────┬───────────────────┬──────────────────────┬──────────────────────┬────────────────────────────┬────────────────────┬────────────────────┬────────────────────┬─────────────────────┬─────────────────────┬─────────────────────┬──────────────────────┬──────────────────
# ...

# %% [markdown]
# <!-- # originally we had 6318 subjects but if observed keenly we can see that we only have 4350 + 967 + 946 or just 6263 subjects now, as we are missing 55 because in ingest_labels we had to discard some subjects who did not have labels attached to them   -->

# %%
conn.sql(f"""
    SELECT * FROM features_imp WHERE subject_id = 'Coren-3000'         
""")
# Out:
# ┌────────────┬────────────────┬─────────────────────┬──────────────────────────────────────────────────────────────────┬────────────────────────────┬────────────────────┬─────────────────────┬────────────────────┬────────────────────────┬────────────────────┬────────────────────┬────────────────────┬──────────────────┬────────────────────────┬───────────────────────┬──────────────────────┬─────────────────────┬───────────────────┬────────────────────────┬──────────────────────┬─────────────────────────┬────────────────────┬────────────────────┬────────────────────┬───────────────────────┬────────────────────┬────────────────────┬────────────────────┬───────────────────────┬───────────────────┬───────────────────────┬────────────────────┬────────────────────┬──────────────────┬────────────────────┬──────────────────────┬──────────────────────┬────────────────────────────┬────────────────────┬────────────────────┬────────────────────┬─────────────────────┬─────────────────────┬────────
# ...

# %%
SILVER_DATA_DIR
# Out:
# '{DATA_DIR}/{FOLDER_NAME}'

# %%
# # cloud
# labels_path = os.path.join(
#     SILVER_DATA_DIR.format(
#         FOLDER_NAME=SILVER_FOLDER_NAME,
#         SUB_FOLDER_NAME="stage-01"
#     ),
#     "labels"
# ).replace("\\", "/")

# local
labels_path = os.path.join(
    SILVER_DATA_DIR.format(
        DATA_DIR=DATA_DIR,
        FOLDER_NAME=SILVER_FOLDER_NAME,
        SUB_FOLDER_NAME="stage-01"
    ),
    "labels"
).replace("\\", "/")

labels_path
# Out:
# '../../include/data/silver/stage-01/labels'

# %%
conn.sql(f"""
    CREATE OR REPLACE TEMPORARY VIEW labels AS (
        SELECT * FROM delta_scan('{labels_path}')
        UNION
        SELECT 
            'Coren-3000' AS subject_id,
            'female' AS value,
            'val' AS split,
            12 AS split,
            2 AS partition
    );
""")

# %%
conn.sql("SELECT * FROM labels")
# Out:
# ┌─────────────────────────┬─────────┬─────────┬────────┬───────────┐
# │       subject_id        │  value  │  split  │ row_id │ partition │
# │         varchar         │ varchar │ varchar │ int64  │   int64   │
# ├─────────────────────────┼─────────┼─────────┼────────┼───────────┤
# │ Coren-20141121-pxp      │ male    │ test    │     11 │         1 │
# │ Coren-3000              │ female  │ val     │     12 │         2 │
# │ 1337ad-20170321-tkg     │ female  │ train   │      2 │         2 │
# │ 1028-20100710-hne       │ male    │ train   │      0 │         0 │
# │ 1337ad-20170321-ajg     │ female  │ train   │      1 │         1 │
# │ Anniepoo-20140308-hns   │ female  │ test    │      9 │         9 │
# │ Anniepoo-20140308-cqj   │ female  │ train   │      7 │         7 │
# │ Anniepoo-20140308-fcp   │ female  │ val     │      8 │         8 │
# │ Anniepoo-20140308-nky   │ female  │ test    │     10 │         0 │
# │ 23yipikaye-20100807-ujm │ male    │ train   │      4 │         4 │
# ...

# %% [markdown]
# # we use inner join to join our labels delta table to the features imputed view to inherently "split" our data by assigning the data points split based on the subject id
#
# it doesn't matter if a subject is added in our feature data because of our watermark/incremental scheme, what matters is the labels delta table is updated regularly through CDC scheme to know which subjects have been added or deleted and updates itself based on these changes and when inner joined to the feature data it automatically does the filtering out of the subjects in the features not in the labels delta table because of its CDC scheme.

# %%
feature_infos = conn.sql("""
    SELECT 
        column_name, 
        data_type 
    FROM information_schema.columns 
    WHERE table_name = 'features_imp'
    AND column_name NOT IN (
        'subject_id', 
        'signals', 
        'wav_file_row_number', 
        'filename', 
        'loaded_at'
    )
""").fetchall()
feature_cols, _ = list(zip(*feature_infos))
feature_cols
# Out:
# ('freq_kurt',
#  'freq_skew',
#  'freq_entropy',
#  'freq_mean',
#  'freq_median',
#  'freq_mode',
#  'freq_min',
#  'freq_max',
#  'freq_var',
#  'freq_stddev',
#  'freq_first_quart',
#  'freq_third_quart',
#  'freq_range',
#  'freq_inter_quart_range',
#  'zcr',
#  'poly_feat_1',
#  'poly_feat_2',
#  'spec_cent',
#  'spec_bw',
#  'spec_flat',
#  'spec_roll',
#  'mel_spec_mean',
#  'mel_spec_median',
#  'mel_spec_mode',
#  'mel_spec_mode_cnt',
#  'mel_spec_min',
#  'mel_spec_max',
#  'mel_spec_range',
#  'mel_spec_var',
#  'mel_spec_std',
#  'mel_spec_first_quart',
#  'mel_spec_third_quart',
#  'mel_spec_inter_quart_range',
#  'mel_spec_entropy',
#  'mel_spec_kurt',
#  'mel_spec_skew',
#  'mel_spec_db_mean',
#  'mel_spec_db_median',
#  'mel_spec_db_mode',
#  'mel_spec_db_mode_cnt',
#  'mel_spec_db_min',
#  'mel_spec_db_max',
#  'mel_spec_db_range',
#  'mel_spec_db_var',
#  'mel_spec_db_std',
#  'mel_spec_db_first_quart',
#  'mel_spec_db_third_quart',
# ...

# %%
hash_expr = f"MD5(CONCAT_WS('||', {', '.join(feature_cols)})) AS feature_hash_key"
hash_expr
# Out:
# "MD5(CONCAT_WS('||', freq_kurt, freq_skew, freq_entropy, freq_mean, freq_median, freq_mode, freq_min, freq_max, freq_var, freq_stddev, freq_first_quart, freq_third_quart, freq_range, freq_inter_quart_range, zcr, poly_feat_1, poly_feat_2, spec_cent, spec_bw, spec_flat, spec_roll, mel_spec_mean, mel_spec_median, mel_spec_mode, mel_spec_mode_cnt, mel_spec_min, mel_spec_max, mel_spec_range, mel_spec_var, mel_spec_std, mel_spec_first_quart, mel_spec_third_quart, mel_spec_inter_quart_range, mel_spec_entropy, mel_spec_kurt, mel_spec_skew, mel_spec_db_mean, mel_spec_db_median, mel_spec_db_mode, mel_spec_db_mode_cnt, mel_spec_db_min, mel_spec_db_max, mel_spec_db_range, mel_spec_db_var, mel_spec_db_std, mel_spec_db_first_quart, mel_spec_db_third_quart, mel_spec_db_inter_quart_range, mel_spec_db_entropy, mel_spec_db_kurt, mel_spec_db_skew, mfcc_mean, mfcc_median, mfcc_mode, mfcc_mode_cnt, mfcc_min, mfcc_max, mfcc_range, mfcc_var, mfcc_std, mfcc_first_quart, mfcc_third_quart, mfcc_inter_quart_ra
# ...

# %%
conn.sql(f"""
    CREATE OR REPLACE TEMPORARY TABLE data AS (
        WITH feature_label AS (
            SELECT 
                f.* EXCLUDE(f.signals, f.filename),
                f.filename AS file_name,
                l.value AS label,
                l.split AS split,
                l.partition AS partition,
            FROM labels l
            INNER JOIN features_imp f
            ON f.subject_id = l.subject_id
        )
        
        SELECT 
            *,
            {hash_expr}
        FROM feature_label
    );
""")

# %%
conn.sql("SELECT * FROM data")
# Out:
# ┌───────────────────┬─────────────────────┬────────────────────────────┬────────────────────┬─────────────────────┬────────────────────┬────────────────────────┬─────────────────────┬────────────────────┬────────────────────┬────────────────────┬────────────────────────┬───────────────────────┬──────────────────────┬──────────────────────┬───────────────────┬────────────────────────┬──────────────────────┬─────────────────────────┬────────────────────┬────────────────────┬────────────────────┬──────────────────────┬────────────────────┬────────────────────┬────────────────────┬──────────────────────┬───────────────────┬──────────────────────┬────────────────────┬────────────────────┬──────────────────┬────────────────────┬──────────────────────┬──────────────────────┬────────────────────────────┬────────────────────┬────────────────────┬────────────────────┬─────────────────────┬─────────────────────┬─────────────────────┬──────────────────────┬─────────────────────┬─────────────────
# ...

# %%
# let's test an update of a primary key which essentiall deletes it 
# and see if the delta table inserts this "new" record and deletes
# non existent version of this record that used the old primary key
conn.sql("""
    UPDATE data
    SET subject_id = 'Coren-2026'
    WHERE subject_id = 'Coren-20141121-pxp'
""")

# %%
conn.sql("""
    SELECT * FROM data         
""")
# Out:
# ┌───────────────────┬─────────────────────┬────────────────────────────┬────────────────────┬─────────────────────┬────────────────────┬────────────────────────┬─────────────────────┬────────────────────┬────────────────────┬────────────────────┬────────────────────────┬───────────────────────┬──────────────────────┬──────────────────────┬───────────────────┬────────────────────────┬──────────────────────┬─────────────────────────┬────────────────────┬────────────────────┬────────────────────┬──────────────────────┬────────────────────┬────────────────────┬────────────────────┬──────────────────────┬───────────────────┬──────────────────────┬────────────────────┬────────────────────┬──────────────────┬────────────────────┬──────────────────────┬──────────────────────┬────────────────────────────┬────────────────────┬────────────────────┬────────────────────┬─────────────────────┬─────────────────────┬─────────────────────┬──────────────────────┬─────────────────────┬─────────────────
# ...

# %%
subjects_data_table = conn.sql("""
    SELECT * FROM data
    -- to simulate record deletion
    -- WHERE subject_id != '1337ad-20170321-ajg'
""").to_arrow_table()

# %%
subjects_data_table
# Out:
# pyarrow.Table
# subject_id: string
# wav_file_row_number: int64
# loaded_at: timestamp[us]
# freq_kurt: double
# freq_skew: double
# freq_entropy: double
# freq_mean: double
# freq_median: double
# freq_mode: double
# freq_min: double
# freq_max: double
# freq_var: double
# freq_stddev: double
# freq_first_quart: double
# freq_third_quart: double
# freq_range: double
# freq_inter_quart_range: double
# zcr: double
# poly_feat_1: double
# poly_feat_2: double
# spec_cent: double
# spec_bw: double
# spec_flat: double
# spec_roll: double
# mel_spec_mean: double
# mel_spec_median: double
# mel_spec_mode: double
# mel_spec_mode_cnt: double
# mel_spec_min: double
# mel_spec_max: double
# mel_spec_range: double
# mel_spec_var: double
# mel_spec_std: double
# mel_spec_first_quart: double
# mel_spec_third_quart: double
# mel_spec_inter_quart_range: double
# mel_spec_entropy: double
# mel_spec_kurt: double
# mel_spec_skew: double
# mel_spec_db_mean: double
# mel_spec_db_median: double
# ...

# %%
def change_data_capture_data(delta_table: DeltaTable, df: pa.Table):
    """
    follows a change data capture scheme for the all three splits of
    data which includes train, validation, and test splits, and in
    which already contains the label. It basically does the ff:
    
    1. deletes all records in the existing delta table if there are 
    any records in source dataframe that are not present anymore
    
    2. inserts all records in the existing delta table if there 
    are any new records in the source dataframe that are not 
    present in the existing delta table.
    
    3. And updates all records in the existing delta table if there 
    are any records in the source dataframe that have changed their
    column values when compared to the existing delta table. E.g.
    when a subject's gender is changed in readme file, then the 
    existing record in delta table will be updated
    
    unlike the labels delta table these train, val, and test delta
    tables will have make use of not only the subject id as primary
    key but also the file_name, row_id, and split as composite keys
    
    """
    
    # subject_id,
    # file_name,
    
    # does this even change? Maybe if hertz/sampling rate is changed
    # and loaded at does this even change? Maybe if new data arrives
    # wav_file_row_number,
    # loaded_at,
    
    # label,
    # split,
    # partition
    
    feature_cols = list(filter(
        lambda col: col not in (
            'subject_id',
            'wav_file_row_number',
            'file_name',
            'loaded_at',
            'label',
            'split',
            'partition'
        ),
        df.column_names
    ))
    
    update_clause = {
        # these are not included as these are the composite keys
        # that are not by good practice supposed to be updated
        # "subject_id": "source.subject_id",
        # "file_name": "source.file_name",
        # "wav_file_row_number": "source.wav_file_row_number",
        
        "loaded_at": "source.loaded_at",
        "label": "source.label",
        "split": "source.split",
        "partition": "source.partition",
        
        # when feature_hash_key does change because of change in features
        # update the feature_hash_key also, and update all features
        "feature_hash_key": "source.feature_hash_key"
    }
    update_clause.update({col: f"source.{col}" for col in feature_cols})
    print(update_clause)
    
    # when_matched_clause = " OR ".join([
    #     f"source.{col} IS DISTINCT FROM target.{col}" 
    #     for col in feature_cols + ["wav_file_row_number", "loaded_at", "label", "split", "partition"]
    # ])
    when_matched_clause = """
        (source.loaded_at IS DISTINCT FROM target.loaded_at) OR
        (source.label IS DISTINCT FROM target.label) OR
        (source.split IS DISTINCT FROM target.split) OR
        (source.partition IS DISTINCT FROM target.partition) OR
        (source.feature_hash_key IS DISTINCT FROM target.feature_hash_key)
    """
    print(when_matched_clause)

    try:
        delta_table.merge(
            df,
            predicate="""
                target.subject_id = source.subject_id 
                AND target.file_name = source.file_name
                AND target.window_row_number = source.wav_file_row_number
            """,
            source_alias="source",
            target_alias="target",  
            merge_schema=True
        )\
        .when_matched_update(
            updates=update_clause, 
            # this tells delta to only update a record if the new record
            # does indeed have changed its column values when compared to the
            # current record
            predicate=when_matched_clause
        )\
        .when_not_matched_by_source_delete()\
        .when_not_matched_insert_all()\
        .execute()

    except Exception as e:
        # this runs if no table exists in s3 bucket
        logger.warning(f"`{e}` occured during delta upsert")
        
def write_delta_to_bucket(
    azure_creds: dict, 
    df: pa.Table, 
    container_name: str, 
    object_name: str, 
    folder_name: str, 
    is_local: bool, 
    merge_func: Callable
):
    """
    writes a pyarrow dataframe to an azure container in delta format. 
    What we want here is to check if an existing parquet with signal
    data already exists in azure, 
    
    As opposed to a scheme where if in azure there is no current parquet
    and then creating a parquet with object id indicating its the first, 
    and if there is already create a parquet with the object id with 
    the highest or max number, we use a delta lake format  
    """

    try:    
        # if alternative/local path is not provided 
        # modify the delta path if there is no alternative path
        # The URI points to the S3 bucket and folder where the Delta table lives
        DELTA_PATH = os.path.join(
            container_name, 
            folder_name, 
            object_name
        ).replace("\\", "/")
        
        # create delta table from path and load the
        #  delta table if it already exists
        delta_table = DeltaTable(DELTA_PATH, storage_options=azure_creds) if not is_local else DeltaTable(DELTA_PATH)

        # create a delta directory if it is local
        if not "abfss" in DELTA_PATH:
            DELTA_DIR, _ = DELTA_PATH.rsplit("/", 1)
            os.makedirs(DELTA_DIR, exist_ok=True)
        
        # Table exists, so APPEND the new data
        logger.info(f"Delta table found at {DELTA_PATH}") 
        logger.info(f"Inserting new and updated rows...")
        
        # update old records and insert new records 
        merge_func(delta_table, df)
        
    except Exception as e:
        # this runs if no table exists in s3 bucket
        logger.warning(f"`{e}` occured during delta update")
        logger.warning(f"No Delta table found.")
        logger.info(f"Creating new table with {df.num_rows} rows...")

        # delta table is written in s3 bucket with given
        # credentials and path
        write_deltalake(
            DELTA_PATH, 
            df, 
            # Use overwrite (or error) to create the initial table
            mode="overwrite", 
            storage_options=azure_creds,
            
            # this is to use the partition column to partition the delta table 
            # by, which is important for efficient querying and data management 
            # in delta lake when we query by delta scan in the silver/stage-03
            # folder
            partition_by=["partition"]
        )

# %%
azure_creds = {
    "azure_storage_account_name": storage_account_name,
    "azure_storage_account_key": storage_account_key,
    # "client_id": client_id,
    # "client_secret": client_secret,
    # "tenant_id": tenant_id
}

# %%
# local
SILVER_FOLDER_NAME = "silver"
SUB_FOLDER_NAME = "stage-03"
SILVER_DATA_DIR = os.path.join("{DATA_DIR}", "{FOLDER_NAME}").replace("\\", "/")
SILVER_DATA_DIR
# Out:
# '{DATA_DIR}/{FOLDER_NAME}'

# %%
# local
SAVE_DIR = SILVER_DATA_DIR.format(
    DATA_DIR=DATA_DIR,
    FOLDER_NAME=SILVER_FOLDER_NAME,
)
SAVE_DIR
# Out:
# '../../include/data/silver'

# %%
write_delta_to_bucket(
    azure_creds=azure_creds,
    df=subjects_data_table,
    container_name=SAVE_DIR,
    object_name="data",
    folder_name=SUB_FOLDER_NAME,
    is_local=True,
    merge_func=change_data_capture_data
)
# Out:
# INFO: Delta table found at ../../include/data/silver/stage-03/data
# INFO: Inserting new and updated rows...
# ...

# %%
# # cloud
# SAVE_DIR = SILVER_DATA_DIR.format(
#     FOLDER_NAME=SILVER_FOLDER_NAME,
# )
# SAVE_DIR
