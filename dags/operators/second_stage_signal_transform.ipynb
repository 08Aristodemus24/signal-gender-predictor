# %%
import os
import pyarrow as pa
import pyarrow.parquet as pq
import pyarrowfs_adlgen2 as pa_adl
import pyarrow.dataset as ds
import numpy as np
import librosa
import duckdb
import matplotlib.pyplot as plt
import re
import random
import logging

from deltalake import DeltaTable, write_deltalake
from typing import Callable
from scipy.stats import kurtosis as kurt, skew, entropy, mode
from dotenv import load_dotenv
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor

from azure.identity import DefaultAzureCredential, ClientSecretCredential
from azure.storage.filedatalake import DataLakeServiceClient
from azure.keyvault.secrets import SecretClient
from azure.core.exceptions import ResourceNotFoundError

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def setup_logging():
    logger = logging.getLogger('signal_gender_predictor')
    logger.setLevel(logging.DEBUG) # Catch everything at the logger level

    # 2. Console/Stream Handler (for user feedback)
    console_handler = logging.StreamHandler()
    console_handler.setLevel(logging.INFO) # Only show INFO, ERROR, CRITICAL
    console_formatter = logging.Formatter('%(levelname)s: %(message)s')
    console_handler.setFormatter(console_formatter)
    logger.addHandler(console_handler)

    return logger

# %%
logger = setup_logging()

# %%
# local
DATA_DIR = "../../include/data"

# %%
# # cloud
# # URL = "abfss://{FOLDER_NAME}@sgppipelinesa.dfs.core.windows.net"
# URL = "{FOLDER_NAME}"
# SILVER_FOLDER_NAME = "sgppipelinesa-silver"
# SUB_FOLDER_NAME = "stage-01"
# SILVER_DATA_DIR = os.path.join(URL, "{SUB_FOLDER_NAME}").replace("\\", "/")
# SILVER_DATA_DIR

# local
SILVER_FOLDER_NAME = "silver"
SUB_FOLDER_NAME = "stage-01"
SILVER_DATA_DIR = os.path.join("{DATA_DIR}", "{FOLDER_NAME}", "{SUB_FOLDER_NAME}").replace("\\", "/")
SILVER_DATA_DIR
# Out:
# '{DATA_DIR}/{FOLDER_NAME}/{SUB_FOLDER_NAME}'

# %% [markdown]
# # Computing features for a single subjects audio signals
# this is to familiarize what exact features we need to compute for all other subjects audio signals

# %%
# read delta table of a subject
DELTA_SUBJECT_TABLE_PATH = os.path.join(SILVER_DATA_DIR.format(DATA_DIR=DATA_DIR, FOLDER_NAME=SILVER_FOLDER_NAME, SUB_FOLDER_NAME=SUB_FOLDER_NAME), "1028-20100710-hne").replace("\\", "/")
DELTA_SUBJECT_TABLE_PATH
# Out:
# '../../include/data/silver/stage-01/1028-20100710-hne'

# %%
delta_subject_table = DeltaTable(
    DELTA_SUBJECT_TABLE_PATH, 
    # storage_options=azure_creds
)

# %%
subject_table = delta_subject_table.to_pyarrow_table()
subject_table.shape
# Out:
# (521216, 4)

# %%
subject_table
# Out:
# pyarrow.Table
# signals: float
# subject_id: string
# wav_file_row_number: int64
# file_name: string
# ----
# signals: [[0.0043029785,0.004058838,0.0037231445,0.0036621094,0.0035705566,...,0.002319336,0.0009460449,0.0006713867,0.00289917,0.0045166016],[0.0014038086,-0.001739502,-0.0061035156,-0.010040283,-0.012908936,...,0.0032958984,0.0028076172,0.0036315918,0.004272461,0.0060424805],...,[-0.013122559,-0.013031006,-0.012817383,-0.012481689,-0.0121154785,...,-0.00036621094,-0.00045776367,-0.000030517578,-0.00048828125,-0.00079345703],[-0.0074768066,-0.008728027,-0.014007568,-0.01626587,-0.0128479,...,-0.005706787,-0.0064086914,-0.007019043,-0.008361816,-0.009216309]]
# ...

# %%
# connect to an in-memory database
conn = duckdb.connect()

# %%
conn.sql(f"""
    SELECT COUNT(*) FROM DELTA_SCAN('{DELTA_SUBJECT_TABLE_PATH}')
""")
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │       521216 │
# └──────────────┘

# %%
conn.sql(f"""
    SELECT
        DISTINCT
        -- signals, 
        -- subject_id, 
        -- wav_file_row_number, 
        file_name
        -- SPLIT_PART(filename, '/', 7) || '/' || SPLIT_PART(filename, '/', 8) AS file_name
    FROM DELTA_SCAN('{DELTA_SUBJECT_TABLE_PATH}', filename=True)
""")
# Out:
# ┌───────────┐
# │ file_name │
# │  varchar  │
# ├───────────┤
# │ ar-03.wav │
# │ ar-04.wav │
# │ ar-07.wav │
# │ ar-01.wav │
# │ rp-31.wav │
# │ ar-05.wav │
# │ rp-29.wav │
# │ ar-02.wav │
# │ rp-30.wav │
# │ ar-06.wav │
# ├───────────┤
# │  10 rows  │
# └───────────┘

# %%
# hertz
hertz = 16000
window_time = 3
hop_time = 1

# we calculate the window size of each segment or the
# amount of samples it has to have based on the frequency
samples_per_win_size = int(window_time * hertz)
samples_per_hop_size = int(hop_time * hertz)

# %% [markdown]
# # Computing statistical features

# %%
subject_table = conn.sql(f"""
    SELECT
        signals, 
        subject_id, 
        wav_file_row_number, 
        file_name
    FROM DELTA_SCAN('{DELTA_SUBJECT_TABLE_PATH}')
""").to_arrow_table()

# %%
conn.sql(f"""
    CREATE OR REPLACE TEMPORARY TABLE subject_features AS (
        WITH stat_feats_1 AS (
            SELECT
                subject_id, 
                signals, 
                wav_file_row_number,
                file_name,
                
                KURTOSIS(signals) OVER(PARTITION BY subject_id, file_name ORDER BY wav_file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_kurt,
                SKEWNESS(signals) OVER(PARTITION BY subject_id, file_name ORDER BY wav_file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_skew,
                ENTROPY(signals)OVER(PARTITION BY subject_id, file_name ORDER BY wav_file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_entropy,
                AVG(signals) OVER(PARTITION BY subject_id, file_name ORDER BY wav_file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_mean,
                MEDIAN(signals) OVER(PARTITION BY subject_id, file_name ORDER BY wav_file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_median,
                MODE(signals) OVER(PARTITION BY subject_id, file_name ORDER BY wav_file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_mode,
                MIN(signals) OVER(PARTITION BY subject_id, file_name ORDER BY wav_file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_min,
                MAX(signals) OVER(PARTITION BY subject_id, file_name ORDER BY wav_file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_max,
                VAR_SAMP(signals) OVER(PARTITION BY subject_id, file_name ORDER BY wav_file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_var,
                STDDEV_SAMP(signals) OVER(PARTITION BY subject_id, file_name ORDER BY wav_file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_stddev,
                QUANTILE_CONT(signals, 0.25) OVER(PARTITION BY subject_id, file_name ORDER BY wav_file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_first_quart,
                QUANTILE_CONT(signals, 0.75) OVER(PARTITION BY subject_id, file_name ORDER BY wav_file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_third_quart
            FROM subject_table
            WHERE (wav_file_row_number % {samples_per_hop_size}) = 0
            ORDER BY wav_file_row_number
        ),
        
        stat_feats_2 AS (
            SELECT 
                *,
                (freq_max - freq_min) AS freq_range,
                (freq_third_quart - freq_first_quart) AS freq_inter_quart_range
            FROM stat_feats_1
        )
        
        SELECT * FROM stat_feats_2
    )
""")

# %%
conn.sql("""
    SELECT * FROM subject_features WHERE file_name = 'ar-04.wav'
""")
# Out:
# ┌───────────────────┬───────────────┬─────────────────────┬───────────┬─────────────────────┬─────────────────────┬────────────────────┬─────────────────────┬───────────────┬───────────────┬─────────────┬───────────────┬────────────────────────┬──────────────────────┬──────────────────┬──────────────────┬─────────────┬────────────────────────┐
# │    subject_id     │    signals    │ wav_file_row_number │ file_name │      freq_kurt      │      freq_skew      │    freq_entropy    │      freq_mean      │  freq_median  │   freq_mode   │  freq_min   │   freq_max    │        freq_var        │     freq_stddev      │ freq_first_quart │ freq_third_quart │ freq_range  │ freq_inter_quart_range │
# ...

# %% [markdown]
# #### 544000 + a window of 48000 is 592000 which is greater 553472 so we consider only the indeces 544000 to 553471 which is just 9471 rows of data for this last window

# %%
# conn.sql("""
#     SELECT COUNT(*) FROM subject_table
# """)

# %% [markdown]
# # Computing spectral features

# %%
# frames = conn.sql("""
#     SELECT COUNT(rowId) FROM subject_features
# """).fetchall()[-1][-1]

# %%
# frames

# %%
# time = librosa.frames_to_time(frames, sr=hertz, hop_length=samples_per_hop_size)
# time

# %%
# subject_table["signals"].to_numpy()

# %%
# x_signals = subject_table["signals"].to_numpy()
# x_signals

# %%
# # calculate other features
# zcr = librosa.feature.zero_crossing_rate(y=x_signals, frame_length=samples_per_win_size, hop_length=samples_per_hop_size)
# zcr

# %%
# zcr.shape[1]

# %%
# new_zcr = zcr.reshape(-1)
# new_zcr.shape

# %%
# view_signal_feature(new_zcr, "zero crossing rate")

# %% [markdown]
# #### sometimes the calculation of spectral features may lead to 1 or more data points being added when compared to the length of the number of statistical features computed based on window length and hop length. To make sure number of values of statistical features and spectral features are the same we get only the first n rows of this spectral features based solely on the number of rows of the statistical features e.g. if there are 35 successfully calculated statistical features and we have 36 calculated spectral features we only get the first 35 of the spectral features and discard the rest

# %%
# zcr_n_values_to_rem = np.abs(zcr.shape[1] - time)
# zcr_n_values_to_rem.astype(int)

# %%
# # get slice of those in range with time only
# new_zcr = zcr.reshape(-1)[:frames]
# new_zcr.shape

# %%
# new_zcr.shape

# %%
# # these are 2 features all in all we don't need to aggregate it
# # into a (1, 35) array
# poly_feats = librosa.feature.poly_features(y=x_signals, sr=hertz, n_fft=samples_per_win_size, hop_length=samples_per_hop_size)
# poly_feats.shape

# %%
# new_poly_feats = poly_feats[:, :frames]
# new_poly_feats.shape

# %%
# # y is the audio signals we must pass
# # sr is the sampling rate of our audio signals
# # n_fft is the window size of the fast fourier transform
# # hop_length is number of samples between successive frames
# # n_mels is the number of Mel bands to generate
# mel_spec = librosa.feature.melspectrogram(y=x_signals, sr=hertz, n_fft=samples_per_win_size, hop_length=samples_per_hop_size, n_mels=90)
# mel_spec.shape

# %%
# mel_spec_mean, \
# mel_spec_median, \
# mel_spec_mode, \
# mel_spec_mode_cnt, \
# mel_spec_min, \
# mel_spec_max, \
# mel_spec_range, \
# mel_spec_var, \
# mel_spec_std, \
# mel_spec_first_quart, \
# mel_spec_third_quart, \
# mel_spec_inter_quart_range, \
# mel_spec_entropy, \
# mel_spec_kurt, \
# mel_spec_skew = extract_spectogam_stats(mel_spec)

# %%
# mel_spec_mode

# %%
# mel_spec_mean.shape, mel_spec_median.shape, mel_spec_mode.shape

# %%
# mel_spec_entropy.shape, mel_spec_kurt.shape, mel_spec_skew.shape

# %%
# librosa.display.specshow(mel_spec)

# %%
# mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
# mel_spec_db

# %%
# mel_spec_db_mean, \
# mel_spec_db_median, \
# mel_spec_db_mode, \
# mel_spec_db_mode_cnt, \
# mel_spec_db_min, \
# mel_spec_db_max, \
# mel_spec_db_range, \
# mel_spec_db_var, \
# mel_spec_db_std, \
# mel_spec_db_first_quart, \
# mel_spec_db_third_quart, \
# mel_spec_db_inter_quart_range, \
# mel_spec_db_entropy, \
# mel_spec_db_kurt, \
# mel_spec_db_skew = extract_spectogam_stats(mel_spec_db)

# %%
# librosa.display.specshow(mel_spec_db)

# %%
# spec_cent = librosa.feature.spectral_centroid(y=x_signals, sr=hertz, n_fft=samples_per_win_size, hop_length=samples_per_hop_size)
# spec_cent.shape

# %%
# new_spec_cent = spec_cent.reshape(-1)
# new_spec_cent.shape

# %%
# view_signal_feature(new_spec_cent, "spectral centroid")

# %%
# mfcc = librosa.feature.mfcc(y=x_signals, sr=hertz, n_fft=samples_per_win_size, hop_length=samples_per_hop_size, n_mfcc=90)
# mfcc.shape

# %%
# mfcc_mean, \
# mfcc_median, \
# mfcc_mode, \
# mfcc_mode_cnt, \
# mfcc_min, \
# mfcc_max, \
# mfcc_range, \
# mfcc_var, \
# mfcc_std, \
# mfcc_first_quart, \
# mfcc_third_quart, \
# mfcc_inter_quart_range, \
# mfcc_entropy, \
# mfcc_kurt, \
# mfcc_skew = extract_spectogam_stats(mfcc)

# %%
# librosa.display.specshow(mfcc)

# %%
# spec_bw = librosa.feature.spectral_bandwidth(y=x_signals, sr=hertz, n_fft=samples_per_win_size, hop_length=samples_per_hop_size)
# spec_bw.shape

# %%
# new_spec_bw = spec_bw.reshape(-1)
# new_spec_bw.shape

# %%
# view_signal_feature(new_spec_bw, "spectral bandwidth")

# %%
# spec_cont = librosa.feature.spectral_contrast(y=x_signals, sr=hertz, n_fft=samples_per_win_size, hop_length=samples_per_hop_size)
# spec_cont.shape

# %%
# spec_cont_mean, \
# spec_cont_median, \
# spec_cont_mode, \
# spec_cont_mode_cnt, \
# spec_cont_min, \
# spec_cont_max, \
# spec_cont_range, \
# spec_cont_var, \
# spec_cont_std, \
# spec_cont_first_quart, \
# spec_cont_third_quart, \
# spec_cont_inter_quart_range, \
# spec_cont_entropy, \
# spec_cont_kurt, \
# spec_cont_skew = extract_spectogam_stats(spec_cont)

# %%
# librosa.display.specshow(spec_cont)

# %%
# spec_flat = librosa.feature.spectral_flatness(y=x_signals, n_fft=samples_per_win_size, hop_length=samples_per_hop_size)
# spec_flat.shape

# %%
# new_spec_flat = spec_flat.reshape(-1)
# new_spec_flat.shape

# %%
# view_signal_feature(new_spec_flat, "spectral flatness")

# %%
# spec_roll = librosa.feature.spectral_rolloff(y=x_signals, sr=hertz, n_fft=samples_per_win_size, hop_length=samples_per_hop_size)
# spec_roll.shape

# %%
# new_spec_roll = spec_roll.reshape(-1)
# new_spec_roll.shape

# %%
# view_signal_feature(new_spec_roll, "spectral rolloff")

# %%
# subject_features = conn.sql("""
#     SELECT * FROM subject_features
# """).to_arrow_table()

# %%
# subject_features

# %%
# subject_features = subject_features.append_column("zcr", [new_zcr])
# subject_features = subject_features.append_column("poly_feat_1", [poly_feats[0, :]])
# subject_features = subject_features.append_column("poly_feat_2", [poly_feats[1, :]])
# subject_features = subject_features.append_column("spec_cent", [new_spec_cent])
# subject_features = subject_features.append_column("spec_bw", [new_spec_bw])
# subject_features = subject_features.append_column("spec_flat", [new_spec_flat])
# subject_features = subject_features.append_column("spec_roll", [new_spec_roll])

# subject_features = subject_features.append_column("mel_spec_mean", [mel_spec_mean])
# subject_features = subject_features.append_column("mel_spec_median", [mel_spec_median])
# subject_features = subject_features.append_column("mel_spec_mode", [mel_spec_mode])
# subject_features = subject_features.append_column("mel_spec_mode_cnt", [mel_spec_mode_cnt])
# subject_features = subject_features.append_column("mel_spec_min", [mel_spec_min])
# subject_features = subject_features.append_column("mel_spec_max", [mel_spec_max])
# subject_features = subject_features.append_column("mel_spec_range", [mel_spec_range])
# subject_features = subject_features.append_column("mel_spec_var", [mel_spec_var])
# subject_features = subject_features.append_column("mel_spec_std", [mel_spec_std])
# subject_features = subject_features.append_column("mel_spec_first_quart", [mel_spec_first_quart])
# subject_features = subject_features.append_column("mel_spec_third_quart", [mel_spec_third_quart])
# subject_features = subject_features.append_column("mel_spec_inter_quart_range", [mel_spec_inter_quart_range])
# subject_features = subject_features.append_column("mel_spec_entropy", [mel_spec_entropy])
# subject_features = subject_features.append_column("mel_spec_kurt", [mel_spec_kurt])
# subject_features = subject_features.append_column("mel_spec_skew", [mel_spec_skew])

# subject_features = subject_features.append_column("mel_spec_db_mean", [mel_spec_db_mean])
# subject_features = subject_features.append_column("mel_spec_db_median", [mel_spec_db_median])
# subject_features = subject_features.append_column("mel_spec_db_mode", [mel_spec_db_mode])
# subject_features = subject_features.append_column("mel_spec_db_mode_cnt", [mel_spec_db_mode_cnt])
# subject_features = subject_features.append_column("mel_spec_db_min", [mel_spec_db_min])
# subject_features = subject_features.append_column("mel_spec_db_max", [mel_spec_db_max])
# subject_features = subject_features.append_column("mel_spec_db_range", [mel_spec_db_range])
# subject_features = subject_features.append_column("mel_spec_db_var", [mel_spec_db_var])
# subject_features = subject_features.append_column("mel_spec_db_std", [mel_spec_db_std])
# subject_features = subject_features.append_column("mel_spec_db_first_quart", [mel_spec_db_first_quart])
# subject_features = subject_features.append_column("mel_spec_db_third_quart", [mel_spec_db_third_quart])
# subject_features = subject_features.append_column("mel_spec_db_inter_quart_range", [mel_spec_db_inter_quart_range])
# subject_features = subject_features.append_column("mel_spec_db_entropy", [mel_spec_db_entropy])
# subject_features = subject_features.append_column("mel_spec_db_kurt", [mel_spec_db_kurt])
# subject_features = subject_features.append_column("mel_spec_db_skew", [mel_spec_db_skew])

# subject_features = subject_features.append_column("mfcc_mean", [mfcc_mean])
# subject_features = subject_features.append_column("mfcc_median", [mfcc_median])
# subject_features = subject_features.append_column("mfcc_mode", [mfcc_mode])
# subject_features = subject_features.append_column("mfcc_mode_cnt", [mfcc_mode_cnt])
# subject_features = subject_features.append_column("mfcc_min", [mfcc_min])
# subject_features = subject_features.append_column("mfcc_max", [mfcc_max])
# subject_features = subject_features.append_column("mfcc_range", [mfcc_range])
# subject_features = subject_features.append_column("mfcc_var", [mfcc_var])
# subject_features = subject_features.append_column("mfcc_std", [mfcc_std])
# subject_features = subject_features.append_column("mfcc_first_quart", [mfcc_first_quart])
# subject_features = subject_features.append_column("mfcc_third_quart", [mfcc_third_quart])
# subject_features = subject_features.append_column("mfcc_inter_quart_range", [mfcc_inter_quart_range])
# subject_features = subject_features.append_column("mfcc_entropy", [mfcc_entropy])
# subject_features = subject_features.append_column("mfcc_kurt", [mfcc_kurt])
# subject_features = subject_features.append_column("mfcc_skew", [mfcc_skew])

# subject_features = subject_features.append_column("spec_cont_mean", [spec_cont_mean])
# subject_features = subject_features.append_column("spec_cont_median", [spec_cont_median])
# subject_features = subject_features.append_column("spec_cont_mode", [spec_cont_mode])
# subject_features = subject_features.append_column("spec_cont_mode_cnt", [spec_cont_mode_cnt])
# subject_features = subject_features.append_column("spec_cont_min", [spec_cont_min])
# subject_features = subject_features.append_column("spec_cont_max", [spec_cont_max])
# subject_features = subject_features.append_column("spec_cont_range", [spec_cont_range])
# subject_features = subject_features.append_column("spec_cont_var", [spec_cont_var])
# subject_features = subject_features.append_column("spec_cont_std", [spec_cont_std])
# subject_features = subject_features.append_column("spec_cont_first_quart", [spec_cont_first_quart])
# subject_features = subject_features.append_column("spec_cont_third_quart", [spec_cont_third_quart])
# subject_features = subject_features.append_column("spec_cont_inter_quart_range", [spec_cont_inter_quart_range])
# subject_features = subject_features.append_column("spec_cont_entropy", [spec_cont_entropy])
# subject_features = subject_features.append_column("spec_cont_kurt", [spec_cont_kurt])
# subject_features = subject_features.append_column("spec_cont_skew", [spec_cont_skew])

# %%
# subject_features

# %%
# subject_features.shape

# %% [markdown]
# # Recall when we aggregate nulls that they are discounted and might as well be 0
# <!-- because turning infs to null values when all values/rows in that column are infs are averaged and still used for imputation still produce null values. What if there are cases when rows have now values that aren't inf? Then that means we'd turn the inf values to null, and during imputation whatever non null values are in the column that iwll be used to calculate the average and then impute the rest of the null values,
#
# but what if there aren't any values that are non inf? Then that means we'd be calculating null averages over and over?
#
# with non inf:
# `inf, 1, 2, 3 --nullification--> null, 1, 2, 3 --imputation--> 2, 1, 2, 3`
#
# with inf only:
# `inf, inf, inf, inf --nullification--> null, null, null, null --imputation--> null, null, null, null`
#
# with inf only what if?
# `inf, inf, inf, inf --nullification--> null, null, null, null --imputation--> 0, 0, 0, 0`
#
# with non inf only what if?
# `inf, 1, 2, 3, 0, 0, 0 --nullification--> null, 1, 2, 3, 0, 0, 0 --imputation using 0--> 0, 1, 2, 3, 0, 0, 0`
#
# the problem with the above is we are filling in null values with 0 when in fact it could be filled with  a userful value like the average of the numbers in the column, problem with using 0 for imputation is it it's not like a pure 0 feature that's part and parcel of the instance/row which directly corresponds to a label say male or female. Because what if for that row that naturally has that 0 feature it corresponds to male and mostly male? And we then impute 0 for that null value when it fact corresponds to a differetn label say female?? Then this would lead to incaccuracies in our model, given that 0 most usually is associated iwth male, we cannot associate a 0 that's been used for imputation for the label female
#
# so mas maganda talaga ideally is instead of null, we use zeros only if all values in the column are null and instead use imputation from average if there are non infs the column before they are turned into null values -->

# %%
# conn.sql("""
#     WITH null_table AS (
#         SELECT 
#             col0 AS spec_cont_kurt,
#             COUNT(*) OVER(ORDER BY NULL) AS total_count
#         FROM (VALUES (2), (5), (0), (NULL), (NULL), (NULL), (NULL), (NULL), (NULL), (NULL), (NULL), ('Infinity'::FLOAT), ('Infinity'::FLOAT), ('-Infinity'::FLOAT), (NULL), (NULL), (NULL), (NULL), (NULL), (NULL), (NULL))
#     ),
    
#     final AS (
#         SELECT 
#             COUNT(CASE 
#                 WHEN spec_cont_kurt = 'Infinity' THEN NULL 
#                 WHEN spec_cont_kurt = '-Infinity' THEN NULL
#                 ELSE spec_cont_kurt
#             END) OVER(ORDER BY NULL)AS non_null_spec_cont_kurt_cnt,
#             AVG(CASE 
#                 WHEN spec_cont_kurt = 'Infinity' THEN NULL 
#                 WHEN spec_cont_kurt = '-Infinity' THEN NULL
#                 ELSE spec_cont_kurt
#             END) OVER(ORDER BY NULL) AS non_null_spec_cont_kurt_avg,
#             total_count,
#             spec_cont_kurt
#         FROM null_table
#     )
    
#     -- we will only transform/impute the null values of a feature if the
#     -- null percentage is greater than a certain threshold e.g. 30%
#     -- 
#     SELECT
#         *,
#         ISINF(spec_cont_kurt) AS is_inf,
#         (total_count - non_null_spec_cont_kurt_cnt) / CAST(total_count AS FLOAT) AS null_perc,
#         CASE
#             -- we check here first thing if a value is null or even
#             -- if it is just an inf value, because we will not 
#             -- strictly retain these values as they will be imputed later
#             WHEN spec_cont_kurt IS NOT NULL 
#                 AND NOT ISINF(spec_cont_kurt) 
#                 THEN spec_cont_kurt
#             WHEN non_null_spec_cont_kurt_cnt = 0 THEN 0.0
#             WHEN (total_count - non_null_spec_cont_kurt_cnt) / CAST(total_count AS FLOAT) > 0.3
#                 THEN 0
#             ELSE non_null_spec_cont_kurt_avg
#         END AS imputed_col,
#         -- *
#         -- spec_cont_kurt 
#     FROM final
#     -- WHERE spec_cont_kurt = 'Infinity'
#     -- OR spec_cont_kurt = '-Infinity'
# """)
# Out:
# ┌─────────────────────────────┬─────────────────────────────┬─────────────┬────────────────┬─────────┬────────────┬─────────────┐
# │ non_null_spec_cont_kurt_cnt │ non_null_spec_cont_kurt_avg │ total_count │ spec_cont_kurt │ is_inf  │ null_perc  │ imputed_col │
# │            int64            │           double            │    int64    │     float      │ boolean │   float    │   double    │
# ├─────────────────────────────┼─────────────────────────────┼─────────────┼────────────────┼─────────┼────────────┼─────────────┤
# │                           3 │          2.3333333333333335 │          21 │            2.0 │ false   │ 0.85714287 │         2.0 │
# │                           3 │          2.3333333333333335 │          21 │            5.0 │ false   │ 0.85714287 │         5.0 │
# │                           3 │          2.3333333333333335 │          21 │            0.0 │ false   │ 0.85714287 │         0.0 │
# ...

# %% [markdown]
# # We have computed more than enough features we need, now we will load all of the subjects audio signal parquet files into one giant table

# %%
# local
signal_file_paths = [
    os.path.join(
        SILVER_DATA_DIR.format(
            DATA_DIR=DATA_DIR,
            FOLDER_NAME=SILVER_FOLDER_NAME,
            SUB_FOLDER_NAME=SUB_FOLDER_NAME
        ), 
        signal_file_path
    ).replace("\\", "/") 
    for signal_file_path in os.listdir(SILVER_DATA_DIR.format(
        DATA_DIR=DATA_DIR,
        FOLDER_NAME=SILVER_FOLDER_NAME,
        SUB_FOLDER_NAME=SUB_FOLDER_NAME
    )) 
    if (not "labels" in signal_file_path)
]
signal_file_paths
# Out:
# ['../../include/data/silver/stage-01/1028-20100710-hne',
#  '../../include/data/silver/stage-01/1337ad-20170321-ajg',
#  '../../include/data/silver/stage-01/1337ad-20170321-tkg',
#  '../../include/data/silver/stage-01/1snoke-20120412-hge',
#  '../../include/data/silver/stage-01/23yipikaye-20100807-ujm',
#  '../../include/data/silver/stage-01/Aaron-20080318-kdl',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-bft',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-cqj',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-fcp',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-hns',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-nky',
#  '../../include/data/silver/stage-01/Coren-20141121-pxp']

# %%
# # local
# signal_file_paths = [
#     str(signal_file_path).replace("\\", "/") for signal_file_path in Path(
#         SILVER_DATA_DIR.format(
#             DATA_DIR=DATA_DIR,
#             FOLDER_NAME=SILVER_FOLDER_NAME,
#             SUB_FOLDER_NAME=SUB_FOLDER_NAME
#         )
#     ).rglob('*')  
#     if signal_file_path.is_file() and "labels" not in str(signal_file_path)
# ]
# signal_file_paths

# %%
# Retrieve credentials from environment variables
# this is strictly used only in development
# load env variables
env_dir = Path('../../').resolve()
load_dotenv(os.path.join(env_dir, '.env'))
# Out:
# True

# %%
storage_account_name = os.environ.get("STORAGE_ACCOUNT_NAME")
credential = os.environ.get("STORAGE_ACCOUNT_KEY")
conn_str = os.environ.get("STORAGE_ACCOUNT_CONN_STR")

# %%
SILVER_DATA_DIR
# Out:
# '{DATA_DIR}/{FOLDER_NAME}/{SUB_FOLDER_NAME}'

# %%
# cloud
# create client with generated sas token
datalake_service_client = DataLakeServiceClient(
    account_url=f"https://{storage_account_name}.dfs.core.windows.net", 
    credential=credential
)

# retrieves file system client/container client 
# to retrieve datalake client
silver_container_client = datalake_service_client.get_file_system_client(f"{storage_account_name}-silver")

# we only get the directories in the first level of 
# the container, if it has a "/" then it means it is not
# an immediate folder in the container. This only really
# gets the subject folders 
signal_file_paths = [
    os.path.join(
        SILVER_FOLDER_NAME,
        path.name
    ).replace("\\", "/") 
    for path in silver_container_client.get_paths(path=SUB_FOLDER_NAME) 
    if (not "labels" in path.name) and (".parquet" in path.name)
]
signal_file_paths
# Out:
# []

# %% [markdown]
# # Once all paths from silver/stage-01 are extracted get only the ones that don't already exist in the paths silver/stage-02

# %%
# subjects_features_paths = [
#     str(signal_features_path).replace("\\", "/")
#     for signal_features_path in Path(
#         SILVER_DATA_DIR.format(
#             DATA_DIR=DATA_DIR, 
#             FOLDER_NAME=SILVER_FOLDER_NAME, 
#             SUB_FOLDER_NAME="stage-02"
#         )
#     ).rglob("*")
#     if signal_features_path.is_file()
# ]
# subjects_features_paths

# %%
# def filter_path_to_wavs(prev_stage_path_to_files, next_stage_path_to_files):
#     """
#     we compare this:
    
#     '../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0729.parquet',
#     '../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0730.parquet',
#     ...
#     '../../include/data/silver/stage-01/Coren-20141121-pxp/b0472.parquet',
#     '../../include/data/silver/stage-01/Coren-20141121-pxp/b0473.parquet',
#     '../../include/data/silver/stage-01/Coren-20141121-pxp/b0474.parquet',
#     '../../include/data/silver/stage-01/Coren-20141121-pxp/b0475.parquet',
#     '../../include/data/silver/stage-01/Coren-20141121-pxp/b0476.parquet',
#     '../../include/data/silver/stage-01/Coren-20141121-pxp/test_signal.parquet',]
    
#     to this:
    
#     '../../include/data/silver/stage-02/1337ad-20170321-tkg/en-0729.parquet',
#     '../../include/data/silver/stage-02/1337ad-20170321-tkg/en-0730.parquet',
#     ...
#     '../../include/data/silver/stage-02/Coren-20141121-pxp/b0472.parquet',
#     '../../include/data/silver/stage-02/Coren-20141121-pxp/b0473.parquet',
#     '../../include/data/silver/stage-02/Coren-20141121-pxp/b0474.parquet',
#     '../../include/data/silver/stage-02/Coren-20141121-pxp/b0475.parquet',
#     '../../include/data/silver/stage-02/Coren-20141121-pxp/b0476.parquet']
    
#     but we need to normalize both lists to be just the subject folder and its 
#     corresponding root file without the extension, and conversely subject
#     folder in the next stage and its corresponding parquet file name 
#     without the extension. E.g. 1337ad-20170321-tkg/en-0729.wav becomes
#     1337ad-20170321-tkg/en-0729 and 
#     ../../include/data/silver/stage-02/1337ad-20170321-tkg/en-0730.parquet 
#     becomes 1337ad-20170321-tkg/en-0730
#     """
    
#     normalized_prev_stage_path_to_files_map = dict(zip(
#         prev_stage_path_to_files,
#         [
#             os.path.join(
#                 path.split("/")[-2],
#                 path.split("/")[-1].replace(".parquet", "")
#             ).replace("\\", "/")
#             for path in prev_stage_path_to_files
#         ],
#     ))

#     normalized_next_stage_path_to_files = [
#         os.path.join(
#             path.split("/")[-2],
#             path.split("/")[-1].replace(".parquet", "")
#         ).replace("\\", "/")
#         for path in next_stage_path_to_files
#     ]
    
#     print(normalized_prev_stage_path_to_files_map)
#     print(normalized_next_stage_path_to_files[:5])

#     return [
#         key for key, normalized_path_to_wav in normalized_prev_stage_path_to_files_map.items()
#         if normalized_path_to_wav not in normalized_next_stage_path_to_files
#     ]

# %%
# signal_file_paths_filt = filter_path_to_wavs(signal_file_paths, subjects_features_paths)
# signal_file_paths_filt

# %%
def change_data_capture_features(delta_table: DeltaTable, df: pa.Table):
    """
    follows a change data capture scheme for the all signals of
    subject which includes have multiple wav files, and in. It 
    basically does the ff:
    
    1. deletes all records in the existing delta table if there are 
    new record based on the combination of the keys subject_id, 
    wav_file_row_number, and file_name in source dataframe that are
    not present anymore
    
    2. inserts all records in the existing delta table if there 
    are new record based on the combination of the keys subject_id, 
    wav_file_row_number, and file_name in the source dataframe that 
    are not present in the existing delta table.
    
    3. And updates all records in the existing delta table if there 
    are any records based on the combination of the keys subject_id, 
    wav_file_row_number, and file_name in the source dataframe that 
    have changed their signal values when compared to the existing 
    delta table. E.g. when a subject's signal changes then obviously
    its wav_file_row_number may have new row values and new signals
    that can be added and likewise if those signals at a specific 
    wav_file_row_number, file_name, and subject changes then values
    in the existing delta table will be updated
    """
    
    # subject_id,
    # file_name,
    
    # does this even change? Maybe if hertz/sampling rate is changed
    # and loaded at does this even change? Maybe if new data arrives
    # wav_file_row_number,
    # loaded_at,
    
    # label,
    # split,
    # partition
    
    feature_cols = list(filter(
        lambda col: col not in (
            'subject_id',
            'wav_file_row_number',
            'file_name',
            'loaded_at',
            'label',
            'split',
            'partition'
        ),
        df.column_names
    ))
    
    update_clause = {
        # these are not included as these are the composite keys
        # that are not by good practice supposed to be updated
        # "subject_id": "source.subject_id",
        # "file_name": "source.file_name",
        # "wav_file_row_number": "source.wav_file_row_number",
        
        "loaded_at": "source.loaded_at",
        "label": "source.label",
        "split": "source.split",
        "partition": "source.partition",
        
        # when feature_hash_key does change because of change in features
        # update the feature_hash_key also, and update all features
        "feature_hash_key": "source.feature_hash_key"
    }
    update_clause.update({col: f"source.{col}" for col in feature_cols})
    print(update_clause)
    
    # when_matched_clause = " OR ".join([
    #     f"source.{col} IS DISTINCT FROM target.{col}" 
    #     for col in feature_cols + ["wav_file_row_number", "loaded_at", "label", "split", "partition"]
    # ])
    when_matched_clause = """
        (source.loaded_at IS DISTINCT FROM target.loaded_at) OR
        (source.label IS DISTINCT FROM target.label) OR
        (source.split IS DISTINCT FROM target.split) OR
        (source.partition IS DISTINCT FROM target.partition) OR
        (source.feature_hash_key IS DISTINCT FROM target.feature_hash_key)
    """
    print(when_matched_clause)

    try:
        delta_table.merge(
            df,
            predicate="""
                target.subject_id = source.subject_id 
                AND target.file_name = source.file_name
                AND target.window_row_number = source.wav_file_row_number
            """,
            source_alias="source",
            target_alias="target",  
            merge_schema=True
        )\
        .when_matched_update(
            updates=update_clause, 
            # this tells delta to only update a record if the new record
            # does indeed have changed its column values when compared to the
            # current record
            predicate=when_matched_clause
        )\
        .when_not_matched_by_source_delete()\
        .when_not_matched_insert_all()\
        .execute()

    except Exception as e:
        # this runs if no table exists in s3 bucket
        logger.warning(f"`{e}` occured during delta upsert")
        
def write_delta_to_bucket(
    azure_creds: dict, 
    df: pa.Table, 
    container_name: str, 
    object_name: str, 
    folder_name: str, 
    is_local: bool, 
    merge_func: Callable,
    subject_id: str
):
    """
    writes a pyarrow dataframe to an azure container in delta format. 
    What we want here is to check if an existing parquet with signal
    data already exists in azure, 
    
    As opposed to a scheme where if in azure there is no current parquet
    and then creating a parquet with object id indicating its the first, 
    and if there is already create a parquet with the object id with 
    the highest or max number, we use a delta lake format  
    """

    try:    
        # if alternative/local path is not provided 
        # modify the delta path if there is no alternative path
        # The URI points to the S3 bucket and folder where the Delta table lives
        DELTA_PATH = os.path.join(
            container_name, 
            folder_name, 
            object_name
        ).replace("\\", "/")
        
        # create delta table from path and load the
        #  delta table if it already exists
        delta_table = DeltaTable(DELTA_PATH, storage_options=azure_creds) if not is_local else DeltaTable(DELTA_PATH)

        # create a delta directory if it is local
        if not "abfss" in DELTA_PATH:
            DELTA_DIR, _ = DELTA_PATH.rsplit("/", 1)
            os.makedirs(DELTA_DIR, exist_ok=True)
        
        # Table exists, so APPEND the new data
        logger.info(f"Delta table found at {DELTA_PATH}") 
        logger.info(f"Inserting new and updated rows...")
        
        # update old records and insert new records 
        merge_func(delta_table, df, subject_id)
        
    except Exception as e:
        # this runs if no table exists in s3 bucket
        logger.warning(f"`{e}` occured during delta update")
        logger.warning(f"No Delta table found.")
        logger.info(f"Creating new table with {df.num_rows} rows...")

        # delta table is written in s3 bucket with given
        # credentials and path
        write_deltalake(
            DELTA_PATH, 
            df, 
            # Use overwrite (or error) to create the initial table
            mode="overwrite", 
            storage_options=azure_creds,
        )
        
def align_spectral_features_length(feature, target_len, pad_mode='edge'):
    """
    Aligns audio features to a target length along the time axis (axis 1).
    Works for 2D arrays like MFCC (n_mfcc, n_frames) or ZCR (1, n_frames).
    """
    curr_len = feature.shape[1]
    
    if curr_len < target_len:
        # Calculate how many frames are missing
        pad_width = target_len - curr_len
        # np.pad(array, ((top, bottom), (left, right)), mode)
        # We only want to pad the 'right' side of the second axis
        # >>> import numpy as np
        # >>>
        # >>> test = np.array([
        # ...     [1, 2, 3],
        # ...     [4,5, 6],
        # ... ])
        # >>>
        # >>> pad_width = 5
        # >>> padded_test = np.pad(test, ((0, 0), (0, pad_width)), mode='edge')
        # >>> padded_test
        # array([[1, 2, 3, 3, 3, 3, 3, 3],
        #     [4, 5, 6, 6, 6, 6, 6, 6]])
        padded_feature = np.pad(feature, ((0, 0), (0, pad_width)), mode=pad_mode)
        return padded_feature
    
    elif curr_len > target_len:
        # If librosa gave us an extra frame, trim it back which 
        # is equivalent to the ff:
        # zcr_n_values_to_rem = np.abs(zcr.shape[1] - time.shape[0])
        # zcr = zcr.reshape(-1)[:-zcr_n_values_to_rem]
        return feature[:, :target_len]
    
    return feature

def extract_spectrogram_stats(spectrogram):
    """
    extracts statistical features of mel frequency ceptstral 
    coefficients, mel spectrogram, mel decibel spectrogram,
    spectral contrast spectrogram matrices along the the x-axis
    so if a matrix or spectrogram is (90, 35) final array will 
    be (1, 35)
    """

    # central tendency
    spec_mean = np.mean(spectrogram, axis=0)
    spec_median = np.median(spectrogram, axis=0)
    spec_mode = mode(spectrogram, axis=0).mode
    spec_mode_cnt = mode(spectrogram, axis=0).count
    
    # spread
    spec_min = np.min(spectrogram, axis=0)
    spec_max = np.max(spectrogram, axis=0)
    spec_range = spec_max - spec_min
    spec_var = np.var(spectrogram, axis=0)
    spec_std = np.std(spectrogram, axis=0)

    # percentiles
    spec_first_quart = np.percentile(spectrogram, 25, axis=0)
    spec_third_quart = np.percentile(spectrogram, 75, axis=0)
    spec_inter_quart_range  = spec_third_quart - spec_first_quart

    # morphology
    spec_entropy = entropy(spectrogram, axis=0)
    spec_kurt = kurt(spectrogram, axis=0)
    spec_skew = skew(spectrogram, axis=0)

    return (
        spec_mean, 
        spec_median, 
        spec_mode, 
        spec_mode_cnt, 
        spec_min, 
        spec_max, 
        spec_range, 
        spec_var, 
        spec_std, 
        spec_first_quart, 
        spec_third_quart, 
        spec_inter_quart_range, 
        spec_entropy, 
        spec_kurt, 
        spec_skew
    )

def compute_statistical_features(
    conn, 
    subject_table, 
    samples_per_win_size, 
    samples_per_hop_size,
):
    """
    computes statistical features of audio signals using
    duckdb window functions to calculate features like mean,
    median, mode, min, max, variance, standard deviation,
    quantiles, inter quantile range, entropy, kurtosis, skewness
    """
    
    # count = conn.sql("""
    #     SELECT COUNT(rowId) FROM subject_table
    # """).fetchall()[-1][-1]
    conn.sql(f"""
        CREATE OR REPLACE TEMPORARY TABLE subject_features AS (
            WITH subject_table AS (
                SELECT
                    signals, 
                    subject_id, 
                    wav_file_row_number, 
                    file_name
                FROM DELTA_SCAN('{DELTA_SUBJECT_TABLE_PATH}')
            ),
            
            stat_feats_1 AS (
                SELECT
                    subject_id, 
                    signals, 
                    wav_file_row_number,
                    file_name,
                    
                    KURTOSIS(signals) OVER(PARTITION BY subject_id, file_name ORDER BY wav_file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_kurt,
                    SKEWNESS(signals) OVER(PARTITION BY subject_id, file_name ORDER BY wav_file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_skew,
                    ENTROPY(signals)OVER(PARTITION BY subject_id, file_name ORDER BY wav_file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_entropy,
                    AVG(signals) OVER(PARTITION BY subject_id, file_name ORDER BY wav_file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_mean,
                    MEDIAN(signals) OVER(PARTITION BY subject_id, file_name ORDER BY wav_file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_median,
                    MODE(signals) OVER(PARTITION BY subject_id, file_name ORDER BY wav_file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_mode,
                    MIN(signals) OVER(PARTITION BY subject_id, file_name ORDER BY wav_file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_min,
                    MAX(signals) OVER(PARTITION BY subject_id, file_name ORDER BY wav_file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_max,
                    VAR_SAMP(signals) OVER(PARTITION BY subject_id, file_name ORDER BY wav_file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_var,
                    STDDEV_SAMP(signals) OVER(PARTITION BY subject_id, file_name ORDER BY wav_file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_stddev,
                    QUANTILE_CONT(signals, 0.25) OVER(PARTITION BY subject_id, file_name ORDER BY wav_file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_first_quart,
                    QUANTILE_CONT(signals, 0.75) OVER(PARTITION BY subject_id, file_name ORDER BY wav_file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_third_quart
                FROM subject_table
                WHERE (wav_file_row_number % {samples_per_hop_size}) = 0
                ORDER BY wav_file_row_number
            ),
            
            stat_feats_2 AS (
                SELECT 
                    *,
                    (freq_max - freq_min) AS freq_range,
                    (freq_third_quart - freq_first_quart) AS freq_inter_quart_range
                FROM stat_feats_1
            )
            
            SELECT * FROM stat_feats_2
        )
    """)

    subject_features = conn.sql(f"""
        SELECT * FROM subject_features
    """).to_arrow_table()
    
    # cleanup
    conn.sql("DROP TABLE subject_features")

    return subject_features

def compute_spectral_features(
    subject_features,
    x_signals,
    hertz,
    samples_per_win_size,
    samples_per_hop_size,
    n_frames
):
    """
    computes spectral features of audio signals using
    librosa library
    """

    # note a center of false still doesn't work to get librosa 
    # feature functions to calculate features the size of our 
    # statistical features so we must use the last value of these 
    # resulting features as padding to match thevlength of our 
    # statistical features. E.g. statiscal feature table has shape
    # (28, 19) and computed librosa feature like zcr has (1, 24)
    # then we have to subtract 28 - 24 = 4 and 4 will be the number
    # of values we need to pad to the zcr feature using this 
    # features last vlue
    zcr = librosa.feature.zero_crossing_rate(
        y=x_signals, 
        frame_length=samples_per_win_size, 
        hop_length=samples_per_hop_size,
    )[:, :n_frames]
    # print(f"ZCR shape: {zcr.shape}")
    zcr = align_spectral_features_length(zcr, n_frames, pad_mode='edge')
    # print(f"ZCR shape: {zcr.shape}")
    # print(zcr[:, zcr.shape[1] - 5:])
    
    poly_feats = librosa.feature.poly_features(
        y=x_signals, 
        sr=hertz, 
        n_fft=samples_per_win_size, 
        hop_length=samples_per_hop_size
    )[:, :n_frames]
    poly_feats = align_spectral_features_length(poly_feats, n_frames, pad_mode='edge')
    # print(f"Poly shape: {poly_feats.shape}")

    mel_spec = librosa.feature.melspectrogram(
        y=x_signals, 
        sr=hertz, 
        n_fft=samples_per_win_size, 
        hop_length=samples_per_hop_size, 
        n_mels=90
    )[:, :n_frames]
    mel_spec = align_spectral_features_length(mel_spec, n_frames, pad_mode='edge')
    mel_spec_mean, \
    mel_spec_median, \
    mel_spec_mode, \
    mel_spec_mode_cnt, \
    mel_spec_min, \
    mel_spec_max, \
    mel_spec_range, \
    mel_spec_var, \
    mel_spec_std, \
    mel_spec_first_quart, \
    mel_spec_third_quart, \
    mel_spec_inter_quart_range, \
    mel_spec_entropy, \
    mel_spec_kurt, \
    mel_spec_skew = extract_spectrogram_stats(mel_spec)
    # print(f"Mel Spectrogram shape: {mel_spec.shape}")

    mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
    mel_spec_db = align_spectral_features_length(mel_spec_db, n_frames, pad_mode='edge')
    mel_spec_db_mean, \
    mel_spec_db_median, \
    mel_spec_db_mode, \
    mel_spec_db_mode_cnt, \
    mel_spec_db_min, \
    mel_spec_db_max, \
    mel_spec_db_range, \
    mel_spec_db_var, \
    mel_spec_db_std, \
    mel_spec_db_first_quart, \
    mel_spec_db_third_quart, \
    mel_spec_db_inter_quart_range, \
    mel_spec_db_entropy, \
    mel_spec_db_kurt, \
    mel_spec_db_skew = extract_spectrogram_stats(mel_spec_db)
    # print(f"Mel Spectrogram DB shape: {mel_spec_db.shape}")

    mfcc = librosa.feature.mfcc(
        y=x_signals, 
        sr=hertz, 
        n_fft=samples_per_win_size, 
        hop_length=samples_per_hop_size, n_mfcc=90
    )[:, :n_frames]
    mfcc = align_spectral_features_length(mfcc, n_frames, pad_mode='edge')
    mfcc_mean, \
    mfcc_median, \
    mfcc_mode, \
    mfcc_mode_cnt, \
    mfcc_min, \
    mfcc_max, \
    mfcc_range, \
    mfcc_var, \
    mfcc_std, \
    mfcc_first_quart, \
    mfcc_third_quart, \
    mfcc_inter_quart_range, \
    mfcc_entropy, \
    mfcc_kurt, \
    mfcc_skew = extract_spectrogram_stats(mfcc)
    # print(f"MFCC shape: {mfcc.shape}")
    
    spec_cont = librosa.feature.spectral_contrast(
        y=x_signals, 
        sr=hertz, 
        n_fft=samples_per_win_size, 
        hop_length=samples_per_hop_size
    )[:, :n_frames]
    spec_cont = align_spectral_features_length(spec_cont, n_frames, pad_mode='edge')
    spec_cont_mean, \
    spec_cont_median, \
    spec_cont_mode, \
    spec_cont_mode_cnt, \
    spec_cont_min, \
    spec_cont_max, \
    spec_cont_range, \
    spec_cont_var, \
    spec_cont_std, \
    spec_cont_first_quart, \
    spec_cont_third_quart, \
    spec_cont_inter_quart_range, \
    spec_cont_entropy, \
    spec_cont_kurt, \
    spec_cont_skew = extract_spectrogram_stats(spec_cont)
    # print(f"spectral contrast shape: {zcr.shape}")

    spec_cent = librosa.feature.spectral_centroid(
        y=x_signals, 
        sr=hertz, 
        n_fft=samples_per_win_size, 
        hop_length=samples_per_hop_size
    )[:, :n_frames]
    spec_cent = align_spectral_features_length(spec_cent, n_frames, pad_mode='edge')
    # print(f"Spectral centroid shape: {spec_cent.shape}")

    spec_bw = librosa.feature.spectral_bandwidth(
        y=x_signals, 
        sr=hertz, 
        n_fft=samples_per_win_size, 
        hop_length=samples_per_hop_size
    )[:, :n_frames]
    spec_bw = align_spectral_features_length(spec_bw, n_frames, pad_mode='edge')
    # print(f"Spectral bandwidth shape: {spec_bw.shape}")

    spec_flat = librosa.feature.spectral_flatness(
        y=x_signals, 
        n_fft=samples_per_win_size, 
        hop_length=samples_per_hop_size
    )[:, :n_frames]
    spec_flat = align_spectral_features_length(spec_flat, n_frames, pad_mode='edge')
    # print(f"Spectral flatness shape: {spec_flat.shape}")

    spec_roll = librosa.feature.spectral_rolloff(
        y=x_signals, 
        sr=hertz, 
        n_fft=samples_per_win_size, 
        hop_length=samples_per_hop_size
    )[:, :n_frames]
    spec_roll = align_spectral_features_length(spec_roll, n_frames, pad_mode='edge')
    # print(f"Spectral rolloff shape: {spec_roll.shape}")

    # add the newly computed spectographic and chromagraphic
    # features as columns
    subject_features = subject_features.append_column("zcr", [zcr.reshape(-1)])
    subject_features = subject_features.append_column("poly_feat_1", [poly_feats[0, :]])
    subject_features = subject_features.append_column("poly_feat_2", [poly_feats[1, :]])
    subject_features = subject_features.append_column("spec_cent", [spec_cent.reshape(-1)])
    subject_features = subject_features.append_column("spec_bw", [spec_bw.reshape(-1)])
    subject_features = subject_features.append_column("spec_flat", [spec_flat.reshape(-1)])
    subject_features = subject_features.append_column("spec_roll", [spec_roll.reshape(-1)])

    subject_features = subject_features.append_column("mel_spec_mean", [mel_spec_mean])
    subject_features = subject_features.append_column("mel_spec_median", [mel_spec_median])
    subject_features = subject_features.append_column("mel_spec_mode", [mel_spec_mode])
    subject_features = subject_features.append_column("mel_spec_mode_cnt", [mel_spec_mode_cnt])
    subject_features = subject_features.append_column("mel_spec_min", [mel_spec_min])
    subject_features = subject_features.append_column("mel_spec_max", [mel_spec_max])
    subject_features = subject_features.append_column("mel_spec_range", [mel_spec_range])
    subject_features = subject_features.append_column("mel_spec_var", [mel_spec_var])
    subject_features = subject_features.append_column("mel_spec_std", [mel_spec_std])
    subject_features = subject_features.append_column("mel_spec_first_quart", [mel_spec_first_quart])
    subject_features = subject_features.append_column("mel_spec_third_quart", [mel_spec_third_quart])
    subject_features = subject_features.append_column("mel_spec_inter_quart_range", [mel_spec_inter_quart_range])
    subject_features = subject_features.append_column("mel_spec_entropy", [mel_spec_entropy])
    subject_features = subject_features.append_column("mel_spec_kurt", [mel_spec_kurt])
    subject_features = subject_features.append_column("mel_spec_skew", [mel_spec_skew])

    subject_features = subject_features.append_column("mel_spec_db_mean", [mel_spec_db_mean])
    subject_features = subject_features.append_column("mel_spec_db_median", [mel_spec_db_median])
    subject_features = subject_features.append_column("mel_spec_db_mode", [mel_spec_db_mode])
    subject_features = subject_features.append_column("mel_spec_db_mode_cnt", [mel_spec_db_mode_cnt])
    subject_features = subject_features.append_column("mel_spec_db_min", [mel_spec_db_min])
    subject_features = subject_features.append_column("mel_spec_db_max", [mel_spec_db_max])
    subject_features = subject_features.append_column("mel_spec_db_range", [mel_spec_db_range])
    subject_features = subject_features.append_column("mel_spec_db_var", [mel_spec_db_var])
    subject_features = subject_features.append_column("mel_spec_db_std", [mel_spec_db_std])
    subject_features = subject_features.append_column("mel_spec_db_first_quart", [mel_spec_db_first_quart])
    subject_features = subject_features.append_column("mel_spec_db_third_quart", [mel_spec_db_third_quart])
    subject_features = subject_features.append_column("mel_spec_db_inter_quart_range", [mel_spec_db_inter_quart_range])
    subject_features = subject_features.append_column("mel_spec_db_entropy", [mel_spec_db_entropy])
    subject_features = subject_features.append_column("mel_spec_db_kurt", [mel_spec_db_kurt])
    subject_features = subject_features.append_column("mel_spec_db_skew", [mel_spec_db_skew])

    subject_features = subject_features.append_column("mfcc_mean", [mfcc_mean])
    subject_features = subject_features.append_column("mfcc_median", [mfcc_median])
    subject_features = subject_features.append_column("mfcc_mode", [mfcc_mode])
    subject_features = subject_features.append_column("mfcc_mode_cnt", [mfcc_mode_cnt])
    subject_features = subject_features.append_column("mfcc_min", [mfcc_min])
    subject_features = subject_features.append_column("mfcc_max", [mfcc_max])
    subject_features = subject_features.append_column("mfcc_range", [mfcc_range])
    subject_features = subject_features.append_column("mfcc_var", [mfcc_var])
    subject_features = subject_features.append_column("mfcc_std", [mfcc_std])
    subject_features = subject_features.append_column("mfcc_first_quart", [mfcc_first_quart])
    subject_features = subject_features.append_column("mfcc_third_quart", [mfcc_third_quart])
    subject_features = subject_features.append_column("mfcc_inter_quart_range", [mfcc_inter_quart_range])
    subject_features = subject_features.append_column("mfcc_entropy", [mfcc_entropy])
    subject_features = subject_features.append_column("mfcc_kurt", [mfcc_kurt])
    subject_features = subject_features.append_column("mfcc_skew", [mfcc_skew])

    subject_features = subject_features.append_column("spec_cont_mean", [spec_cont_mean])
    subject_features = subject_features.append_column("spec_cont_median", [spec_cont_median])
    subject_features = subject_features.append_column("spec_cont_mode", [spec_cont_mode])
    subject_features = subject_features.append_column("spec_cont_mode_cnt", [spec_cont_mode_cnt])
    subject_features = subject_features.append_column("spec_cont_min", [spec_cont_min])
    subject_features = subject_features.append_column("spec_cont_max", [spec_cont_max])
    subject_features = subject_features.append_column("spec_cont_range", [spec_cont_range])
    subject_features = subject_features.append_column("spec_cont_var", [spec_cont_var])
    subject_features = subject_features.append_column("spec_cont_std", [spec_cont_std])
    subject_features = subject_features.append_column("spec_cont_first_quart", [spec_cont_first_quart])
    subject_features = subject_features.append_column("spec_cont_third_quart", [spec_cont_third_quart])
    subject_features = subject_features.append_column("spec_cont_inter_quart_range", [spec_cont_inter_quart_range])
    subject_features = subject_features.append_column("spec_cont_entropy", [spec_cont_entropy])
    subject_features = subject_features.append_column("spec_cont_kurt", [spec_cont_kurt])
    subject_features = subject_features.append_column("spec_cont_skew", [spec_cont_skew])

    return subject_features

def impute_features(
    conn: duckdb.DuckDBPyConnection, 
    spectrographic_features: pa.Table, 
    threshold: float,
):
    """
    imputes missing values in the features table using methods like
    median, mean, knn, and regression imputation
    
    if the threshold value is a certain percentage e.g. 0.3 or 30% of 
    the values in a column are missing then we will use median/avg imputation
    
    we can use sql for median and mean imputation but for knn and regression
    we will have to use sklearn imputation functions which will require
    us to convert our features table to a pandas dataframe and then back to
    an arrow table to save as parquet
    """
    # Implementation for imputing missing feature values
    
    # retrieve column names of features table to know which columns to apply
    rows = conn.sql("""
        SELECT column_name
        FROM (DESCRIBE spectrographic_features)
    """).fetchall()
    feat_cols = list(filter(lambda feat_col: feat_col not in (
        "subject_id", 
        "signals", 
        "wav_file_row_number",
        "file_name"
    ), [row[-1] for row in rows]))
    
    # 1. Generate the Window Function parts
    stats_clauses = []
    for col in feat_cols:
        # we could also count inf values apart from null values
        # apart from merely using a query like this
        # "COUNT({col}) OVER(PARTITION BY subject_id, file_name) as non_null_{col}"
        
        # if we had a set of columns
        # 1, 2, 3, 4, 5, 6, null, null, null
        # inf, inf, inf, inf, inf, inf, 10, 11, 12
        # -inf, -inf, -inf, -inf, -inf, -inf, 13, 14, 15
        # inf, inf, inf, inf, inf, inf, inf, inf, inf
        # null, null, null, null, null, null, null, null, null
        
        # it would all become
        
        # 1, 2, 3, 4, 5, 6, null, null, null
        # null, null, null, null, null, null, 10, 11, 12
        # null, null, null, null, null, null, 13, 14, 15
        # null, null, null, null, null, null, null, null, null
        # null, null, null, null, null, null, null, null, null
        
        # if we use the case when in the count window function.
        # we do this because we want to normalize it such that
        # even inf values are counted as nulls and will not be therefore
        # counted in the count window function as a legitimate value
        stats_clauses.append(f"""
            COUNT(CASE
                WHEN {col} = 'Infinity' THEN NULL
                WHEN {col} = '-Infinity' THEN NULL
                ELSE {col}
            END) OVER(PARTITION BY subject_id, file_name) AS non_null_{col}_cnt
        """)
        stats_clauses.append(f"""
            AVG(CASE
                WHEN {col} = 'Infinity' THEN NULL
                WHEN {col} = '-Infinity' THEN NULL
                ELSE {col}
            END) OVER(PARTITION BY subject_id, file_name) AS non_null_{col}_avg
        """)
        
    # 2. Generate the CASE statements
    impute_clauses = []
    for col in feat_cols:
        # if the column value in a certain row is not null
        # then we will simply keep it as it is, and return it.
        # if the total non null values count of the column is 
        # 0 meaning all values are null then we will impute it
        # just 0.0. If the percentage of missing values in the
        # column is greater than a certain threshold e.g. 0.3 or 
        # 30% then we will impute it with the median/avg of the
        # column
        
        # we check here first thing if a value is null or even
        # if it is just an inf value, because we will not 
        # strictly retain these values as they will be imputed later
        clause = f"""
        CASE 
            WHEN 
                {col} IS NOT NULL 
                AND NOT ISINF({col})
                THEN {col}
            WHEN non_null_{col}_cnt = 0 THEN 0.0
            WHEN (total_count - non_null_{col}_cnt) / CAST(total_count AS FLOAT) > {threshold}
                THEN non_null_{col}_avg
            ELSE non_null_{col}_avg
        END AS {col}
        """
        impute_clauses.append(clause)
        
    query = f"""
        WITH subject_features_imp AS (
            SELECT
                *,
                COUNT(*) OVER(PARTITION BY subject_id, file_name) AS total_count,
                {", ".join(stats_clauses)}
            FROM spectrographic_features
        ),
        
        final AS (
            SELECT
                subject_id,
                signals,
                wav_file_row_number,
                file_name,
                {", ".join(impute_clauses)}
            FROM subject_features_imp
        )
        
        -- add hashing key from combination of feature columns
        SELECT
            *,
            MD5(CONCAT_WS('||', {', '.join(feat_cols)})) AS feature_hash_key
        FROM final
    """
    
    print(conn.sql(query))
    
    imputed_features = conn.sql(query).to_arrow_table()
    
    return imputed_features
        
    

def transform_signals(
    signal_file_paths, 
    data_dir, 
    hertz: int=16000, 
    window_time: int=3, 
    hop_time: int=1, 
    storage_account_name: str=None, 
    credential: str=None,
    threshold: float=0.3,
):
    """
    concurrently extracts the features of each signal
    the first half of feature extraction involves using
    sql for computing statistical features of the subjects
    signals

    the second half involves using librosa for computing
    for instance spectral features of the sujects signals
    as there is not supported function to compute audio
    specific signal features like spectrograms, chromagrams,
    tempogram, etc.
    """
    
    # we calculate the window size of each segment or the
    # amount of samples it has to have based on the frequency
    samples_per_win_size = int(window_time * hertz)
    samples_per_hop_size = int(hop_time * hertz)

    # # connect to in memory db
    # conn = duckdb.connect()

    if storage_account_name and credential:
        handler = pa_adl.AccountHandler.from_account_name(storage_account_name, credential=credential)
        fs = pa.fs.PyFileSystem(handler)

    def helper(signal_file_path):
        
        try:
            # connect to in memory db
            conn = duckdb.connect()

            # extract subject name from file path
            subject_id = signal_file_path.split("/")[-2]
            subject_file_id = signal_file_path.split("/")[-1].replace(".parquet", "")
            print(f"Subject {subject_id} with subject file id {subject_file_id} is processing...")

            # read subjects table and it ssignals
            # can read from both cloud and local
            subject_table = conn.sql(f"""
                SELECT
                    signals, 
                    subject_id, 
                    wav_file_row_number, 
                    file_name
                FROM DELTA_SCAN('{signal_file_path}')
            """).to_arrow_table()

            # extract signals from subjects feature table and 
            # convert to numpy array for librosa to compute 
            # spectral features
            x_signals = subject_table["signals"].to_numpy()

            # calculate statistical features
            statistical_features = compute_statistical_features(
                conn,
                subject_table, 
                samples_per_win_size, 
                samples_per_hop_size
            )
            print(f"subject statistical features shape: {statistical_features.shape}")

            # get the number of frames used using a window of 48000
            # and hop length of 16000
            n_frames = statistical_features.shape[0]
            print(f"Number of frames: {n_frames}")

            # compute spectographic and chromagraphic features
            spectrographic_features = compute_spectral_features(
                statistical_features, 
                x_signals, 
                hertz, 
                samples_per_win_size, 
                samples_per_hop_size, 
                n_frames
            )
            
            print(f"subject spectrographic features shape: {spectrographic_features.shape}")
            
            imputed_features = impute_features(
                conn, 
                spectrographic_features, 
                threshold
            )
            print(imputed_features)
            
            # # create dedicated folder of subject containing all
            # # its features for each of its signals derived from
            # # individual wav file
            # # ../../include/data/silver/stage-02 + <subject_id>
            # save_dir = os.path.join(data_dir, subject_id).replace("\\", "/")
            
            # # create save path
            # # ../../include/data/silver/stage-02/<subject_id>/features_0.parquet
            # save_path = os.path.join(save_dir, f"{subject_file_id}.parquet").replace("\\", "/")
            
            # if storage_account_name and credential:
            #     pq.write_table(imputed_features, save_path, filesystem=fs)
            # else:
            #     # make directory where subject features wil lbe saved
            #     os.makedirs(save_dir, exist_ok=True)
                
            #     # write table to a 2nd sub stage in silver staging layer 
            #     pq.write_table(imputed_features, save_path)

        except Exception as e:
            print(f"error {e} occured on subject id {subject_id} and file {subject_file_id}")
            
            # return the last subjects features
            return subject_id, e

    # concurrently calculate statistical features and spectral
    # features of each subject using DuckDB SQL and librosa
    with ThreadPoolExecutor(max_workers=2) as exe:
        subjects_features_list = list(exe.map(helper, signal_file_paths))

    return subjects_features_list

# %%
# local
SAVE_DIR = SILVER_DATA_DIR.format(
    DATA_DIR=DATA_DIR,
    FOLDER_NAME=SILVER_FOLDER_NAME,
    SUB_FOLDER_NAME="stage-02"
)
SAVE_DIR

# # cloud
# SAVE_DIR = SILVER_DATA_DIR.format(
#     FOLDER_NAME=SILVER_FOLDER_NAME,
#     SUB_FOLDER_NAME="stage-02"
# )
# SAVE_DIR
# Out:
# '../../include/data/silver/stage-02'

# %%
signal_file_paths[:1]
# Out:
# ['../../include/data/silver/stage-01/1028-20100710-hne']

# %%
# local
subjects_features = transform_signals(
    signal_file_paths[:1], 
    SAVE_DIR, 
    storage_account_name=None, 
    credential=None, 
    threshold=0.3
)
# Out:
# Subject stage-01 with subject file id 1028-20100710-hne is processing...
# subject statistical features shape: (35, 18)
# Number of frames: 35
# subject spectrographic features shape: (35, 85)
# ...

# %%
# # cloud
# subjects_features = transform_signals(signal_file_paths, SAVE_DIR, storage_account_name=storage_account_name, credential=credential)
