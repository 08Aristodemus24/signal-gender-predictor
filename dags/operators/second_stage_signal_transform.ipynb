# %%
import os
import pyarrow as pa
import pyarrow.parquet as pq
import pyarrowfs_adlgen2 as pa_adl
import pyarrow.dataset as ds
import numpy as np
import librosa
import duckdb
import matplotlib.pyplot as plt
import re
import random

from scipy.stats import kurtosis as kurt, skew, entropy, mode
from dotenv import load_dotenv
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor

from azure.identity import DefaultAzureCredential, ClientSecretCredential
from azure.storage.filedatalake import DataLakeServiceClient
from azure.keyvault.secrets import SecretClient
from azure.core.exceptions import ResourceNotFoundError

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# local
DATA_DIR = "../../include/data"

# %%
# # cloud
# # URL = "abfss://{FOLDER_NAME}@sgppipelinesa.dfs.core.windows.net"
# URL = "{FOLDER_NAME}"
# SILVER_FOLDER_NAME = "sgppipelinesa-silver"
# SUB_FOLDER_NAME = "stage-01"
# SILVER_DATA_DIR = os.path.join(URL, "{SUB_FOLDER_NAME}").replace("\\", "/")
# SILVER_DATA_DIR

# local
SILVER_FOLDER_NAME = "silver"
SUB_FOLDER_NAME = "stage-01"
SILVER_DATA_DIR = os.path.join("{DATA_DIR}", "{FOLDER_NAME}", "{SUB_FOLDER_NAME}").replace("\\", "/")
SILVER_DATA_DIR
# Out:
# '{DATA_DIR}/{FOLDER_NAME}/{SUB_FOLDER_NAME}'

# %% [markdown]
# # Computing features for a single subjects audio signals
# this is to familiarize what exact features we need to compute for all other subjects audio signals

# %%
# anonymous-20080904-qzg_signals
# _caustic_-20170306-smy_signals
subject_table = pq.read_table(
    os.path.join(
        SILVER_DATA_DIR.format(
            DATA_DIR=DATA_DIR,
            FOLDER_NAME=SILVER_FOLDER_NAME,
            SUB_FOLDER_NAME=SUB_FOLDER_NAME
        ), 
        "1028-20100710-hne/ar-01.parquet"
    )
)
subject_table
# Out:
# pyarrow.Table
# signals: float
# subject_id: string
# file_row_number: int64
# file_name: string
# loaded_at: timestamp[us]
# ----
# signals: [[-0.013122559,-0.013031006,-0.012817383,-0.012481689,-0.0121154785,...,-0.00036621094,-0.00045776367,-0.000030517578,-0.00048828125,-0.00079345703]]
# subject_id: [["1028-20100710-hne","1028-20100710-hne","1028-20100710-hne","1028-20100710-hne","1028-20100710-hne",...,"1028-20100710-hne","1028-20100710-hne","1028-20100710-hne","1028-20100710-hne","1028-20100710-hne"]]
# file_row_number: [[0,1,2,3,4,...,63483,63484,63485,63486,63487]]
# file_name: [["https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav","https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav","https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav","https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav","https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav",...,"https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav","https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav","https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav","https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav","https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav"]]
# loaded_at: [[2026-03-31 17:12:01.965807,2026-03-31 17:12:01.965807,2026-03-31 17:12:01.965807,2026-03-31 17:12:01.965807,2026-03-31 17:12:01.965807,...,2026-03-31 17:12:01.965807,2026-03-31 17:12:01.965807,2026-03-31 17:12:01.965807,2026-03-31 17:12:01.965807,2026-03-31 17:12:01.965807]]

# %%
# connect to an in-memory database
conn = duckdb.connect()

# %%
conn.sql("""
    SELECT COUNT(*) FROM subject_table
""")
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │        63488 │
# └──────────────┘

# %%
# hertz
hertz = 16000
window_time = 3
hop_time = 1

# we calculate the window size of each segment or the
# amount of samples it has to have based on the frequency
samples_per_win_size = int(window_time * hertz)
samples_per_hop_size = int(hop_time * hertz)

# %% [markdown]
# # Computing statistical features

# %%
conn.sql(f"""
    CREATE OR REPLACE TEMPORARY TABLE subject_features AS (
        SELECT
            subject_id, 
            signals, 
            file_row_number,
            file_name,
            loaded_at,
            
            KURTOSIS(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_kurt,
            SKEWNESS(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_skew,
            ENTROPY(signals)OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_entropy,
            AVG(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_mean,
            MEDIAN(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_median,
            MODE(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_mode,
            MIN(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_min,
            MAX(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_max,
            VAR_SAMP(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_var,
            STDDEV_SAMP(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_stddev,
            QUANTILE_CONT(signals, 0.25) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_first_quart,
            QUANTILE_CONT(signals, 0.75) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_third_quart
        FROM subject_table
        WHERE (file_row_number % {samples_per_hop_size}) = 0
        ORDER BY file_row_number
    )
""")

# %%
conn.sql("""
    CREATE OR REPLACE TEMPORARY TABLE subject_features AS (
        SELECT 
            *,
            (freq_max - freq_min) AS freq_range,
            (freq_third_quart - freq_first_quart) AS freq_inter_quart_range
        FROM subject_features
    )
""")

# %%
conn.sql("""
    SELECT * FROM subject_features
""")
# Out:
# ┌───────────────────┬───────────────┬─────────────────┬─────────────────────────────────────────────────────────────────────────────────────────────────┬────────────────────────────┬────────────────────┬─────────────────────┬────────────────────┬────────────────────┬───────────────┬───────────────┬───────────────┬──────────────┬────────────────────────┬───────────────────────┬──────────────────┬──────────────────┬──────────────┬────────────────────────┐
# │    subject_id     │    signals    │ file_row_number │                                            file_name                                            │         loaded_at          │     freq_kurt      │      freq_skew      │    freq_entropy    │     freq_mean      │  freq_median  │   freq_mode   │   freq_min    │   freq_max   │        freq_var        │      freq_stddev      │ freq_first_quart │ freq_third_quart │  freq_range  │ freq_inter_quart_range │
# │      varchar      │     float     │      int64      │                                             varchar                                             │         timestamp          │       double       │       double        │       double       │       double       │     float     │     float     │     float     │    float     │         double         │        double         │      float       │      float       │    float     │         float          │
# ├───────────────────┼───────────────┼─────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────┼────────────────────┼─────────────────────┼────────────────────┼────────────────────┼───────────────┼───────────────┼───────────────┼──────────────┼────────────────────────┼───────────────────────┼──────────────────┼──────────────────┼──────────────┼────────────────────────┤
# │ 1028-20100710-hne │  -0.013122559 │               0 │ https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav │ 2026-03-31 17:12:01.965807 │ 3.1151970942264215 │ -1.6518507505141513 │                2.0 │ -0.003692626953125 │ -0.0016326904 │  -0.013122559 │  -0.013122559 │ 0.0016174316 │  4.187040030956268e-05 │  0.006470734139922817 │    -0.0045394897 │   -0.00078582764 │   0.01473999 │            0.003753662 │
# │ 1028-20100710-hne │ -0.0016784668 │           16000 │ https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav │ 2026-03-31 17:12:01.965807 │               NULL │  1.7274162139091893 │ 1.5849625007211559 │  -0.00054931640625 │ -0.0015869141 │ -0.0016784668 │ -0.0016784668 │ 0.0016174316 │ 3.5231932997703552e-06 │ 0.0018770171282570533 │    -0.0016326904 │    1.5258789e-05 │ 0.0032958984 │           0.0016479492 │
# │ 1028-20100710-hne │ -0.0015869141 │           32000 │ https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav │ 2026-03-31 17:12:01.965807 │               NULL │                NULL │                1.0 │  1.52587890625e-05 │ 1.5258789e-05 │ -0.0015869141 │ -0.0015869141 │ 0.0016174316 │  5.133915692567825e-06 │ 0.0022658145759456632 │   -0.00078582764 │     0.0008163452 │ 0.0032043457 │           0.0016021729 │
# │ 1028-20100710-hne │  0.0016174316 │           48000 │ https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav │ 2026-03-31 17:12:01.965807 │               NULL │                NULL │                0.0 │  0.001617431640625 │  0.0016174316 │  0.0016174316 │  0.0016174316 │ 0.0016174316 │                   NULL │                  NULL │     0.0016174316 │     0.0016174316 │          0.0 │                    0.0 │
# └───────────────────┴───────────────┴─────────────────┴─────────────────────────────────────────────────────────────────────────────────────────────────┴────────────────────────────┴────────────────────┴─────────────────────┴────────────────────┴────────────────────┴───────────────┴───────────────┴───────────────┴──────────────┴────────────────────────┴───────────────────────┴──────────────────┴──────────────────┴──────────────┴────────────────────────┘

# %% [markdown]
# #### 544000 + a window of 48000 is 592000 which is greater 553472 so we consider only the indeces 544000 to 553471 which is just 9471 rows of data for this last window

# %%
# conn.sql("""
#     SELECT COUNT(*) FROM subject_table
# """)

# %% [markdown]
# # imputing missing or null values created from feature engineering

# %%
# conn.sql("""
#     SELECT 
#         COALESCE(
#             freq_kurt, 
#             (SELECT AVG(freq_kurt) FROM subject_features)
#         ) AS freq_kurt_imp,
#         COALESCE(
#             freq_skew, 
#             (SELECT AVG(freq_skew) FROM subject_features)
#         ) AS freq_skew_imp,
#         COALESCE(
#             freq_entropy, 
#             (SELECT AVG(freq_entropy) FROM subject_features)
#         ) AS freq_entropy_imp
#     FROM subject_features
# """)

# %% [markdown]
# # Computing spectral features

# %%
# frames = conn.sql("""
#     SELECT COUNT(rowId) FROM subject_features
# """).fetchall()[-1][-1]

# %%
# frames

# %%
# time = librosa.frames_to_time(frames, sr=hertz, hop_length=samples_per_hop_size)
# time

# %%
# subject_table["signals"].to_numpy()

# %%
# x_signals = subject_table["signals"].to_numpy()
# x_signals

# %%
# # calculate other features
# zcr = librosa.feature.zero_crossing_rate(y=x_signals, frame_length=samples_per_win_size, hop_length=samples_per_hop_size)
# zcr

# %%
# zcr.shape[1]

# %%
# new_zcr = zcr.reshape(-1)
# new_zcr.shape

# %%
# view_signal_feature(new_zcr, "zero crossing rate")

# %% [markdown]
# #### sometimes the calculation of spectral features may lead to 1 or more data points being added when compared to the length of the number of statistical features computed based on window length and hop length. To make sure number of values of statistical features and spectral features are the same we get only the first n rows of this spectral features based solely on the number of rows of the statistical features e.g. if there are 35 successfully calculated statistical features and we have 36 calculated spectral features we only get the first 35 of the spectral features and discard the rest

# %%
# zcr_n_values_to_rem = np.abs(zcr.shape[1] - time)
# zcr_n_values_to_rem.astype(int)

# %%
# # get slice of those in range with time only
# new_zcr = zcr.reshape(-1)[:frames]
# new_zcr.shape

# %%
# new_zcr.shape

# %%
# # these are 2 features all in all we don't need to aggregate it
# # into a (1, 35) array
# poly_feats = librosa.feature.poly_features(y=x_signals, sr=hertz, n_fft=samples_per_win_size, hop_length=samples_per_hop_size)
# poly_feats.shape

# %%
# new_poly_feats = poly_feats[:, :frames]
# new_poly_feats.shape

# %%
# # y is the audio signals we must pass
# # sr is the sampling rate of our audio signals
# # n_fft is the window size of the fast fourier transform
# # hop_length is number of samples between successive frames
# # n_mels is the number of Mel bands to generate
# mel_spec = librosa.feature.melspectrogram(y=x_signals, sr=hertz, n_fft=samples_per_win_size, hop_length=samples_per_hop_size, n_mels=90)
# mel_spec.shape

# %%
# mel_spec_mean, \
# mel_spec_median, \
# mel_spec_mode, \
# mel_spec_mode_cnt, \
# mel_spec_min, \
# mel_spec_max, \
# mel_spec_range, \
# mel_spec_var, \
# mel_spec_std, \
# mel_spec_first_quart, \
# mel_spec_third_quart, \
# mel_spec_inter_quart_range, \
# mel_spec_entropy, \
# mel_spec_kurt, \
# mel_spec_skew = extract_spectogam_stats(mel_spec)

# %%
# mel_spec_mode

# %%
# mel_spec_mean.shape, mel_spec_median.shape, mel_spec_mode.shape

# %%
# mel_spec_entropy.shape, mel_spec_kurt.shape, mel_spec_skew.shape

# %%
# librosa.display.specshow(mel_spec)

# %%
# mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
# mel_spec_db

# %%
# mel_spec_db_mean, \
# mel_spec_db_median, \
# mel_spec_db_mode, \
# mel_spec_db_mode_cnt, \
# mel_spec_db_min, \
# mel_spec_db_max, \
# mel_spec_db_range, \
# mel_spec_db_var, \
# mel_spec_db_std, \
# mel_spec_db_first_quart, \
# mel_spec_db_third_quart, \
# mel_spec_db_inter_quart_range, \
# mel_spec_db_entropy, \
# mel_spec_db_kurt, \
# mel_spec_db_skew = extract_spectogam_stats(mel_spec_db)

# %%
# librosa.display.specshow(mel_spec_db)

# %%
# spec_cent = librosa.feature.spectral_centroid(y=x_signals, sr=hertz, n_fft=samples_per_win_size, hop_length=samples_per_hop_size)
# spec_cent.shape

# %%
# new_spec_cent = spec_cent.reshape(-1)
# new_spec_cent.shape

# %%
# view_signal_feature(new_spec_cent, "spectral centroid")

# %%
# mfcc = librosa.feature.mfcc(y=x_signals, sr=hertz, n_fft=samples_per_win_size, hop_length=samples_per_hop_size, n_mfcc=90)
# mfcc.shape

# %%
# mfcc_mean, \
# mfcc_median, \
# mfcc_mode, \
# mfcc_mode_cnt, \
# mfcc_min, \
# mfcc_max, \
# mfcc_range, \
# mfcc_var, \
# mfcc_std, \
# mfcc_first_quart, \
# mfcc_third_quart, \
# mfcc_inter_quart_range, \
# mfcc_entropy, \
# mfcc_kurt, \
# mfcc_skew = extract_spectogam_stats(mfcc)

# %%
# librosa.display.specshow(mfcc)

# %%
# spec_bw = librosa.feature.spectral_bandwidth(y=x_signals, sr=hertz, n_fft=samples_per_win_size, hop_length=samples_per_hop_size)
# spec_bw.shape

# %%
# new_spec_bw = spec_bw.reshape(-1)
# new_spec_bw.shape

# %%
# view_signal_feature(new_spec_bw, "spectral bandwidth")

# %%
# spec_cont = librosa.feature.spectral_contrast(y=x_signals, sr=hertz, n_fft=samples_per_win_size, hop_length=samples_per_hop_size)
# spec_cont.shape

# %%
# spec_cont_mean, \
# spec_cont_median, \
# spec_cont_mode, \
# spec_cont_mode_cnt, \
# spec_cont_min, \
# spec_cont_max, \
# spec_cont_range, \
# spec_cont_var, \
# spec_cont_std, \
# spec_cont_first_quart, \
# spec_cont_third_quart, \
# spec_cont_inter_quart_range, \
# spec_cont_entropy, \
# spec_cont_kurt, \
# spec_cont_skew = extract_spectogam_stats(spec_cont)

# %%
# librosa.display.specshow(spec_cont)

# %%
# spec_flat = librosa.feature.spectral_flatness(y=x_signals, n_fft=samples_per_win_size, hop_length=samples_per_hop_size)
# spec_flat.shape

# %%
# new_spec_flat = spec_flat.reshape(-1)
# new_spec_flat.shape

# %%
# view_signal_feature(new_spec_flat, "spectral flatness")

# %%
# spec_roll = librosa.feature.spectral_rolloff(y=x_signals, sr=hertz, n_fft=samples_per_win_size, hop_length=samples_per_hop_size)
# spec_roll.shape

# %%
# new_spec_roll = spec_roll.reshape(-1)
# new_spec_roll.shape

# %%
# view_signal_feature(new_spec_roll, "spectral rolloff")

# %%
# subject_features = conn.sql("""
#     SELECT * FROM subject_features
# """).to_arrow_table()

# %%
# subject_features

# %%
# subject_features = subject_features.append_column("zcr", [new_zcr])
# subject_features = subject_features.append_column("poly_feat_1", [poly_feats[0, :]])
# subject_features = subject_features.append_column("poly_feat_2", [poly_feats[1, :]])
# subject_features = subject_features.append_column("spec_cent", [new_spec_cent])
# subject_features = subject_features.append_column("spec_bw", [new_spec_bw])
# subject_features = subject_features.append_column("spec_flat", [new_spec_flat])
# subject_features = subject_features.append_column("spec_roll", [new_spec_roll])

# subject_features = subject_features.append_column("mel_spec_mean", [mel_spec_mean])
# subject_features = subject_features.append_column("mel_spec_median", [mel_spec_median])
# subject_features = subject_features.append_column("mel_spec_mode", [mel_spec_mode])
# subject_features = subject_features.append_column("mel_spec_mode_cnt", [mel_spec_mode_cnt])
# subject_features = subject_features.append_column("mel_spec_min", [mel_spec_min])
# subject_features = subject_features.append_column("mel_spec_max", [mel_spec_max])
# subject_features = subject_features.append_column("mel_spec_range", [mel_spec_range])
# subject_features = subject_features.append_column("mel_spec_var", [mel_spec_var])
# subject_features = subject_features.append_column("mel_spec_std", [mel_spec_std])
# subject_features = subject_features.append_column("mel_spec_first_quart", [mel_spec_first_quart])
# subject_features = subject_features.append_column("mel_spec_third_quart", [mel_spec_third_quart])
# subject_features = subject_features.append_column("mel_spec_inter_quart_range", [mel_spec_inter_quart_range])
# subject_features = subject_features.append_column("mel_spec_entropy", [mel_spec_entropy])
# subject_features = subject_features.append_column("mel_spec_kurt", [mel_spec_kurt])
# subject_features = subject_features.append_column("mel_spec_skew", [mel_spec_skew])

# subject_features = subject_features.append_column("mel_spec_db_mean", [mel_spec_db_mean])
# subject_features = subject_features.append_column("mel_spec_db_median", [mel_spec_db_median])
# subject_features = subject_features.append_column("mel_spec_db_mode", [mel_spec_db_mode])
# subject_features = subject_features.append_column("mel_spec_db_mode_cnt", [mel_spec_db_mode_cnt])
# subject_features = subject_features.append_column("mel_spec_db_min", [mel_spec_db_min])
# subject_features = subject_features.append_column("mel_spec_db_max", [mel_spec_db_max])
# subject_features = subject_features.append_column("mel_spec_db_range", [mel_spec_db_range])
# subject_features = subject_features.append_column("mel_spec_db_var", [mel_spec_db_var])
# subject_features = subject_features.append_column("mel_spec_db_std", [mel_spec_db_std])
# subject_features = subject_features.append_column("mel_spec_db_first_quart", [mel_spec_db_first_quart])
# subject_features = subject_features.append_column("mel_spec_db_third_quart", [mel_spec_db_third_quart])
# subject_features = subject_features.append_column("mel_spec_db_inter_quart_range", [mel_spec_db_inter_quart_range])
# subject_features = subject_features.append_column("mel_spec_db_entropy", [mel_spec_db_entropy])
# subject_features = subject_features.append_column("mel_spec_db_kurt", [mel_spec_db_kurt])
# subject_features = subject_features.append_column("mel_spec_db_skew", [mel_spec_db_skew])

# subject_features = subject_features.append_column("mfcc_mean", [mfcc_mean])
# subject_features = subject_features.append_column("mfcc_median", [mfcc_median])
# subject_features = subject_features.append_column("mfcc_mode", [mfcc_mode])
# subject_features = subject_features.append_column("mfcc_mode_cnt", [mfcc_mode_cnt])
# subject_features = subject_features.append_column("mfcc_min", [mfcc_min])
# subject_features = subject_features.append_column("mfcc_max", [mfcc_max])
# subject_features = subject_features.append_column("mfcc_range", [mfcc_range])
# subject_features = subject_features.append_column("mfcc_var", [mfcc_var])
# subject_features = subject_features.append_column("mfcc_std", [mfcc_std])
# subject_features = subject_features.append_column("mfcc_first_quart", [mfcc_first_quart])
# subject_features = subject_features.append_column("mfcc_third_quart", [mfcc_third_quart])
# subject_features = subject_features.append_column("mfcc_inter_quart_range", [mfcc_inter_quart_range])
# subject_features = subject_features.append_column("mfcc_entropy", [mfcc_entropy])
# subject_features = subject_features.append_column("mfcc_kurt", [mfcc_kurt])
# subject_features = subject_features.append_column("mfcc_skew", [mfcc_skew])

# subject_features = subject_features.append_column("spec_cont_mean", [spec_cont_mean])
# subject_features = subject_features.append_column("spec_cont_median", [spec_cont_median])
# subject_features = subject_features.append_column("spec_cont_mode", [spec_cont_mode])
# subject_features = subject_features.append_column("spec_cont_mode_cnt", [spec_cont_mode_cnt])
# subject_features = subject_features.append_column("spec_cont_min", [spec_cont_min])
# subject_features = subject_features.append_column("spec_cont_max", [spec_cont_max])
# subject_features = subject_features.append_column("spec_cont_range", [spec_cont_range])
# subject_features = subject_features.append_column("spec_cont_var", [spec_cont_var])
# subject_features = subject_features.append_column("spec_cont_std", [spec_cont_std])
# subject_features = subject_features.append_column("spec_cont_first_quart", [spec_cont_first_quart])
# subject_features = subject_features.append_column("spec_cont_third_quart", [spec_cont_third_quart])
# subject_features = subject_features.append_column("spec_cont_inter_quart_range", [spec_cont_inter_quart_range])
# subject_features = subject_features.append_column("spec_cont_entropy", [spec_cont_entropy])
# subject_features = subject_features.append_column("spec_cont_kurt", [spec_cont_kurt])
# subject_features = subject_features.append_column("spec_cont_skew", [spec_cont_skew])

# %%
# subject_features

# %%
# subject_features.shape

# %% [markdown]
# # We have computed more than enough features we need, now we will load all of the subjects audio signal parquet files into one giant table

# %%
# local
signal_file_paths = [
    str(signal_file_path).replace("\\", "/") for signal_file_path in Path(
        SILVER_DATA_DIR.format(
            DATA_DIR=DATA_DIR,
            FOLDER_NAME=SILVER_FOLDER_NAME,
            SUB_FOLDER_NAME=SUB_FOLDER_NAME
        )
    ).rglob('*')  
    if signal_file_path.is_file() and "labels" not in str(signal_file_path)
]
signal_file_paths
# Out:
# ['../../include/data/silver/stage-01/1028-20100710-hne/ar-01.parquet',
#  '../../include/data/silver/stage-01/1028-20100710-hne/ar-02.parquet',
#  '../../include/data/silver/stage-01/1028-20100710-hne/ar-03.parquet',
#  '../../include/data/silver/stage-01/1028-20100710-hne/ar-04.parquet',
#  '../../include/data/silver/stage-01/1028-20100710-hne/ar-05.parquet',
#  '../../include/data/silver/stage-01/1028-20100710-hne/ar-06.parquet',
#  '../../include/data/silver/stage-01/1028-20100710-hne/ar-07.parquet',
#  '../../include/data/silver/stage-01/1028-20100710-hne/rp-29.parquet',
#  '../../include/data/silver/stage-01/1028-20100710-hne/rp-30.parquet',
#  '../../include/data/silver/stage-01/1028-20100710-hne/rp-31.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-ajg/en-0532.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-ajg/en-0533.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-ajg/en-0534.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-ajg/en-0535.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-ajg/en-0536.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-ajg/en-0537.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-ajg/en-0538.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-ajg/en-0539.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-ajg/en-0540.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-ajg/en-0541.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0726.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0727.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0728.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0729.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0730.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0731.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0732.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0733.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0734.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0735.parquet',
#  '../../include/data/silver/stage-01/1snoke-20120412-hge/a0405.parquet',
#  '../../include/data/silver/stage-01/1snoke-20120412-hge/a0406.parquet',
#  '../../include/data/silver/stage-01/1snoke-20120412-hge/a0407.parquet',
#  '../../include/data/silver/stage-01/1snoke-20120412-hge/a0408.parquet',
#  '../../include/data/silver/stage-01/1snoke-20120412-hge/a0409.parquet',
#  '../../include/data/silver/stage-01/1snoke-20120412-hge/a0410.parquet',
#  '../../include/data/silver/stage-01/1snoke-20120412-hge/a0411.parquet',
#  '../../include/data/silver/stage-01/1snoke-20120412-hge/a0412.parquet',
#  '../../include/data/silver/stage-01/1snoke-20120412-hge/a0413.parquet',
#  '../../include/data/silver/stage-01/1snoke-20120412-hge/a0414.parquet',
#  '../../include/data/silver/stage-01/23yipikaye-20100807-ujm/b0312.parquet',
#  '../../include/data/silver/stage-01/23yipikaye-20100807-ujm/b0313.parquet',
#  '../../include/data/silver/stage-01/23yipikaye-20100807-ujm/b0314.parquet',
#  '../../include/data/silver/stage-01/23yipikaye-20100807-ujm/b0315.parquet',
#  '../../include/data/silver/stage-01/23yipikaye-20100807-ujm/b0316.parquet',
#  '../../include/data/silver/stage-01/23yipikaye-20100807-ujm/b0317.parquet',
#  '../../include/data/silver/stage-01/23yipikaye-20100807-ujm/b0318.parquet',
#  '../../include/data/silver/stage-01/23yipikaye-20100807-ujm/b0319.parquet',
#  '../../include/data/silver/stage-01/23yipikaye-20100807-ujm/b0320.parquet',
#  '../../include/data/silver/stage-01/23yipikaye-20100807-ujm/b0321.parquet',
#  '../../include/data/silver/stage-01/Aaron-20080318-kdl/b0019.parquet',
#  '../../include/data/silver/stage-01/Aaron-20080318-kdl/b0020.parquet',
#  '../../include/data/silver/stage-01/Aaron-20080318-kdl/b0021.parquet',
#  '../../include/data/silver/stage-01/Aaron-20080318-kdl/b0022.parquet',
#  '../../include/data/silver/stage-01/Aaron-20080318-kdl/b0023.parquet',
#  '../../include/data/silver/stage-01/Aaron-20080318-kdl/b0024.parquet',
#  '../../include/data/silver/stage-01/Aaron-20080318-kdl/b0025.parquet',
#  '../../include/data/silver/stage-01/Aaron-20080318-kdl/b0026.parquet',
#  '../../include/data/silver/stage-01/Aaron-20080318-kdl/b0027.parquet',
#  '../../include/data/silver/stage-01/Aaron-20080318-kdl/b0028.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-bft/rb-04.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-bft/rb-05.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-bft/rb-06.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-bft/rb-07.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-bft/rb-08.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-bft/rb-09.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-bft/rb-10.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-bft/rb-11.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-bft/rb-12.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-bft/rb-13.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-cqj/a0116.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-cqj/a0117.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-cqj/a0118.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-cqj/a0119.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-cqj/a0120.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-cqj/a0121.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-cqj/a0122.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-cqj/a0123.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-cqj/a0124.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-cqj/a0125.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-fcp/a0059.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-fcp/a0060.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-fcp/a0061.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-fcp/a0062.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-fcp/a0063.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-fcp/a0064.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-fcp/a0065.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-fcp/a0066.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-fcp/a0067.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-fcp/a0068.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-hns/a0282.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-hns/a0283.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-hns/a0284.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-hns/a0285.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-hns/a0286.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-hns/a0287.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-hns/a0288.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-hns/a0289.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-hns/a0290.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-hns/a0291.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-nky/b0069.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-nky/b0070.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-nky/b0071.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-nky/b0072.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-nky/b0073.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-nky/b0074.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-nky/b0075.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-nky/b0076.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-nky/b0077.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-nky/b0078.parquet',
#  '../../include/data/silver/stage-01/Coren-20141121-pxp/b0467.parquet',
#  '../../include/data/silver/stage-01/Coren-20141121-pxp/b0468.parquet',
#  '../../include/data/silver/stage-01/Coren-20141121-pxp/b0469.parquet',
#  '../../include/data/silver/stage-01/Coren-20141121-pxp/b0470.parquet',
#  '../../include/data/silver/stage-01/Coren-20141121-pxp/b0471.parquet',
#  '../../include/data/silver/stage-01/Coren-20141121-pxp/b0472.parquet',
#  '../../include/data/silver/stage-01/Coren-20141121-pxp/b0473.parquet',
#  '../../include/data/silver/stage-01/Coren-20141121-pxp/b0474.parquet',
#  '../../include/data/silver/stage-01/Coren-20141121-pxp/b0475.parquet',
#  '../../include/data/silver/stage-01/Coren-20141121-pxp/b0476.parquet']

# %%
# Retrieve credentials from environment variables
# this is strictly used only in development
# load env variables
env_dir = Path('../../').resolve()
load_dotenv(os.path.join(env_dir, '.env'))
# Out:
# True

# %%
storage_account_name = os.environ.get("STORAGE_ACCOUNT_NAME")
credential = os.environ.get("STORAGE_ACCOUNT_KEY")
conn_str = os.environ.get("STORAGE_ACCOUNT_CONN_STR")

# %%
SILVER_DATA_DIR
# Out:
# '{DATA_DIR}/{FOLDER_NAME}/{SUB_FOLDER_NAME}'

# %%
# cloud
# create client with generated sas token
datalake_service_client = DataLakeServiceClient(
    account_url=f"https://{storage_account_name}.dfs.core.windows.net", 
    credential=credential
)

# retrieves file system client/container client 
# to retrieve datalake client
silver_container_client = datalake_service_client.get_file_system_client(f"{storage_account_name}-silver")

# we only get the directories in the first level of 
# the container, if it has a "/" then it means it is not
# an immediate folder in the container. This only really
# gets the subject folders 
signal_file_paths = [
    os.path.join(
        SILVER_FOLDER_NAME,
        path.name
    ).replace("\\", "/") 
    for path in silver_container_client.get_paths(path=SUB_FOLDER_NAME) 
    if (not "labels" in path.name) and (".parquet" in path.name)
]
signal_file_paths

# %% [markdown]
# # Once all paths from silver/stage-01 are extracted get only the ones that don't already exist in the paths silver/stage-02

# %%
subjects_features_paths = [
    str(signal_features_path).replace("\\", "/")
    for signal_features_path in Path(
        SILVER_DATA_DIR.format(
            DATA_DIR=DATA_DIR, 
            FOLDER_NAME=SILVER_FOLDER_NAME, 
            SUB_FOLDER_NAME="stage-02"
        )
    ).rglob("*")
    if signal_features_path.is_file()
]
subjects_features_paths
# Out:
# ['../../include/data/silver/stage-02/1028-20100710-hne/ar-01.parquet',
#  '../../include/data/silver/stage-02/1028-20100710-hne/ar-02.parquet',
#  '../../include/data/silver/stage-02/1028-20100710-hne/ar-03.parquet',
#  '../../include/data/silver/stage-02/1028-20100710-hne/ar-04.parquet',
#  '../../include/data/silver/stage-02/1028-20100710-hne/ar-05.parquet',
#  '../../include/data/silver/stage-02/1028-20100710-hne/ar-06.parquet',
#  '../../include/data/silver/stage-02/1028-20100710-hne/ar-07.parquet',
#  '../../include/data/silver/stage-02/1028-20100710-hne/rp-29.parquet',
#  '../../include/data/silver/stage-02/1028-20100710-hne/rp-30.parquet',
#  '../../include/data/silver/stage-02/1028-20100710-hne/rp-31.parquet',
#  '../../include/data/silver/stage-02/1337ad-20170321-ajg/en-0532.parquet',
#  '../../include/data/silver/stage-02/1337ad-20170321-ajg/en-0533.parquet',
#  '../../include/data/silver/stage-02/1337ad-20170321-ajg/en-0534.parquet',
#  '../../include/data/silver/stage-02/1337ad-20170321-ajg/en-0535.parquet',
#  '../../include/data/silver/stage-02/1337ad-20170321-ajg/en-0536.parquet',
#  '../../include/data/silver/stage-02/1337ad-20170321-ajg/en-0537.parquet',
#  '../../include/data/silver/stage-02/1337ad-20170321-ajg/en-0538.parquet',
#  '../../include/data/silver/stage-02/1337ad-20170321-ajg/en-0539.parquet',
#  '../../include/data/silver/stage-02/1337ad-20170321-ajg/en-0540.parquet',
#  '../../include/data/silver/stage-02/1337ad-20170321-ajg/en-0541.parquet',
#  '../../include/data/silver/stage-02/1337ad-20170321-tkg/en-0726.parquet',
#  '../../include/data/silver/stage-02/1337ad-20170321-tkg/en-0727.parquet',
#  '../../include/data/silver/stage-02/1337ad-20170321-tkg/en-0728.parquet',
#  '../../include/data/silver/stage-02/1337ad-20170321-tkg/en-0729.parquet',
#  '../../include/data/silver/stage-02/1337ad-20170321-tkg/en-0730.parquet',
#  '../../include/data/silver/stage-02/1337ad-20170321-tkg/en-0731.parquet',
#  '../../include/data/silver/stage-02/1337ad-20170321-tkg/en-0732.parquet',
#  '../../include/data/silver/stage-02/1337ad-20170321-tkg/en-0733.parquet',
#  '../../include/data/silver/stage-02/1337ad-20170321-tkg/en-0734.parquet',
#  '../../include/data/silver/stage-02/1337ad-20170321-tkg/en-0735.parquet',
#  '../../include/data/silver/stage-02/1snoke-20120412-hge/a0405.parquet',
#  '../../include/data/silver/stage-02/1snoke-20120412-hge/a0406.parquet',
#  '../../include/data/silver/stage-02/1snoke-20120412-hge/a0407.parquet',
#  '../../include/data/silver/stage-02/1snoke-20120412-hge/a0408.parquet',
#  '../../include/data/silver/stage-02/1snoke-20120412-hge/a0409.parquet',
#  '../../include/data/silver/stage-02/1snoke-20120412-hge/a0410.parquet',
#  '../../include/data/silver/stage-02/1snoke-20120412-hge/a0411.parquet',
#  '../../include/data/silver/stage-02/1snoke-20120412-hge/a0412.parquet',
#  '../../include/data/silver/stage-02/1snoke-20120412-hge/a0413.parquet',
#  '../../include/data/silver/stage-02/1snoke-20120412-hge/a0414.parquet',
#  '../../include/data/silver/stage-02/23yipikaye-20100807-ujm/b0312.parquet',
#  '../../include/data/silver/stage-02/23yipikaye-20100807-ujm/b0313.parquet',
#  '../../include/data/silver/stage-02/23yipikaye-20100807-ujm/b0314.parquet',
#  '../../include/data/silver/stage-02/23yipikaye-20100807-ujm/b0315.parquet',
#  '../../include/data/silver/stage-02/23yipikaye-20100807-ujm/b0316.parquet',
#  '../../include/data/silver/stage-02/23yipikaye-20100807-ujm/b0317.parquet',
#  '../../include/data/silver/stage-02/23yipikaye-20100807-ujm/b0318.parquet',
#  '../../include/data/silver/stage-02/23yipikaye-20100807-ujm/b0319.parquet',
#  '../../include/data/silver/stage-02/23yipikaye-20100807-ujm/b0320.parquet',
#  '../../include/data/silver/stage-02/23yipikaye-20100807-ujm/b0321.parquet',
#  '../../include/data/silver/stage-02/Aaron-20080318-kdl/b0019.parquet',
#  '../../include/data/silver/stage-02/Aaron-20080318-kdl/b0020.parquet',
#  '../../include/data/silver/stage-02/Aaron-20080318-kdl/b0021.parquet',
#  '../../include/data/silver/stage-02/Aaron-20080318-kdl/b0022.parquet',
#  '../../include/data/silver/stage-02/Aaron-20080318-kdl/b0023.parquet',
#  '../../include/data/silver/stage-02/Aaron-20080318-kdl/b0024.parquet',
#  '../../include/data/silver/stage-02/Aaron-20080318-kdl/b0025.parquet',
#  '../../include/data/silver/stage-02/Aaron-20080318-kdl/b0026.parquet',
#  '../../include/data/silver/stage-02/Aaron-20080318-kdl/b0027.parquet',
#  '../../include/data/silver/stage-02/Aaron-20080318-kdl/b0028.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-bft/rb-04.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-bft/rb-05.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-bft/rb-06.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-bft/rb-07.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-bft/rb-08.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-bft/rb-09.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-bft/rb-10.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-bft/rb-11.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-bft/rb-12.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-bft/rb-13.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-cqj/a0116.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-cqj/a0117.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-cqj/a0118.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-cqj/a0119.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-cqj/a0120.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-cqj/a0121.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-cqj/a0122.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-cqj/a0123.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-cqj/a0124.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-cqj/a0125.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-fcp/a0059.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-fcp/a0060.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-fcp/a0061.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-fcp/a0062.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-fcp/a0063.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-fcp/a0064.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-fcp/a0065.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-fcp/a0066.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-fcp/a0067.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-fcp/a0068.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-hns/a0282.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-hns/a0283.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-hns/a0284.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-hns/a0285.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-hns/a0286.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-hns/a0287.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-hns/a0288.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-hns/a0289.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-hns/a0290.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-hns/a0291.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-nky/b0069.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-nky/b0070.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-nky/b0071.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-nky/b0072.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-nky/b0073.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-nky/b0074.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-nky/b0075.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-nky/b0076.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-nky/b0077.parquet',
#  '../../include/data/silver/stage-02/Anniepoo-20140308-nky/b0078.parquet',
#  '../../include/data/silver/stage-02/Coren-20141121-pxp/b0467.parquet',
#  '../../include/data/silver/stage-02/Coren-20141121-pxp/b0468.parquet',
#  '../../include/data/silver/stage-02/Coren-20141121-pxp/b0469.parquet',
#  '../../include/data/silver/stage-02/Coren-20141121-pxp/b0470.parquet',
#  '../../include/data/silver/stage-02/Coren-20141121-pxp/b0471.parquet',
#  '../../include/data/silver/stage-02/Coren-20141121-pxp/b0472.parquet',
#  '../../include/data/silver/stage-02/Coren-20141121-pxp/b0473.parquet',
#  '../../include/data/silver/stage-02/Coren-20141121-pxp/b0474.parquet',
#  '../../include/data/silver/stage-02/Coren-20141121-pxp/b0475.parquet',
#  '../../include/data/silver/stage-02/Coren-20141121-pxp/b0476.parquet']

# %%
def filter_path_to_wavs(prev_stage_path_to_files, next_stage_path_to_files):
    """
    we compare this:
    
    '../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0729.parquet',
    '../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0730.parquet',
    ...
    '../../include/data/silver/stage-01/Coren-20141121-pxp/b0472.parquet',
    '../../include/data/silver/stage-01/Coren-20141121-pxp/b0473.parquet',
    '../../include/data/silver/stage-01/Coren-20141121-pxp/b0474.parquet',
    '../../include/data/silver/stage-01/Coren-20141121-pxp/b0475.parquet',
    '../../include/data/silver/stage-01/Coren-20141121-pxp/b0476.parquet',
    '../../include/data/silver/stage-01/Coren-20141121-pxp/test_signal.parquet',]
    
    to this:
    
    '../../include/data/silver/stage-02/1337ad-20170321-tkg/en-0729.parquet',
    '../../include/data/silver/stage-02/1337ad-20170321-tkg/en-0730.parquet',
    ...
    '../../include/data/silver/stage-02/Coren-20141121-pxp/b0472.parquet',
    '../../include/data/silver/stage-02/Coren-20141121-pxp/b0473.parquet',
    '../../include/data/silver/stage-02/Coren-20141121-pxp/b0474.parquet',
    '../../include/data/silver/stage-02/Coren-20141121-pxp/b0475.parquet',
    '../../include/data/silver/stage-02/Coren-20141121-pxp/b0476.parquet']
    
    but we need to normalize both lists to be just the subject folder and its 
    corresponding root file without the extension, and conversely subject
    folder in the next stage and its corresponding parquet file name 
    without the extension. E.g. 1337ad-20170321-tkg/en-0729.wav becomes
    1337ad-20170321-tkg/en-0729 and 
    ../../include/data/silver/stage-02/1337ad-20170321-tkg/en-0730.parquet 
    becomes 1337ad-20170321-tkg/en-0730
    """
    
    normalized_prev_stage_path_to_files_map = dict(zip(
        prev_stage_path_to_files,
        [
            os.path.join(
                path.split("/")[-2],
                path.split("/")[-1].replace(".parquet", "")
            ).replace("\\", "/")
            for path in prev_stage_path_to_files
        ],
    ))

    normalized_next_stage_path_to_files = [
        os.path.join(
            path.split("/")[-2],
            path.split("/")[-1].replace(".parquet", "")
        ).replace("\\", "/")
        for path in next_stage_path_to_files
    ]
    
    print(normalized_prev_stage_path_to_files_map)
    print(normalized_next_stage_path_to_files[:5])

    return [
        key for key, normalized_path_to_wav in normalized_prev_stage_path_to_files_map.items()
        if normalized_path_to_wav not in normalized_next_stage_path_to_files
    ]

# %%
signal_file_paths_filt = filter_path_to_wavs(signal_file_paths, subjects_features_paths)
signal_file_paths_filt
# Out:
# {'../../include/data/silver/stage-01/1028-20100710-hne/ar-01.parquet': '1028-20100710-hne/ar-01', '../../include/data/silver/stage-01/1028-20100710-hne/ar-02.parquet': '1028-20100710-hne/ar-02', '../../include/data/silver/stage-01/1028-20100710-hne/ar-03.parquet': '1028-20100710-hne/ar-03', '../../include/data/silver/stage-01/1028-20100710-hne/ar-04.parquet': '1028-20100710-hne/ar-04', '../../include/data/silver/stage-01/1028-20100710-hne/ar-05.parquet': '1028-20100710-hne/ar-05', '../../include/data/silver/stage-01/1028-20100710-hne/ar-06.parquet': '1028-20100710-hne/ar-06', '../../include/data/silver/stage-01/1028-20100710-hne/ar-07.parquet': '1028-20100710-hne/ar-07', '../../include/data/silver/stage-01/1028-20100710-hne/rp-29.parquet': '1028-20100710-hne/rp-29', '../../include/data/silver/stage-01/1028-20100710-hne/rp-30.parquet': '1028-20100710-hne/rp-30', '../../include/data/silver/stage-01/1028-20100710-hne/rp-31.parquet': '1028-20100710-hne/rp-31', '../../include/data/silver/stage-01/1337ad-20170321-ajg/en-0532.parquet': '1337ad-20170321-ajg/en-0532', '../../include/data/silver/stage-01/1337ad-20170321-ajg/en-0533.parquet': '1337ad-20170321-ajg/en-0533', '../../include/data/silver/stage-01/1337ad-20170321-ajg/en-0534.parquet': '1337ad-20170321-ajg/en-0534', '../../include/data/silver/stage-01/1337ad-20170321-ajg/en-0535.parquet': '1337ad-20170321-ajg/en-0535', '../../include/data/silver/stage-01/1337ad-20170321-ajg/en-0536.parquet': '1337ad-20170321-ajg/en-0536', '../../include/data/silver/stage-01/1337ad-20170321-ajg/en-0537.parquet': '1337ad-20170321-ajg/en-0537', '../../include/data/silver/stage-01/1337ad-20170321-ajg/en-0538.parquet': '1337ad-20170321-ajg/en-0538', '../../include/data/silver/stage-01/1337ad-20170321-ajg/en-0539.parquet': '1337ad-20170321-ajg/en-0539', '../../include/data/silver/stage-01/1337ad-20170321-ajg/en-0540.parquet': '1337ad-20170321-ajg/en-0540', '../../include/data/silver/stage-01/1337ad-20170321-ajg/en-0541.parquet': '1337ad-20170321-ajg/en-0541', '../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0726.parquet': '1337ad-20170321-tkg/en-0726', '../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0727.parquet': '1337ad-20170321-tkg/en-0727', '../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0728.parquet': '1337ad-20170321-tkg/en-0728', '../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0729.parquet': '1337ad-20170321-tkg/en-0729', '../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0730.parquet': '1337ad-20170321-tkg/en-0730', '../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0731.parquet': '1337ad-20170321-tkg/en-0731', '../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0732.parquet': '1337ad-20170321-tkg/en-0732', '../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0733.parquet': '1337ad-20170321-tkg/en-0733', '../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0734.parquet': '1337ad-20170321-tkg/en-0734', '../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0735.parquet': '1337ad-20170321-tkg/en-0735', '../../include/data/silver/stage-01/1snoke-20120412-hge/a0405.parquet': '1snoke-20120412-hge/a0405', '../../include/data/silver/stage-01/1snoke-20120412-hge/a0406.parquet': '1snoke-20120412-hge/a0406', '../../include/data/silver/stage-01/1snoke-20120412-hge/a0407.parquet': '1snoke-20120412-hge/a0407', '../../include/data/silver/stage-01/1snoke-20120412-hge/a0408.parquet': '1snoke-20120412-hge/a0408', '../../include/data/silver/stage-01/1snoke-20120412-hge/a0409.parquet': '1snoke-20120412-hge/a0409', '../../include/data/silver/stage-01/1snoke-20120412-hge/a0410.parquet': '1snoke-20120412-hge/a0410', '../../include/data/silver/stage-01/1snoke-20120412-hge/a0411.parquet': '1snoke-20120412-hge/a0411', '../../include/data/silver/stage-01/1snoke-20120412-hge/a0412.parquet': '1snoke-20120412-hge/a0412', '../../include/data/silver/stage-01/1snoke-20120412-hge/a0413.parquet': '1snoke-20120412-hge/a0413', '../../include/data/ ...
# ['1028-20100710-hne/ar-01', '1028-20100710-hne/ar-02', '1028-20100710-hne/ar-03', '1028-20100710-hne/ar-04', '1028-20100710-hne/ar-05']
# []

# %%
def align_spectral_features_length(feature, target_len, pad_mode='edge'):
    """
    Aligns audio features to a target length along the time axis (axis 1).
    Works for 2D arrays like MFCC (n_mfcc, n_frames) or ZCR (1, n_frames).
    """
    curr_len = feature.shape[1]
    
    if curr_len < target_len:
        # Calculate how many frames are missing
        pad_width = target_len - curr_len
        # np.pad(array, ((top, bottom), (left, right)), mode)
        # We only want to pad the 'right' side of the second axis
        # >>> import numpy as np
        # >>>
        # >>> test = np.array([
        # ...     [1, 2, 3],
        # ...     [4,5, 6],
        # ... ])
        # >>>
        # >>> pad_width = 5
        # >>> padded_test = np.pad(test, ((0, 0), (0, pad_width)), mode='edge')
        # >>> padded_test
        # array([[1, 2, 3, 3, 3, 3, 3, 3],
        #     [4, 5, 6, 6, 6, 6, 6, 6]])
        padded_feature = np.pad(feature, ((0, 0), (0, pad_width)), mode=pad_mode)
        return padded_feature
    
    elif curr_len > target_len:
        # If librosa gave us an extra frame, trim it back which 
        # is equivalent to the ff:
        # zcr_n_values_to_rem = np.abs(zcr.shape[1] - time.shape[0])
        # zcr = zcr.reshape(-1)[:-zcr_n_values_to_rem]
        return feature[:, :target_len]
    
    return feature

def extract_spectrogram_stats(spectrogram):
    """
    extracts statistical features of mel frequency ceptstral 
    coefficients, mel spectrogram, mel decibel spectrogram,
    spectral contrast spectrogram matrices along the the x-axis
    so if a matrix or spectrogram is (90, 35) final array will 
    be (1, 35)
    """

    # central tendency
    spec_mean = np.mean(spectrogram, axis=0)
    spec_median = np.median(spectrogram, axis=0)
    spec_mode = mode(spectrogram, axis=0).mode
    spec_mode_cnt = mode(spectrogram, axis=0).count
    
    # spread
    spec_min = np.min(spectrogram, axis=0)
    spec_max = np.max(spectrogram, axis=0)
    spec_range = spec_max - spec_min
    spec_var = np.var(spectrogram, axis=0)
    spec_std = np.std(spectrogram, axis=0)

    # percentiles
    spec_first_quart = np.percentile(spectrogram, 25, axis=0)
    spec_third_quart = np.percentile(spectrogram, 75, axis=0)
    spec_inter_quart_range  = spec_third_quart - spec_first_quart

    # morphology
    spec_entropy = entropy(spectrogram, axis=0)
    spec_kurt = kurt(spectrogram, axis=0)
    spec_skew = skew(spectrogram, axis=0)

    return (
        spec_mean, 
        spec_median, 
        spec_mode, 
        spec_mode_cnt, 
        spec_min, 
        spec_max, 
        spec_range, 
        spec_var, 
        spec_std, 
        spec_first_quart, 
        spec_third_quart, 
        spec_inter_quart_range, 
        spec_entropy, 
        spec_kurt, 
        spec_skew
    )

def compute_statistical_features(
    conn, 
    subject_table, 
    samples_per_win_size, 
    samples_per_hop_size,
):
    print("Computing statistical features...")

    # count = conn.sql("""
    #     SELECT COUNT(rowId) FROM subject_table
    # """).fetchall()[-1][-1]

    conn.sql(f"""
        CREATE OR REPLACE TEMPORARY TABLE subject_features AS (
            SELECT
                subject_id, 
                signals, 
                file_row_number,
                file_name,
                loaded_at,
                
                KURTOSIS(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_kurt,
                SKEWNESS(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_skew,
                ENTROPY(signals)OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_entropy,
                AVG(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_mean,
                MEDIAN(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_median,
                MODE(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_mode,
                MIN(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_min,
                MAX(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_max,
                VAR_SAMP(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_var,
                STDDEV_SAMP(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_stddev,
                QUANTILE_CONT(signals, 0.25) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_first_quart,
                QUANTILE_CONT(signals, 0.75) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_third_quart
            FROM subject_table
            WHERE (file_row_number % {samples_per_hop_size}) = 0
            ORDER BY file_row_number
        )
    """)

    conn.sql(f"""
        CREATE OR REPLACE TEMPORARY TABLE subject_features AS (
            SELECT 
                *,
                (freq_max - freq_min) AS freq_range,
                (freq_third_quart - freq_first_quart) AS freq_inter_quart_range
            FROM subject_features
        )
    """)

    subject_features = conn.sql(f"""
        SELECT * FROM subject_features
    """).to_arrow_table()

    return subject_features

def compute_spectral_features(subject_features, x_signals, hertz, samples_per_win_size, samples_per_hop_size, n_frames):
    """
    computes spectral features of audio signals using
    librosa library
    """
    
    print("Calculating spectral features...")

    # note a center of false still doesn't work to get librosa 
    # feature functions to calculate features the size of our 
    # statistical features so we must use the last value of these 
    # resulting features as padding to match thevlength of our 
    # statistical features. E.g. statiscal feature table has shape
    # (28, 19) and computed librosa feature like zcr has (1, 24)
    # then we have to subtract 28 - 24 = 4 and 4 will be the number
    # of values we need to pad to the zcr feature using this 
    # features last vlue
    zcr = librosa.feature.zero_crossing_rate(
        y=x_signals, 
        frame_length=samples_per_win_size, 
        hop_length=samples_per_hop_size,
    )[:, :n_frames]
    # print(f"ZCR shape: {zcr.shape}")
    zcr = align_spectral_features_length(zcr, n_frames, pad_mode='edge')
    # print(f"ZCR shape: {zcr.shape}")
    # print(zcr[:, zcr.shape[1] - 5:])
    
    poly_feats = librosa.feature.poly_features(
        y=x_signals, 
        sr=hertz, 
        n_fft=samples_per_win_size, 
        hop_length=samples_per_hop_size
    )[:, :n_frames]
    poly_feats = align_spectral_features_length(poly_feats, n_frames, pad_mode='edge')
    # print(f"Poly shape: {poly_feats.shape}")

    mel_spec = librosa.feature.melspectrogram(
        y=x_signals, 
        sr=hertz, 
        n_fft=samples_per_win_size, 
        hop_length=samples_per_hop_size, 
        n_mels=90
    )[:, :n_frames]
    mel_spec = align_spectral_features_length(mel_spec, n_frames, pad_mode='edge')
    mel_spec_mean, \
    mel_spec_median, \
    mel_spec_mode, \
    mel_spec_mode_cnt, \
    mel_spec_min, \
    mel_spec_max, \
    mel_spec_range, \
    mel_spec_var, \
    mel_spec_std, \
    mel_spec_first_quart, \
    mel_spec_third_quart, \
    mel_spec_inter_quart_range, \
    mel_spec_entropy, \
    mel_spec_kurt, \
    mel_spec_skew = extract_spectrogram_stats(mel_spec)
    # print(f"Mel Spectrogram shape: {mel_spec.shape}")

    mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
    mel_spec_db = align_spectral_features_length(mel_spec_db, n_frames, pad_mode='edge')
    mel_spec_db_mean, \
    mel_spec_db_median, \
    mel_spec_db_mode, \
    mel_spec_db_mode_cnt, \
    mel_spec_db_min, \
    mel_spec_db_max, \
    mel_spec_db_range, \
    mel_spec_db_var, \
    mel_spec_db_std, \
    mel_spec_db_first_quart, \
    mel_spec_db_third_quart, \
    mel_spec_db_inter_quart_range, \
    mel_spec_db_entropy, \
    mel_spec_db_kurt, \
    mel_spec_db_skew = extract_spectrogram_stats(mel_spec_db)
    # print(f"Mel Spectrogram DB shape: {mel_spec_db.shape}")

    mfcc = librosa.feature.mfcc(
        y=x_signals, 
        sr=hertz, 
        n_fft=samples_per_win_size, 
        hop_length=samples_per_hop_size, n_mfcc=90
    )[:, :n_frames]
    mfcc = align_spectral_features_length(mfcc, n_frames, pad_mode='edge')
    mfcc_mean, \
    mfcc_median, \
    mfcc_mode, \
    mfcc_mode_cnt, \
    mfcc_min, \
    mfcc_max, \
    mfcc_range, \
    mfcc_var, \
    mfcc_std, \
    mfcc_first_quart, \
    mfcc_third_quart, \
    mfcc_inter_quart_range, \
    mfcc_entropy, \
    mfcc_kurt, \
    mfcc_skew = extract_spectrogram_stats(mfcc)
    # print(f"MFCC shape: {mfcc.shape}")
    
    spec_cont = librosa.feature.spectral_contrast(
        y=x_signals, 
        sr=hertz, 
        n_fft=samples_per_win_size, 
        hop_length=samples_per_hop_size
    )[:, :n_frames]
    spec_cont = align_spectral_features_length(spec_cont, n_frames, pad_mode='edge')
    spec_cont_mean, \
    spec_cont_median, \
    spec_cont_mode, \
    spec_cont_mode_cnt, \
    spec_cont_min, \
    spec_cont_max, \
    spec_cont_range, \
    spec_cont_var, \
    spec_cont_std, \
    spec_cont_first_quart, \
    spec_cont_third_quart, \
    spec_cont_inter_quart_range, \
    spec_cont_entropy, \
    spec_cont_kurt, \
    spec_cont_skew = extract_spectrogram_stats(spec_cont)
    # print(f"spectral contrast shape: {zcr.shape}")

    spec_cent = librosa.feature.spectral_centroid(
        y=x_signals, 
        sr=hertz, 
        n_fft=samples_per_win_size, 
        hop_length=samples_per_hop_size
    )[:, :n_frames]
    spec_cent = align_spectral_features_length(spec_cent, n_frames, pad_mode='edge')
    # print(f"Spectral centroid shape: {spec_cent.shape}")

    spec_bw = librosa.feature.spectral_bandwidth(
        y=x_signals, 
        sr=hertz, 
        n_fft=samples_per_win_size, 
        hop_length=samples_per_hop_size
    )[:, :n_frames]
    spec_bw = align_spectral_features_length(spec_bw, n_frames, pad_mode='edge')
    # print(f"Spectral bandwidth shape: {spec_bw.shape}")

    spec_flat = librosa.feature.spectral_flatness(
        y=x_signals, 
        n_fft=samples_per_win_size, 
        hop_length=samples_per_hop_size
    )[:, :n_frames]
    spec_flat = align_spectral_features_length(spec_flat, n_frames, pad_mode='edge')
    # print(f"Spectral flatness shape: {spec_flat.shape}")

    spec_roll = librosa.feature.spectral_rolloff(
        y=x_signals, 
        sr=hertz, 
        n_fft=samples_per_win_size, 
        hop_length=samples_per_hop_size
    )[:, :n_frames]
    spec_roll = align_spectral_features_length(spec_roll, n_frames, pad_mode='edge')
    # print(f"Spectral rolloff shape: {spec_roll.shape}")

    # add the newly computed spectographic and chromagraphic
    # features as columns
    subject_features = subject_features.append_column("zcr", [zcr.reshape(-1)])
    subject_features = subject_features.append_column("poly_feat_1", [poly_feats[0, :]])
    subject_features = subject_features.append_column("poly_feat_2", [poly_feats[1, :]])
    subject_features = subject_features.append_column("spec_cent", [spec_cent.reshape(-1)])
    subject_features = subject_features.append_column("spec_bw", [spec_bw.reshape(-1)])
    subject_features = subject_features.append_column("spec_flat", [spec_flat.reshape(-1)])
    subject_features = subject_features.append_column("spec_roll", [spec_roll.reshape(-1)])

    subject_features = subject_features.append_column("mel_spec_mean", [mel_spec_mean])
    subject_features = subject_features.append_column("mel_spec_median", [mel_spec_median])
    subject_features = subject_features.append_column("mel_spec_mode", [mel_spec_mode])
    subject_features = subject_features.append_column("mel_spec_mode_cnt", [mel_spec_mode_cnt])
    subject_features = subject_features.append_column("mel_spec_min", [mel_spec_min])
    subject_features = subject_features.append_column("mel_spec_max", [mel_spec_max])
    subject_features = subject_features.append_column("mel_spec_range", [mel_spec_range])
    subject_features = subject_features.append_column("mel_spec_var", [mel_spec_var])
    subject_features = subject_features.append_column("mel_spec_std", [mel_spec_std])
    subject_features = subject_features.append_column("mel_spec_first_quart", [mel_spec_first_quart])
    subject_features = subject_features.append_column("mel_spec_third_quart", [mel_spec_third_quart])
    subject_features = subject_features.append_column("mel_spec_inter_quart_range", [mel_spec_inter_quart_range])
    subject_features = subject_features.append_column("mel_spec_entropy", [mel_spec_entropy])
    subject_features = subject_features.append_column("mel_spec_kurt", [mel_spec_kurt])
    subject_features = subject_features.append_column("mel_spec_skew", [mel_spec_skew])

    subject_features = subject_features.append_column("mel_spec_db_mean", [mel_spec_db_mean])
    subject_features = subject_features.append_column("mel_spec_db_median", [mel_spec_db_median])
    subject_features = subject_features.append_column("mel_spec_db_mode", [mel_spec_db_mode])
    subject_features = subject_features.append_column("mel_spec_db_mode_cnt", [mel_spec_db_mode_cnt])
    subject_features = subject_features.append_column("mel_spec_db_min", [mel_spec_db_min])
    subject_features = subject_features.append_column("mel_spec_db_max", [mel_spec_db_max])
    subject_features = subject_features.append_column("mel_spec_db_range", [mel_spec_db_range])
    subject_features = subject_features.append_column("mel_spec_db_var", [mel_spec_db_var])
    subject_features = subject_features.append_column("mel_spec_db_std", [mel_spec_db_std])
    subject_features = subject_features.append_column("mel_spec_db_first_quart", [mel_spec_db_first_quart])
    subject_features = subject_features.append_column("mel_spec_db_third_quart", [mel_spec_db_third_quart])
    subject_features = subject_features.append_column("mel_spec_db_inter_quart_range", [mel_spec_db_inter_quart_range])
    subject_features = subject_features.append_column("mel_spec_db_entropy", [mel_spec_db_entropy])
    subject_features = subject_features.append_column("mel_spec_db_kurt", [mel_spec_db_kurt])
    subject_features = subject_features.append_column("mel_spec_db_skew", [mel_spec_db_skew])

    subject_features = subject_features.append_column("mfcc_mean", [mfcc_mean])
    subject_features = subject_features.append_column("mfcc_median", [mfcc_median])
    subject_features = subject_features.append_column("mfcc_mode", [mfcc_mode])
    subject_features = subject_features.append_column("mfcc_mode_cnt", [mfcc_mode_cnt])
    subject_features = subject_features.append_column("mfcc_min", [mfcc_min])
    subject_features = subject_features.append_column("mfcc_max", [mfcc_max])
    subject_features = subject_features.append_column("mfcc_range", [mfcc_range])
    subject_features = subject_features.append_column("mfcc_var", [mfcc_var])
    subject_features = subject_features.append_column("mfcc_std", [mfcc_std])
    subject_features = subject_features.append_column("mfcc_first_quart", [mfcc_first_quart])
    subject_features = subject_features.append_column("mfcc_third_quart", [mfcc_third_quart])
    subject_features = subject_features.append_column("mfcc_inter_quart_range", [mfcc_inter_quart_range])
    subject_features = subject_features.append_column("mfcc_entropy", [mfcc_entropy])
    subject_features = subject_features.append_column("mfcc_kurt", [mfcc_kurt])
    subject_features = subject_features.append_column("mfcc_skew", [mfcc_skew])

    subject_features = subject_features.append_column("spec_cont_mean", [spec_cont_mean])
    subject_features = subject_features.append_column("spec_cont_median", [spec_cont_median])
    subject_features = subject_features.append_column("spec_cont_mode", [spec_cont_mode])
    subject_features = subject_features.append_column("spec_cont_mode_cnt", [spec_cont_mode_cnt])
    subject_features = subject_features.append_column("spec_cont_min", [spec_cont_min])
    subject_features = subject_features.append_column("spec_cont_max", [spec_cont_max])
    subject_features = subject_features.append_column("spec_cont_range", [spec_cont_range])
    subject_features = subject_features.append_column("spec_cont_var", [spec_cont_var])
    subject_features = subject_features.append_column("spec_cont_std", [spec_cont_std])
    subject_features = subject_features.append_column("spec_cont_first_quart", [spec_cont_first_quart])
    subject_features = subject_features.append_column("spec_cont_third_quart", [spec_cont_third_quart])
    subject_features = subject_features.append_column("spec_cont_inter_quart_range", [spec_cont_inter_quart_range])
    subject_features = subject_features.append_column("spec_cont_entropy", [spec_cont_entropy])
    subject_features = subject_features.append_column("spec_cont_kurt", [spec_cont_kurt])
    subject_features = subject_features.append_column("spec_cont_skew", [spec_cont_skew])

    return subject_features


def transform_signals(
    signal_file_paths, 
    data_dir, 
    hertz: int=16000, 
    window_time: int=3, 
    hop_time: int=1, 
    storage_account_name: str=None, 
    credential: str=None,
):
    """
    concurrently extracts the features of each signal
    the first half of feature extraction involves using
    sql for computing statistical features of the subjects
    signals

    the second half involves using librosa for computing
    for instance spectral features of the sujects signals
    as there is not supported function to compute audio
    specific signal features like spectrograms, chromagrams,
    tempogram, etc.
    """
    
    # we calculate the window size of each segment or the
    # amount of samples it has to have based on the frequency
    samples_per_win_size = int(window_time * hertz)
    samples_per_hop_size = int(hop_time * hertz)

    # # connect to in memory db
    # conn = duckdb.connect()

    if storage_account_name and credential:
        handler = pa_adl.AccountHandler.from_account_name(storage_account_name, credential=credential)
        fs = pa.fs.PyFileSystem(handler)

    def helper(signal_file_path):
        
        try:
            # connect to in memory db
            conn = duckdb.connect()

            # extract subject name from file path
            subject_id = signal_file_path.split("/")[-2]
            subject_file_id = signal_file_path.split("/")[-1].replace(".parquet", "")
            print(f"Subject {subject_id} with subject file id {subject_file_id} is processing...")

            # read subjects table and it ssignals
            if storage_account_name and credential:
                # cloud
                subject_table = pq.read_table(signal_file_path, filesystem=fs)
                
            else:
                # local reads a path like this
                # '../../include/data/silver/stage-01/1337ad-20170321-ajg/en-0532.parquet'
                subject_table = pq.read_table(signal_file_path)
            
            # apply necessary changes to file name column in subjects 
            # feature table read from file
            subject_table = subject_table.drop_columns(["file_name"])
            subject_file_name_col = pa.array([signal_file_path] * subject_table.shape[0], type=pa.string())
            subject_table = subject_table.append_column("file_name", subject_file_name_col)

            # extract signals from subjects feature table and 
            # convert to numpy array for librosa to compute 
            # spectral features
            x_signals = subject_table["signals"].to_numpy()

            # calculate statistical features
            subject_features = compute_statistical_features(
                conn,
                subject_table, 
                samples_per_win_size, 
                samples_per_hop_size
            )
            print(f"subject statistical features shape: {subject_features.shape}")

            # get the number of frames used using a window of 48000
            # and hop length of 16000
            n_frames = subject_features.shape[0]
            print(f"Number of frames: {n_frames}")

            # compute spectographic and chromagraphic features
            subject_features = compute_spectral_features(
                subject_features, 
                x_signals, 
                hertz, 
                samples_per_win_size, 
                samples_per_hop_size, 
                n_frames
            )
            
            # create dedicated folder of subject containing all
            # its features for each of its signals derived from
            # individual wav file
            # ../../include/data/silver/stage-02 + <subject_id>
            save_dir = os.path.join(data_dir, subject_id).replace("\\", "/")
            
            # create save path
            # ../../include/data/silver/stage-02/<subject_id>/features_0.parquet
            save_path = os.path.join(save_dir, f"{subject_file_id}.parquet").replace("\\", "/")
            
            if storage_account_name and credential:
                pq.write_table(subject_features, save_path, filesystem=fs)
            else:
                # make directory where subject features wil lbe saved
                os.makedirs(save_dir, exist_ok=True)
                
                # write table to a 2nd sub stage in silver staging layer 
                pq.write_table(subject_features, save_path)

        except Exception as e:
            print(f"error {e} occured on subject id {subject_id} and file {subject_file_id}")
            
            # return the last subjects features
            return subject_id, e

    # concurrently calculate statistical features and spectral
    # features of each subject using DuckDB SQL and librosa
    with ThreadPoolExecutor(max_workers=2) as exe:
        subjects_features_list = list(exe.map(helper, signal_file_paths))

    return subjects_features_list

# %%
# local
SAVE_DIR = SILVER_DATA_DIR.format(
    DATA_DIR=DATA_DIR,
    FOLDER_NAME=SILVER_FOLDER_NAME,
    SUB_FOLDER_NAME="stage-02"
)
SAVE_DIR

# # cloud
# SAVE_DIR = SILVER_DATA_DIR.format(
#     FOLDER_NAME=SILVER_FOLDER_NAME,
#     SUB_FOLDER_NAME="stage-02"
# )
# SAVE_DIR
# Out:
# '../../include/data/silver/stage-02'

# %%
signal_file_paths[7:10]
# Out:
# ['../../include/data/silver/stage-01/1028-20100710-hne/rp-29.parquet',
#  '../../include/data/silver/stage-01/1028-20100710-hne/rp-30.parquet',
#  '../../include/data/silver/stage-01/1028-20100710-hne/rp-31.parquet']

# %%
# local
subjects_features = transform_signals(signal_file_paths, SAVE_DIR, storage_account_name=None, credential=None)
# Out:
# Subject 1028-20100710-hne with subject file id ar-01 is processing...
# Subject 1028-20100710-hne with subject file id ar-02 is processing...
# Computing statistical features...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=47616
#   warnings.warn(
# Subject 1028-20100710-hne with subject file id ar-03 is processing...
# Computing statistical features...
# Subject 1028-20100710-hne with subject file id ar-04 is processing...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject 1028-20100710-hne with subject file id ar-05 is processing...
# Subject 1028-20100710-hne with subject file id ar-06 is processing...
# Computing statistical features...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=39424
#   warnings.warn(
# Subject 1028-20100710-hne with subject file id ar-07 is processing...
# Computing statistical features...
# Subject 1028-20100710-hne with subject file id rp-29 is processing...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=43520
#   warnings.warn(
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=44032
#   warnings.warn(
# Subject 1028-20100710-hne with subject file id rp-30 is processing...
# Subject 1028-20100710-hne with subject file id rp-31 is processing...
# Computing statistical features...
# Computing statistical features...
# subject statistical features shape: (5, 19)
# Number of frames: 5
# Calculating spectral features...
# subject statistical features shape: (2, 19)
# Number of frames: 2
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=30208
#   warnings.warn(
# Subject 1337ad-20170321-ajg with subject file id en-0532 is processing...
# Subject 1337ad-20170321-ajg with subject file id en-0533 is processing...
# Computing statistical features...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# subject statistical features shape: (6, 19)
# Number of frames: 6
# Calculating spectral features...
# Subject 1337ad-20170321-ajg with subject file id en-0534 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# Subject 1337ad-20170321-ajg with subject file id en-0535 is processing...
# Computing statistical features...
# subject statistical features shape: (5, 19)
# Number of frames: 5
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=37888
#   warnings.warn(
# Subject 1337ad-20170321-ajg with subject file id en-0536 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject 1337ad-20170321-ajg with subject file id en-0537 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject 1337ad-20170321-ajg with subject file id en-0538 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# Subject 1337ad-20170321-ajg with subject file id en-0539 is processing...
# Computing statistical features...
# subject statistical features shape: (5, 19)
# Number of frames: 5
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=32256
#   warnings.warn(
# Subject 1337ad-20170321-ajg with subject file id en-0540 is processing...
# Computing statistical features...
# subject statistical features shape: (5, 19)
# Number of frames: 5
# Calculating spectral features...
# Subject 1337ad-20170321-ajg with subject file id en-0541 is processing...
# Computing statistical features...
# subject statistical features shape: (5, 19)
# Number of frames: 5
# Calculating spectral features...
# Subject 1337ad-20170321-tkg with subject file id en-0726 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject 1337ad-20170321-tkg with subject file id en-0727 is processing...
# Computing statistical features...
# subject statistical features shape: (5, 19)
# Number of frames: 5
# Calculating spectral features...
# Subject 1337ad-20170321-tkg with subject file id en-0728 is processing...
# Computing statistical features...
# subject statistical features shape: (5, 19)
# Number of frames: 5
# Calculating spectral features...
# Subject 1337ad-20170321-tkg with subject file id en-0729 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject 1337ad-20170321-tkg with subject file id en-0730 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject 1337ad-20170321-tkg with subject file id en-0731 is processing...
# Computing statistical features...
# subject statistical features shape: (2, 19)
# Number of frames: 2
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=31744
#   warnings.warn(
# Subject 1337ad-20170321-tkg with subject file id en-0732 is processing...
# Computing statistical features...
# subject statistical features shape: (2, 19)
# Number of frames: 2
# Calculating spectral features...
# Subject 1337ad-20170321-tkg with subject file id en-0733 is processing...
# Computing statistical features...
# subject statistical features shape: (5, 19)
# Number of frames: 5
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=28672
#   warnings.warn(
# Subject 1337ad-20170321-tkg with subject file id en-0734 is processing...
# Computing statistical features...
# subject statistical features shape: (5, 19)
# Number of frames: 5
# Calculating spectral features...
# Subject 1337ad-20170321-tkg with subject file id en-0735 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject 1snoke-20120412-hge with subject file id a0405 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject 1snoke-20120412-hge with subject file id a0406 is processing...
# Computing statistical features...
# subject statistical features shape: (5, 19)
# Number of frames: 5
# Calculating spectral features...
# Subject 1snoke-20120412-hge with subject file id a0407 is processing...
# Computing statistical features...
# Subject 1snoke-20120412-hge with subject file id a0408 is processing...
# subject statistical features shape: (8, 19)
# Number of frames: 8
# Calculating spectral features...
# Computing statistical features...
# subject statistical features shape: (5, 19)
# Number of frames: 5
# Calculating spectral features...
# Subject 1snoke-20120412-hge with subject file id a0409 is processing...
# Computing statistical features...
# Subject 1snoke-20120412-hge with subject file id a0410 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# subject statistical features shape: (5, 19)
# Number of frames: 5
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=39936
#   warnings.warn(
# Subject 1snoke-20120412-hge with subject file id a0411 is processing...
# Computing statistical features...
# subject statistical features shape: (5, 19)
# Number of frames: 5
# Calculating spectral features...
# Subject 1snoke-20120412-hge with subject file id a0412 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# Subject 1snoke-20120412-hge with subject file id a0413 is processing...
# Subject 1snoke-20120412-hge with subject file id a0414 is processing...
# Computing statistical features...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=34304
#   warnings.warn(
# Subject 23yipikaye-20100807-ujm with subject file id b0312 is processing...
# Computing statistical features...
# Subject 23yipikaye-20100807-ujm with subject file id b0313 is processing...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Computing statistical features...
# subject statistical features shape: (6, 19)
# Number of frames: 6
# Calculating spectral features...
# Subject 23yipikaye-20100807-ujm with subject file id b0314 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# Subject 23yipikaye-20100807-ujm with subject file id b0315 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=34816
#   warnings.warn(
# Subject 23yipikaye-20100807-ujm with subject file id b0316 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject 23yipikaye-20100807-ujm with subject file id b0317 is processing...
# Computing statistical features...
# subject statistical features shape: (5, 19)
# Number of frames: 5
# Calculating spectral features...
# Subject 23yipikaye-20100807-ujm with subject file id b0318 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# Subject 23yipikaye-20100807-ujm with subject file id b0319 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=40448
#   warnings.warn(
# Subject 23yipikaye-20100807-ujm with subject file id b0320 is processing...
# Computing statistical features...
# subject statistical features shape: (5, 19)
# Number of frames: 5
# Calculating spectral features...
# Subject 23yipikaye-20100807-ujm with subject file id b0321 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject Aaron-20080318-kdl with subject file id b0019 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# Subject Aaron-20080318-kdl with subject file id b0020 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=37376
#   warnings.warn(
# Subject Aaron-20080318-kdl with subject file id b0021 is processing...
# Computing statistical features...
# subject statistical features shape: (2, 19)
# Number of frames: 2
# Calculating spectral features...
# Subject Aaron-20080318-kdl with subject file id b0022 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=27136
#   warnings.warn(
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=35840
#   warnings.warn(
# Subject Aaron-20080318-kdl with subject file id b0023 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# Subject Aaron-20080318-kdl with subject file id b0024 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=33792
#   warnings.warn(
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=36352
#   warnings.warn(
# Subject Aaron-20080318-kdl with subject file id b0025 is processing...
# Computing statistical features...
# subject statistical features shape: (2, 19)
# Number of frames: 2
# Calculating spectral features...
# Subject Aaron-20080318-kdl with subject file id b0026 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=22016
#   warnings.warn(
# Subject Aaron-20080318-kdl with subject file id b0027 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# Subject Aaron-20080318-kdl with subject file id b0028 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=45568
#   warnings.warn(
# Subject Anniepoo-20140308-bft with subject file id rb-04 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject Anniepoo-20140308-bft with subject file id rb-05 is processing...
# Computing statistical features...
# subject statistical features shape: (6, 19)
# Number of frames: 6
# Calculating spectral features...
# Subject Anniepoo-20140308-bft with subject file id rb-06 is processing...
# Computing statistical features...
# subject statistical features shape: (5, 19)
# Number of frames: 5
# Calculating spectral features...
# Subject Anniepoo-20140308-bft with subject file id rb-07 is processing...
# Computing statistical features...
# subject statistical features shape: (5, 19)
# Number of frames: 5
# Calculating spectral features...
# Subject Anniepoo-20140308-bft with subject file id rb-08 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# Subject Anniepoo-20140308-bft with subject file id rb-09 is processing...
# Computing statistical features...
# subject statistical features shape: (5, 19)
# Number of frames: 5
# Calculating spectral features...
# Subject Anniepoo-20140308-bft with subject file id rb-10 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# Subject Anniepoo-20140308-bft with subject file id rb-11 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject Anniepoo-20140308-bft with subject file id rb-12 is processing...
# Computing statistical features...
# subject statistical features shape: (5, 19)
# Number of frames: 5
# Calculating spectral features...
# Subject Anniepoo-20140308-bft with subject file id rb-13 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject Anniepoo-20140308-cqj with subject file id a0116 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject Anniepoo-20140308-cqj with subject file id a0117 is processing...
# Computing statistical features...
# subject statistical features shape: (5, 19)
# Number of frames: 5
# Calculating spectral features...
# Subject Anniepoo-20140308-cqj with subject file id a0118 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# Subject Anniepoo-20140308-cqj with subject file id a0119 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# Subject Anniepoo-20140308-cqj with subject file id a0120 is processing...
# Computing statistical features...
# subject statistical features shape: (5, 19)
# Number of frames: 5
# Calculating spectral features...
# Subject Anniepoo-20140308-cqj with subject file id a0121 is processing...
# Computing statistical features...
# subject statistical features shape: (5, 19)
# Number of frames: 5
# Calculating spectral features...
# Subject Anniepoo-20140308-cqj with subject file id a0122 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=44544
#   warnings.warn(
# Subject Anniepoo-20140308-cqj with subject file id a0123 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# Subject Anniepoo-20140308-cqj with subject file id a0124 is processing...
# Computing statistical features...
# subject statistical features shape: (5, 19)
# Number of frames: 5
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=38912
#   warnings.warn(
# Subject Anniepoo-20140308-cqj with subject file id a0125 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject Anniepoo-20140308-fcp with subject file id a0059 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# Subject Anniepoo-20140308-fcp with subject file id a0060 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# Subject Anniepoo-20140308-fcp with subject file id a0061 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=33280
#   warnings.warn(
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=46080
#   warnings.warn(
# Subject Anniepoo-20140308-fcp with subject file id a0062 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# Subject Anniepoo-20140308-fcp with subject file id a0063 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject Anniepoo-20140308-fcp with subject file id a0064 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject Anniepoo-20140308-fcp with subject file id a0065 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject Anniepoo-20140308-fcp with subject file id a0066 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# Subject Anniepoo-20140308-fcp with subject file id a0067 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=35328
#   warnings.warn(
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=36864
#   warnings.warn(
# Subject Anniepoo-20140308-fcp with subject file id a0068 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# Subject Anniepoo-20140308-hns with subject file id a0282 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject Anniepoo-20140308-hns with subject file id a0283 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject Anniepoo-20140308-hns with subject file id a0284 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject Anniepoo-20140308-hns with subject file id a0285 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject Anniepoo-20140308-hns with subject file id a0286 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject Anniepoo-20140308-hns with subject file id a0287 is processing...
# Computing statistical features...
# subject statistical features shape: (1, 19)
# Number of frames: 1
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=15872
#   warnings.warn(
# Subject Anniepoo-20140308-hns with subject file id a0288 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# Subject Anniepoo-20140308-hns with subject file id a0289 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject Anniepoo-20140308-hns with subject file id a0290 is processing...
# Computing statistical features...
# subject statistical features shape: (2, 19)
# Number of frames: 2
# Calculating spectral features...
# Subject Anniepoo-20140308-hns with subject file id a0291 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=31232
#   warnings.warn(
# Subject Anniepoo-20140308-nky with subject file id b0069 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject Anniepoo-20140308-nky with subject file id b0070 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=38400
#   warnings.warn(
# Subject Anniepoo-20140308-nky with subject file id b0071 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# Subject Anniepoo-20140308-nky with subject file id b0072 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject Anniepoo-20140308-nky with subject file id b0073 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject Anniepoo-20140308-nky with subject file id b0074 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject Anniepoo-20140308-nky with subject file id b0075 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject Anniepoo-20140308-nky with subject file id b0076 is processing...
# Computing statistical features...
# subject statistical features shape: (6, 19)
# Number of frames: 6
# Calculating spectral features...
# Subject Anniepoo-20140308-nky with subject file id b0077 is processing...
# Computing statistical features...
# subject statistical features shape: (2, 19)
# Number of frames: 2
# Calculating spectral features...
# Subject Anniepoo-20140308-nky with subject file id b0078 is processing...
# Computing statistical features...
# subject statistical features shape: (5, 19)
# Number of frames: 5
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=28160
#   warnings.warn(
# Subject Coren-20141121-pxp with subject file id b0467 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# Subject Coren-20141121-pxp with subject file id b0468 is processing...
# Computing statistical features...
# subject statistical features shape: (5, 19)
# Number of frames: 5
# Calculating spectral features...
# Subject Coren-20141121-pxp with subject file id b0469 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject Coren-20141121-pxp with subject file id b0470 is processing...
# Computing statistical features...
# subject statistical features shape: (2, 19)
# Number of frames: 2
# Calculating spectral features...
# Subject Coren-20141121-pxp with subject file id b0471 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject Coren-20141121-pxp with subject file id b0472 is processing...
# Computing statistical features...
# subject statistical features shape: (6, 19)
# Number of frames: 6
# Calculating spectral features...
# Subject Coren-20141121-pxp with subject file id b0473 is processing...
# Computing statistical features...
# subject statistical features shape: (2, 19)
# Number of frames: 2
# Calculating spectral features...
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=29184
#   warnings.warn(
# Subject Coren-20141121-pxp with subject file id b0474 is processing...
# Computing statistical features...
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# Subject Coren-20141121-pxp with subject file id b0475 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# Subject Coren-20141121-pxp with subject file id b0476 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...

# %%
# # cloud
# subjects_features = transform_signals(signal_file_paths, SAVE_DIR, storage_account_name=storage_account_name, credential=credential)
