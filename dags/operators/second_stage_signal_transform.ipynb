# %%
import os
import pyarrow as pa
import pyarrow.parquet as pq
import pyarrowfs_adlgen2 as pa_adl
import pyarrow.dataset as ds
import numpy as np
import librosa
import duckdb
import matplotlib.pyplot as plt
import re
import random

from scipy.stats import kurtosis as kurt, skew, entropy, mode
from dotenv import load_dotenv
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor

from azure.identity import DefaultAzureCredential, ClientSecretCredential
from azure.storage.filedatalake import DataLakeServiceClient
from azure.keyvault.secrets import SecretClient
from azure.core.exceptions import ResourceNotFoundError

# %load_ext autoreload
# %autoreload 2

# %%
# local
DATA_DIR = "../../include/data"

# %%
# # cloud
# # URL = "abfss://{FOLDER_NAME}@sgppipelinesa.dfs.core.windows.net"
# URL = "{FOLDER_NAME}"
# SILVER_FOLDER_NAME = "sgppipelinesa-silver"
# SUB_FOLDER_NAME = "stage-01"
# SILVER_DATA_DIR = os.path.join(URL, "{SUB_FOLDER_NAME}").replace("\\", "/")
# SILVER_DATA_DIR

# local
SILVER_FOLDER_NAME = "silver"
SUB_FOLDER_NAME = "stage-01"
SILVER_DATA_DIR = os.path.join("{DATA_DIR}", "{FOLDER_NAME}", "{SUB_FOLDER_NAME}").replace("\\", "/")
SILVER_DATA_DIR
# Out:
# '{DATA_DIR}/{FOLDER_NAME}/{SUB_FOLDER_NAME}'

# %% [markdown]
# # Computing features for a single subjects audio signals
# this is to familiarize what exact features we need to compute for all other subjects audio signals

# %%
# anonymous-20080904-qzg_signals
# _caustic_-20170306-smy_signals
subject_table = pq.read_table(
    os.path.join(
        SILVER_DATA_DIR.format(
            DATA_DIR=DATA_DIR,
            FOLDER_NAME=SILVER_FOLDER_NAME,
            SUB_FOLDER_NAME=SUB_FOLDER_NAME
        ), 
        "1028-20100710-hne/signals_0.parquet"
    )
)
subject_table
# Out:
# pyarrow.Table
# signals: float
# subject_id: string
# file_row_number: int64
# file_name: string
# loaded_at: timestamp[us]
# ----
# signals: [[-0.013122559,-0.013031006,-0.012817383,-0.012481689,-0.0121154785,...,-0.00036621094,-0.00045776367,-0.000030517578,-0.00048828125,-0.00079345703]]
# subject_id: [["1028-20100710-hne","1028-20100710-hne","1028-20100710-hne","1028-20100710-hne","1028-20100710-hne",...,"1028-20100710-hne","1028-20100710-hne","1028-20100710-hne","1028-20100710-hne","1028-20100710-hne"]]
# file_row_number: [[0,1,2,3,4,...,63483,63484,63485,63486,63487]]
# file_name: [["https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav","https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav","https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav","https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav","https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav",...,"https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav","https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav","https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav","https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav","https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav"]]
# loaded_at: [[2026-03-30 10:31:59.154678,2026-03-30 10:31:59.154678,2026-03-30 10:31:59.154678,2026-03-30 10:31:59.154678,2026-03-30 10:31:59.154678,...,2026-03-30 10:31:59.154678,2026-03-30 10:31:59.154678,2026-03-30 10:31:59.154678,2026-03-30 10:31:59.154678,2026-03-30 10:31:59.154678]]

# %%
# connect to an in-memory database
conn = duckdb.connect()

# %%
conn.sql("""
    SELECT COUNT(*) FROM subject_table
""")
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │        63488 │
# └──────────────┘

# %%
# hertz
hertz = 16000
window_time = 3
hop_time = 1

# we calculate the window size of each segment or the
# amount of samples it has to have based on the frequency
samples_per_win_size = int(window_time * hertz)
samples_per_hop_size = int(hop_time * hertz)

# %% [markdown]
# # Computing statistical features

# %%
conn.sql(f"""
    CREATE OR REPLACE TEMPORARY TABLE subject_features AS (
        SELECT
            subject_id, 
            signals, 
            file_row_number,
            file_name,
            loaded_at,
            
            KURTOSIS(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_kurt,
            SKEWNESS(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_skew,
            ENTROPY(signals)OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_entropy,
            AVG(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_mean,
            MEDIAN(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_median,
            MODE(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_mode,
            MIN(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_min,
            MAX(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_max,
            VAR_SAMP(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_var,
            STDDEV_SAMP(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_stddev,
            QUANTILE_CONT(signals, 0.25) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_first_quart,
            QUANTILE_CONT(signals, 0.75) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_third_quart
        FROM subject_table
        WHERE (file_row_number % {samples_per_hop_size}) = 0
        ORDER BY file_row_number
    )
""")

# %%
conn.sql("""
    CREATE OR REPLACE TEMPORARY TABLE subject_features AS (
        SELECT 
            *,
            (freq_max - freq_min) AS freq_range,
            (freq_third_quart - freq_first_quart) AS freq_inter_quart_range
        FROM subject_features
    )
""")

# %%
conn.sql("""
    SELECT * FROM subject_features
""")
# Out:
# ┌───────────────────┬───────────────┬─────────────────┬─────────────────────────────────────────────────────────────────────────────────────────────────┬────────────────────────────┬────────────────────┬─────────────────────┬────────────────────┬────────────────────┬───────────────┬───────────────┬───────────────┬──────────────┬────────────────────────┬───────────────────────┬──────────────────┬──────────────────┬──────────────┬────────────────────────┐
# │    subject_id     │    signals    │ file_row_number │                                            file_name                                            │         loaded_at          │     freq_kurt      │      freq_skew      │    freq_entropy    │     freq_mean      │  freq_median  │   freq_mode   │   freq_min    │   freq_max   │        freq_var        │      freq_stddev      │ freq_first_quart │ freq_third_quart │  freq_range  │ freq_inter_quart_range │
# │      varchar      │     float     │      int64      │                                             varchar                                             │         timestamp          │       double       │       double        │       double       │       double       │     float     │     float     │     float     │    float     │         double         │        double         │      float       │      float       │    float     │         float          │
# ├───────────────────┼───────────────┼─────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────┼────────────────────┼─────────────────────┼────────────────────┼────────────────────┼───────────────┼───────────────┼───────────────┼──────────────┼────────────────────────┼───────────────────────┼──────────────────┼──────────────────┼──────────────┼────────────────────────┤
# │ 1028-20100710-hne │  -0.013122559 │               0 │ https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav │ 2026-03-30 10:31:59.154678 │ 3.1151970942264215 │ -1.6518507505141513 │                2.0 │ -0.003692626953125 │ -0.0016326904 │  -0.013122559 │  -0.013122559 │ 0.0016174316 │  4.187040030956268e-05 │  0.006470734139922817 │    -0.0045394897 │   -0.00078582764 │   0.01473999 │            0.003753662 │
# │ 1028-20100710-hne │ -0.0016784668 │           16000 │ https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav │ 2026-03-30 10:31:59.154678 │               NULL │  1.7274162139091893 │ 1.5849625007211559 │  -0.00054931640625 │ -0.0015869141 │ -0.0016784668 │ -0.0016784668 │ 0.0016174316 │ 3.5231932997703552e-06 │ 0.0018770171282570533 │    -0.0016326904 │    1.5258789e-05 │ 0.0032958984 │           0.0016479492 │
# │ 1028-20100710-hne │ -0.0015869141 │           32000 │ https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav │ 2026-03-30 10:31:59.154678 │               NULL │                NULL │                1.0 │  1.52587890625e-05 │ 1.5258789e-05 │ -0.0015869141 │ -0.0015869141 │ 0.0016174316 │  5.133915692567825e-06 │ 0.0022658145759456632 │   -0.00078582764 │     0.0008163452 │ 0.0032043457 │           0.0016021729 │
# │ 1028-20100710-hne │  0.0016174316 │           48000 │ https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav │ 2026-03-30 10:31:59.154678 │               NULL │                NULL │                0.0 │  0.001617431640625 │  0.0016174316 │  0.0016174316 │  0.0016174316 │ 0.0016174316 │                   NULL │                  NULL │     0.0016174316 │     0.0016174316 │          0.0 │                    0.0 │
# └───────────────────┴───────────────┴─────────────────┴─────────────────────────────────────────────────────────────────────────────────────────────────┴────────────────────────────┴────────────────────┴─────────────────────┴────────────────────┴────────────────────┴───────────────┴───────────────┴───────────────┴──────────────┴────────────────────────┴───────────────────────┴──────────────────┴──────────────────┴──────────────┴────────────────────────┘

# %% [markdown]
# #### 544000 + a window of 48000 is 592000 which is greater 553472 so we consider only the indeces 544000 to 553471 which is just 9471 rows of data for this last window

# %%
# conn.sql("""
#     SELECT COUNT(*) FROM subject_table
# """)

# %% [markdown]
# # imputing missing or null values created from feature engineering

# %%
# conn.sql("""
#     SELECT 
#         COALESCE(
#             freq_kurt, 
#             (SELECT AVG(freq_kurt) FROM subject_features)
#         ) AS freq_kurt_imp,
#         COALESCE(
#             freq_skew, 
#             (SELECT AVG(freq_skew) FROM subject_features)
#         ) AS freq_skew_imp,
#         COALESCE(
#             freq_entropy, 
#             (SELECT AVG(freq_entropy) FROM subject_features)
#         ) AS freq_entropy_imp
#     FROM subject_features
# """)

# %% [markdown]
# # Computing spectral features

# %%
# frames = conn.sql("""
#     SELECT COUNT(rowId) FROM subject_features
# """).fetchall()[-1][-1]

# %%
# frames

# %%
# time = librosa.frames_to_time(frames, sr=hertz, hop_length=samples_per_hop_size)
# time

# %%
# subject_table["signals"].to_numpy()

# %%
# x_signals = subject_table["signals"].to_numpy()
# x_signals

# %%
# # calculate other features
# zcr = librosa.feature.zero_crossing_rate(y=x_signals, frame_length=samples_per_win_size, hop_length=samples_per_hop_size)
# zcr

# %%
# zcr.shape[1]

# %%
# new_zcr = zcr.reshape(-1)
# new_zcr.shape

# %%
# view_signal_feature(new_zcr, "zero crossing rate")

# %% [markdown]
# #### sometimes the calculation of spectral features may lead to 1 or more data points being added when compared to the length of the number of statistical features computed based on window length and hop length. To make sure number of values of statistical features and spectral features are the same we get only the first n rows of this spectral features based solely on the number of rows of the statistical features e.g. if there are 35 successfully calculated statistical features and we have 36 calculated spectral features we only get the first 35 of the spectral features and discard the rest

# %%
# zcr_n_values_to_rem = np.abs(zcr.shape[1] - time)
# zcr_n_values_to_rem.astype(int)

# %%
# # get slice of those in range with time only
# new_zcr = zcr.reshape(-1)[:frames]
# new_zcr.shape

# %%
# new_zcr.shape

# %%
# # these are 2 features all in all we don't need to aggregate it
# # into a (1, 35) array
# poly_feats = librosa.feature.poly_features(y=x_signals, sr=hertz, n_fft=samples_per_win_size, hop_length=samples_per_hop_size)
# poly_feats.shape

# %%
# new_poly_feats = poly_feats[:, :frames]
# new_poly_feats.shape

# %%
# # y is the audio signals we must pass
# # sr is the sampling rate of our audio signals
# # n_fft is the window size of the fast fourier transform
# # hop_length is number of samples between successive frames
# # n_mels is the number of Mel bands to generate
# mel_spec = librosa.feature.melspectrogram(y=x_signals, sr=hertz, n_fft=samples_per_win_size, hop_length=samples_per_hop_size, n_mels=90)
# mel_spec.shape

# %%
# mel_spec_mean, \
# mel_spec_median, \
# mel_spec_mode, \
# mel_spec_mode_cnt, \
# mel_spec_min, \
# mel_spec_max, \
# mel_spec_range, \
# mel_spec_var, \
# mel_spec_std, \
# mel_spec_first_quart, \
# mel_spec_third_quart, \
# mel_spec_inter_quart_range, \
# mel_spec_entropy, \
# mel_spec_kurt, \
# mel_spec_skew = extract_spectogam_stats(mel_spec)

# %%
# mel_spec_mode

# %%
# mel_spec_mean.shape, mel_spec_median.shape, mel_spec_mode.shape

# %%
# mel_spec_entropy.shape, mel_spec_kurt.shape, mel_spec_skew.shape

# %%
# librosa.display.specshow(mel_spec)

# %%
# mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
# mel_spec_db

# %%
# mel_spec_db_mean, \
# mel_spec_db_median, \
# mel_spec_db_mode, \
# mel_spec_db_mode_cnt, \
# mel_spec_db_min, \
# mel_spec_db_max, \
# mel_spec_db_range, \
# mel_spec_db_var, \
# mel_spec_db_std, \
# mel_spec_db_first_quart, \
# mel_spec_db_third_quart, \
# mel_spec_db_inter_quart_range, \
# mel_spec_db_entropy, \
# mel_spec_db_kurt, \
# mel_spec_db_skew = extract_spectogam_stats(mel_spec_db)

# %%
# librosa.display.specshow(mel_spec_db)

# %%
# spec_cent = librosa.feature.spectral_centroid(y=x_signals, sr=hertz, n_fft=samples_per_win_size, hop_length=samples_per_hop_size)
# spec_cent.shape

# %%
# new_spec_cent = spec_cent.reshape(-1)
# new_spec_cent.shape

# %%
# view_signal_feature(new_spec_cent, "spectral centroid")

# %%
# mfcc = librosa.feature.mfcc(y=x_signals, sr=hertz, n_fft=samples_per_win_size, hop_length=samples_per_hop_size, n_mfcc=90)
# mfcc.shape

# %%
# mfcc_mean, \
# mfcc_median, \
# mfcc_mode, \
# mfcc_mode_cnt, \
# mfcc_min, \
# mfcc_max, \
# mfcc_range, \
# mfcc_var, \
# mfcc_std, \
# mfcc_first_quart, \
# mfcc_third_quart, \
# mfcc_inter_quart_range, \
# mfcc_entropy, \
# mfcc_kurt, \
# mfcc_skew = extract_spectogam_stats(mfcc)

# %%
# librosa.display.specshow(mfcc)

# %%
# spec_bw = librosa.feature.spectral_bandwidth(y=x_signals, sr=hertz, n_fft=samples_per_win_size, hop_length=samples_per_hop_size)
# spec_bw.shape

# %%
# new_spec_bw = spec_bw.reshape(-1)
# new_spec_bw.shape

# %%
# view_signal_feature(new_spec_bw, "spectral bandwidth")

# %%
# spec_cont = librosa.feature.spectral_contrast(y=x_signals, sr=hertz, n_fft=samples_per_win_size, hop_length=samples_per_hop_size)
# spec_cont.shape

# %%
# spec_cont_mean, \
# spec_cont_median, \
# spec_cont_mode, \
# spec_cont_mode_cnt, \
# spec_cont_min, \
# spec_cont_max, \
# spec_cont_range, \
# spec_cont_var, \
# spec_cont_std, \
# spec_cont_first_quart, \
# spec_cont_third_quart, \
# spec_cont_inter_quart_range, \
# spec_cont_entropy, \
# spec_cont_kurt, \
# spec_cont_skew = extract_spectogam_stats(spec_cont)

# %%
# librosa.display.specshow(spec_cont)

# %%
# spec_flat = librosa.feature.spectral_flatness(y=x_signals, n_fft=samples_per_win_size, hop_length=samples_per_hop_size)
# spec_flat.shape

# %%
# new_spec_flat = spec_flat.reshape(-1)
# new_spec_flat.shape

# %%
# view_signal_feature(new_spec_flat, "spectral flatness")

# %%
# spec_roll = librosa.feature.spectral_rolloff(y=x_signals, sr=hertz, n_fft=samples_per_win_size, hop_length=samples_per_hop_size)
# spec_roll.shape

# %%
# new_spec_roll = spec_roll.reshape(-1)
# new_spec_roll.shape

# %%
# view_signal_feature(new_spec_roll, "spectral rolloff")

# %%
# subject_features = conn.sql("""
#     SELECT * FROM subject_features
# """).to_arrow_table()

# %%
# subject_features

# %%
# subject_features = subject_features.append_column("zcr", [new_zcr])
# subject_features = subject_features.append_column("poly_feat_1", [poly_feats[0, :]])
# subject_features = subject_features.append_column("poly_feat_2", [poly_feats[1, :]])
# subject_features = subject_features.append_column("spec_cent", [new_spec_cent])
# subject_features = subject_features.append_column("spec_bw", [new_spec_bw])
# subject_features = subject_features.append_column("spec_flat", [new_spec_flat])
# subject_features = subject_features.append_column("spec_roll", [new_spec_roll])

# subject_features = subject_features.append_column("mel_spec_mean", [mel_spec_mean])
# subject_features = subject_features.append_column("mel_spec_median", [mel_spec_median])
# subject_features = subject_features.append_column("mel_spec_mode", [mel_spec_mode])
# subject_features = subject_features.append_column("mel_spec_mode_cnt", [mel_spec_mode_cnt])
# subject_features = subject_features.append_column("mel_spec_min", [mel_spec_min])
# subject_features = subject_features.append_column("mel_spec_max", [mel_spec_max])
# subject_features = subject_features.append_column("mel_spec_range", [mel_spec_range])
# subject_features = subject_features.append_column("mel_spec_var", [mel_spec_var])
# subject_features = subject_features.append_column("mel_spec_std", [mel_spec_std])
# subject_features = subject_features.append_column("mel_spec_first_quart", [mel_spec_first_quart])
# subject_features = subject_features.append_column("mel_spec_third_quart", [mel_spec_third_quart])
# subject_features = subject_features.append_column("mel_spec_inter_quart_range", [mel_spec_inter_quart_range])
# subject_features = subject_features.append_column("mel_spec_entropy", [mel_spec_entropy])
# subject_features = subject_features.append_column("mel_spec_kurt", [mel_spec_kurt])
# subject_features = subject_features.append_column("mel_spec_skew", [mel_spec_skew])

# subject_features = subject_features.append_column("mel_spec_db_mean", [mel_spec_db_mean])
# subject_features = subject_features.append_column("mel_spec_db_median", [mel_spec_db_median])
# subject_features = subject_features.append_column("mel_spec_db_mode", [mel_spec_db_mode])
# subject_features = subject_features.append_column("mel_spec_db_mode_cnt", [mel_spec_db_mode_cnt])
# subject_features = subject_features.append_column("mel_spec_db_min", [mel_spec_db_min])
# subject_features = subject_features.append_column("mel_spec_db_max", [mel_spec_db_max])
# subject_features = subject_features.append_column("mel_spec_db_range", [mel_spec_db_range])
# subject_features = subject_features.append_column("mel_spec_db_var", [mel_spec_db_var])
# subject_features = subject_features.append_column("mel_spec_db_std", [mel_spec_db_std])
# subject_features = subject_features.append_column("mel_spec_db_first_quart", [mel_spec_db_first_quart])
# subject_features = subject_features.append_column("mel_spec_db_third_quart", [mel_spec_db_third_quart])
# subject_features = subject_features.append_column("mel_spec_db_inter_quart_range", [mel_spec_db_inter_quart_range])
# subject_features = subject_features.append_column("mel_spec_db_entropy", [mel_spec_db_entropy])
# subject_features = subject_features.append_column("mel_spec_db_kurt", [mel_spec_db_kurt])
# subject_features = subject_features.append_column("mel_spec_db_skew", [mel_spec_db_skew])

# subject_features = subject_features.append_column("mfcc_mean", [mfcc_mean])
# subject_features = subject_features.append_column("mfcc_median", [mfcc_median])
# subject_features = subject_features.append_column("mfcc_mode", [mfcc_mode])
# subject_features = subject_features.append_column("mfcc_mode_cnt", [mfcc_mode_cnt])
# subject_features = subject_features.append_column("mfcc_min", [mfcc_min])
# subject_features = subject_features.append_column("mfcc_max", [mfcc_max])
# subject_features = subject_features.append_column("mfcc_range", [mfcc_range])
# subject_features = subject_features.append_column("mfcc_var", [mfcc_var])
# subject_features = subject_features.append_column("mfcc_std", [mfcc_std])
# subject_features = subject_features.append_column("mfcc_first_quart", [mfcc_first_quart])
# subject_features = subject_features.append_column("mfcc_third_quart", [mfcc_third_quart])
# subject_features = subject_features.append_column("mfcc_inter_quart_range", [mfcc_inter_quart_range])
# subject_features = subject_features.append_column("mfcc_entropy", [mfcc_entropy])
# subject_features = subject_features.append_column("mfcc_kurt", [mfcc_kurt])
# subject_features = subject_features.append_column("mfcc_skew", [mfcc_skew])

# subject_features = subject_features.append_column("spec_cont_mean", [spec_cont_mean])
# subject_features = subject_features.append_column("spec_cont_median", [spec_cont_median])
# subject_features = subject_features.append_column("spec_cont_mode", [spec_cont_mode])
# subject_features = subject_features.append_column("spec_cont_mode_cnt", [spec_cont_mode_cnt])
# subject_features = subject_features.append_column("spec_cont_min", [spec_cont_min])
# subject_features = subject_features.append_column("spec_cont_max", [spec_cont_max])
# subject_features = subject_features.append_column("spec_cont_range", [spec_cont_range])
# subject_features = subject_features.append_column("spec_cont_var", [spec_cont_var])
# subject_features = subject_features.append_column("spec_cont_std", [spec_cont_std])
# subject_features = subject_features.append_column("spec_cont_first_quart", [spec_cont_first_quart])
# subject_features = subject_features.append_column("spec_cont_third_quart", [spec_cont_third_quart])
# subject_features = subject_features.append_column("spec_cont_inter_quart_range", [spec_cont_inter_quart_range])
# subject_features = subject_features.append_column("spec_cont_entropy", [spec_cont_entropy])
# subject_features = subject_features.append_column("spec_cont_kurt", [spec_cont_kurt])
# subject_features = subject_features.append_column("spec_cont_skew", [spec_cont_skew])

# %%
# subject_features

# %%
# subject_features.shape

# %% [markdown]
# # We have computed more than enough features we need, now we will load all of the subjects audio signal parquet files into one giant table

# %%
# local
signal_file_paths = [
    str(signal_file_path).replace("\\", "/") for signal_file_path in Path(
        SILVER_DATA_DIR.format(
            DATA_DIR=DATA_DIR,
            FOLDER_NAME=SILVER_FOLDER_NAME,
            SUB_FOLDER_NAME=SUB_FOLDER_NAME
        )
    ).rglob('*')  
    if signal_file_path.is_file()
]

# %%
signal_file_paths
# Out:
# ['../../include/data/silver/stage-01/1028-20100710-hne/signals_0.parquet',
#  '../../include/data/silver/stage-01/1028-20100710-hne/signals_1.parquet',
#  '../../include/data/silver/stage-01/1028-20100710-hne/signals_2.parquet',
#  '../../include/data/silver/stage-01/1028-20100710-hne/signals_3.parquet',
#  '../../include/data/silver/stage-01/1028-20100710-hne/signals_4.parquet',
#  '../../include/data/silver/stage-01/1028-20100710-hne/signals_5.parquet',
#  '../../include/data/silver/stage-01/1028-20100710-hne/signals_6.parquet',
#  '../../include/data/silver/stage-01/1028-20100710-hne/signals_7.parquet',
#  '../../include/data/silver/stage-01/1028-20100710-hne/signals_8.parquet',
#  '../../include/data/silver/stage-01/1028-20100710-hne/signals_9.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-ajg/signals_0.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-ajg/signals_1.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-ajg/signals_2.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-ajg/signals_3.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-ajg/signals_4.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-ajg/signals_5.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-ajg/signals_6.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-ajg/signals_7.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-ajg/signals_8.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-ajg/signals_9.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-tkg/signals_0.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-tkg/signals_1.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-tkg/signals_2.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-tkg/signals_3.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-tkg/signals_4.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-tkg/signals_5.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-tkg/signals_6.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-tkg/signals_7.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-tkg/signals_8.parquet',
#  '../../include/data/silver/stage-01/1337ad-20170321-tkg/signals_9.parquet',
#  '../../include/data/silver/stage-01/1snoke-20120412-hge/signals_0.parquet',
#  '../../include/data/silver/stage-01/1snoke-20120412-hge/signals_1.parquet',
#  '../../include/data/silver/stage-01/1snoke-20120412-hge/signals_2.parquet',
#  '../../include/data/silver/stage-01/1snoke-20120412-hge/signals_3.parquet',
#  '../../include/data/silver/stage-01/1snoke-20120412-hge/signals_4.parquet',
#  '../../include/data/silver/stage-01/1snoke-20120412-hge/signals_5.parquet',
#  '../../include/data/silver/stage-01/1snoke-20120412-hge/signals_6.parquet',
#  '../../include/data/silver/stage-01/1snoke-20120412-hge/signals_7.parquet',
#  '../../include/data/silver/stage-01/1snoke-20120412-hge/signals_8.parquet',
#  '../../include/data/silver/stage-01/1snoke-20120412-hge/signals_9.parquet',
#  '../../include/data/silver/stage-01/23yipikaye-20100807-ujm/signals_0.parquet',
#  '../../include/data/silver/stage-01/23yipikaye-20100807-ujm/signals_1.parquet',
#  '../../include/data/silver/stage-01/23yipikaye-20100807-ujm/signals_2.parquet',
#  '../../include/data/silver/stage-01/23yipikaye-20100807-ujm/signals_3.parquet',
#  '../../include/data/silver/stage-01/23yipikaye-20100807-ujm/signals_4.parquet',
#  '../../include/data/silver/stage-01/23yipikaye-20100807-ujm/signals_5.parquet',
#  '../../include/data/silver/stage-01/23yipikaye-20100807-ujm/signals_6.parquet',
#  '../../include/data/silver/stage-01/23yipikaye-20100807-ujm/signals_7.parquet',
#  '../../include/data/silver/stage-01/23yipikaye-20100807-ujm/signals_8.parquet',
#  '../../include/data/silver/stage-01/23yipikaye-20100807-ujm/signals_9.parquet',
#  '../../include/data/silver/stage-01/Aaron-20080318-kdl/signals_0.parquet',
#  '../../include/data/silver/stage-01/Aaron-20080318-kdl/signals_1.parquet',
#  '../../include/data/silver/stage-01/Aaron-20080318-kdl/signals_2.parquet',
#  '../../include/data/silver/stage-01/Aaron-20080318-kdl/signals_3.parquet',
#  '../../include/data/silver/stage-01/Aaron-20080318-kdl/signals_4.parquet',
#  '../../include/data/silver/stage-01/Aaron-20080318-kdl/signals_5.parquet',
#  '../../include/data/silver/stage-01/Aaron-20080318-kdl/signals_6.parquet',
#  '../../include/data/silver/stage-01/Aaron-20080318-kdl/signals_7.parquet',
#  '../../include/data/silver/stage-01/Aaron-20080318-kdl/signals_8.parquet',
#  '../../include/data/silver/stage-01/Aaron-20080318-kdl/signals_9.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-bft/signals_0.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-bft/signals_1.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-bft/signals_2.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-bft/signals_3.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-bft/signals_4.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-bft/signals_5.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-bft/signals_6.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-bft/signals_7.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-bft/signals_8.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-bft/signals_9.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-cqj/signals_0.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-cqj/signals_1.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-cqj/signals_2.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-cqj/signals_3.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-cqj/signals_4.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-cqj/signals_5.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-cqj/signals_6.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-cqj/signals_7.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-cqj/signals_8.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-cqj/signals_9.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-fcp/signals_0.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-fcp/signals_1.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-fcp/signals_2.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-fcp/signals_3.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-fcp/signals_4.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-fcp/signals_5.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-fcp/signals_6.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-fcp/signals_7.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-fcp/signals_8.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-fcp/signals_9.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-hns/signals_0.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-hns/signals_1.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-hns/signals_2.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-hns/signals_3.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-hns/signals_4.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-hns/signals_5.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-hns/signals_6.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-hns/signals_7.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-hns/signals_8.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-hns/signals_9.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-nky/signals_0.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-nky/signals_1.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-nky/signals_2.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-nky/signals_3.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-nky/signals_4.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-nky/signals_5.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-nky/signals_6.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-nky/signals_7.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-nky/signals_8.parquet',
#  '../../include/data/silver/stage-01/Anniepoo-20140308-nky/signals_9.parquet',
#  '../../include/data/silver/stage-01/Coren-20141121-pxp/signals_0.parquet',
#  '../../include/data/silver/stage-01/Coren-20141121-pxp/signals_1.parquet',
#  '../../include/data/silver/stage-01/Coren-20141121-pxp/signals_2.parquet',
#  '../../include/data/silver/stage-01/Coren-20141121-pxp/signals_3.parquet',
#  '../../include/data/silver/stage-01/Coren-20141121-pxp/signals_4.parquet',
#  '../../include/data/silver/stage-01/Coren-20141121-pxp/signals_5.parquet',
#  '../../include/data/silver/stage-01/Coren-20141121-pxp/signals_6.parquet',
#  '../../include/data/silver/stage-01/Coren-20141121-pxp/signals_7.parquet',
#  '../../include/data/silver/stage-01/Coren-20141121-pxp/signals_8.parquet',
#  '../../include/data/silver/stage-01/Coren-20141121-pxp/signals_9.parquet']

# %%
# # local
# signal_file_paths_test = [
#     os.path.join(
#         SILVER_DATA_DIR.format(
#             DATA_DIR=DATA_DIR,
#             SILVER_FOLDER_NAME=SILVER_FOLDER_NAME,
#             SUB_FOLDER_NAME=SUB_FOLDER_NAME
#         ),
#         signal_file_path_test
#     ).replace("\\", "/")
#     for signal_file_path_test in ["anonymous-20080904-qzg_signals.parquet", "_caustic_-20170306-smy_signals.parquet"]
# ]
# signal_file_paths_test

# %%
# Retrieve credentials from environment variables
# this is strictly used only in development
# load env variables
env_dir = Path('../../').resolve()
load_dotenv(os.path.join(env_dir, '.env'))
# Out:
# True

# %%
storage_account_name = os.environ.get("STORAGE_ACCOUNT_NAME")
credential = os.environ.get("STORAGE_ACCOUNT_KEY")
conn_str = os.environ.get("STORAGE_ACCOUNT_CONN_STR")

# %%
SILVER_DATA_DIR
# Out:
# '{DATA_DIR}/{FOLDER_NAME}/{SUB_FOLDER_NAME}'

# %%
# cloud
# create client with generated sas token
datalake_service_client = DataLakeServiceClient(
    account_url=f"https://{storage_account_name}.dfs.core.windows.net", 
    credential=credential
)

# retrieves file system client/container client 
# to retrieve datalake client
silver_container_client = datalake_service_client.get_file_system_client(f"{storage_account_name}-silver")

# we only get the directories in the first level of 
# the container, if it has a "/" then it means it is not
# an immediate folder in the container. This only really
# gets the subject folders 
signal_file_paths = [
    os.path.join(
        SILVER_FOLDER_NAME,
        path.name
    ).replace("\\", "/") 
    for path in silver_container_client.get_paths(path=SUB_FOLDER_NAME) 
    if (not "labels" in path.name) and (".parquet" in path.name)
]
signal_file_paths

# %%
def align_spectral_features_length(feature, target_len, pad_mode='edge'):
    """
    Aligns audio features to a target length along the time axis (axis 1).
    Works for 2D arrays like MFCC (n_mfcc, n_frames) or ZCR (1, n_frames).
    """
    curr_len = feature.shape[1]
    
    if curr_len < target_len:
        # Calculate how many frames are missing
        pad_width = target_len - curr_len
        # np.pad(array, ((top, bottom), (left, right)), mode)
        # We only want to pad the 'right' side of the second axis
        # >>> import numpy as np
        # >>>
        # >>> test = np.array([
        # ...     [1, 2, 3],
        # ...     [4,5, 6],
        # ... ])
        # >>>
        # >>> pad_width = 5
        # >>> padded_test = np.pad(test, ((0, 0), (0, pad_width)), mode='edge')
        # >>> padded_test
        # array([[1, 2, 3, 3, 3, 3, 3, 3],
        #     [4, 5, 6, 6, 6, 6, 6, 6]])
        padded_feature = np.pad(feature, ((0, 0), (0, pad_width)), mode=pad_mode)
        return padded_feature
    
    elif curr_len > target_len:
        # If librosa gave us an extra frame, trim it back which 
        # is equivalent to the ff:
        # zcr_n_values_to_rem = np.abs(zcr.shape[1] - time.shape[0])
        # zcr = zcr.reshape(-1)[:-zcr_n_values_to_rem]
        return feature[:, :target_len]
    
    return feature

def extract_spectrogram_stats(spectrogram):
    """
    extracts statistical features of mel frequency ceptstral 
    coefficients, mel spectrogram, mel decibel spectrogram,
    spectral contrast spectrogram matrices along the the x-axis
    so if a matrix or spectrogram is (90, 35) final array will 
    be (1, 35)
    """

    # central tendency
    spec_mean = np.mean(spectrogram, axis=0)
    spec_median = np.median(spectrogram, axis=0)
    spec_mode = mode(spectrogram, axis=0).mode
    spec_mode_cnt = mode(spectrogram, axis=0).count
    
    # spread
    spec_min = np.min(spectrogram, axis=0)
    spec_max = np.max(spectrogram, axis=0)
    spec_range = spec_max - spec_min
    spec_var = np.var(spectrogram, axis=0)
    spec_std = np.std(spectrogram, axis=0)

    # percentiles
    spec_first_quart = np.percentile(spectrogram, 25, axis=0)
    spec_third_quart = np.percentile(spectrogram, 75, axis=0)
    spec_inter_quart_range  = spec_third_quart - spec_first_quart

    # morphology
    spec_entropy = entropy(spectrogram, axis=0)
    spec_kurt = kurt(spectrogram, axis=0)
    spec_skew = skew(spectrogram, axis=0)

    return (
        spec_mean, 
        spec_median, 
        spec_mode, 
        spec_mode_cnt, 
        spec_min, 
        spec_max, 
        spec_range, 
        spec_var, 
        spec_std, 
        spec_first_quart, 
        spec_third_quart, 
        spec_inter_quart_range, 
        spec_entropy, 
        spec_kurt, 
        spec_skew
    )

def compute_statistical_features(conn, subject_table, samples_per_win_size, samples_per_hop_size):
    print("Computing statistical features...")

    # count = conn.sql("""
    #     SELECT COUNT(rowId) FROM subject_table
    # """).fetchall()[-1][-1]

    conn.sql(f"""
        CREATE OR REPLACE TEMPORARY TABLE subject_features AS (
            SELECT
                subject_id, 
                signals, 
                file_row_number,
                file_name,
                loaded_at,
                
                KURTOSIS(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_kurt,
                SKEWNESS(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_skew,
                ENTROPY(signals)OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_entropy,
                AVG(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_mean,
                MEDIAN(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_median,
                MODE(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_mode,
                MIN(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_min,
                MAX(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_max,
                VAR_SAMP(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_var,
                STDDEV_SAMP(signals) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_stddev,
                QUANTILE_CONT(signals, 0.25) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_first_quart,
                QUANTILE_CONT(signals, 0.75) OVER(PARTITION BY file_name ORDER BY file_row_number ROWS BETWEEN CURRENT ROW AND {samples_per_win_size - 1} FOLLOWING) AS freq_third_quart
            FROM subject_table
            WHERE (file_row_number % {samples_per_hop_size}) = 0
            ORDER BY file_row_number
        )
    """)

    conn.sql(f"""
        CREATE OR REPLACE TEMPORARY TABLE subject_features AS (
            SELECT 
                *,
                (freq_max - freq_min) AS freq_range,
                (freq_third_quart - freq_first_quart) AS freq_inter_quart_range
            FROM subject_features
        )
    """)

    subject_features = conn.sql(f"""
        SELECT * FROM subject_features
    """).to_arrow_table()

    return subject_features

def compute_spectral_features(subject_features, x_signals, hertz, samples_per_win_size, samples_per_hop_size, n_frames):
    """
    computes spectral features of audio signals using
    librosa library
    """
    
    print("Calculating spectral features...")

    # note a center of false still doesn't work to get librosa 
    # feature functions to calculate features the size of our 
    # statistical features so we must use the last value of these 
    # resulting features as padding to match thevlength of our 
    # statistical features. E.g. statiscal feature table has shape
    # (28, 19) and computed librosa feature like zcr has (1, 24)
    # then we have to subtract 28 - 24 = 4 and 4 will be the number
    # of values we need to pad to the zcr feature using this 
    # features last vlue
    zcr = librosa.feature.zero_crossing_rate(
        y=x_signals, 
        frame_length=samples_per_win_size, 
        hop_length=samples_per_hop_size,
    )[:, :n_frames]
    print(f"ZCR shape: {zcr.shape}")
    zcr = align_spectral_features_length(zcr, n_frames, pad_mode='edge')
    print(f"ZCR shape: {zcr.shape}")
    print(zcr[:, zcr.shape[1] - 5:])
    
    poly_feats = librosa.feature.poly_features(
        y=x_signals, 
        sr=hertz, 
        n_fft=samples_per_win_size, 
        hop_length=samples_per_hop_size
    )[:, :n_frames]
    poly_feats = align_spectral_features_length(poly_feats, n_frames, pad_mode='edge')
    print(f"Poly shape: {poly_feats.shape}")

    mel_spec = librosa.feature.melspectrogram(
        y=x_signals, 
        sr=hertz, 
        n_fft=samples_per_win_size, 
        hop_length=samples_per_hop_size, 
        n_mels=90
    )[:, :n_frames]
    mel_spec = align_spectral_features_length(mel_spec, n_frames, pad_mode='edge')
    mel_spec_mean, \
    mel_spec_median, \
    mel_spec_mode, \
    mel_spec_mode_cnt, \
    mel_spec_min, \
    mel_spec_max, \
    mel_spec_range, \
    mel_spec_var, \
    mel_spec_std, \
    mel_spec_first_quart, \
    mel_spec_third_quart, \
    mel_spec_inter_quart_range, \
    mel_spec_entropy, \
    mel_spec_kurt, \
    mel_spec_skew = extract_spectrogram_stats(mel_spec)
    print(f"Mel Spectrogram shape: {mel_spec.shape}")

    mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
    mel_spec_db = align_spectral_features_length(mel_spec_db, n_frames, pad_mode='edge')
    mel_spec_db_mean, \
    mel_spec_db_median, \
    mel_spec_db_mode, \
    mel_spec_db_mode_cnt, \
    mel_spec_db_min, \
    mel_spec_db_max, \
    mel_spec_db_range, \
    mel_spec_db_var, \
    mel_spec_db_std, \
    mel_spec_db_first_quart, \
    mel_spec_db_third_quart, \
    mel_spec_db_inter_quart_range, \
    mel_spec_db_entropy, \
    mel_spec_db_kurt, \
    mel_spec_db_skew = extract_spectrogram_stats(mel_spec_db)
    print(f"Mel Spectrogram DB shape: {mel_spec_db.shape}")

    mfcc = librosa.feature.mfcc(
        y=x_signals, 
        sr=hertz, 
        n_fft=samples_per_win_size, 
        hop_length=samples_per_hop_size, n_mfcc=90
    )[:, :n_frames]
    mfcc = align_spectral_features_length(mfcc, n_frames, pad_mode='edge')
    mfcc_mean, \
    mfcc_median, \
    mfcc_mode, \
    mfcc_mode_cnt, \
    mfcc_min, \
    mfcc_max, \
    mfcc_range, \
    mfcc_var, \
    mfcc_std, \
    mfcc_first_quart, \
    mfcc_third_quart, \
    mfcc_inter_quart_range, \
    mfcc_entropy, \
    mfcc_kurt, \
    mfcc_skew = extract_spectrogram_stats(mfcc)
    print(f"MFCC shape: {mfcc.shape}")
    
    spec_cont = librosa.feature.spectral_contrast(
        y=x_signals, 
        sr=hertz, 
        n_fft=samples_per_win_size, 
        hop_length=samples_per_hop_size
    )[:, :n_frames]
    spec_cont = align_spectral_features_length(spec_cont, n_frames, pad_mode='edge')
    spec_cont_mean, \
    spec_cont_median, \
    spec_cont_mode, \
    spec_cont_mode_cnt, \
    spec_cont_min, \
    spec_cont_max, \
    spec_cont_range, \
    spec_cont_var, \
    spec_cont_std, \
    spec_cont_first_quart, \
    spec_cont_third_quart, \
    spec_cont_inter_quart_range, \
    spec_cont_entropy, \
    spec_cont_kurt, \
    spec_cont_skew = extract_spectrogram_stats(spec_cont)
    print(f"spectral contrast shape: {zcr.shape}")

    spec_cent = librosa.feature.spectral_centroid(
        y=x_signals, 
        sr=hertz, 
        n_fft=samples_per_win_size, 
        hop_length=samples_per_hop_size
    )[:, :n_frames]
    spec_cent = align_spectral_features_length(spec_cent, n_frames, pad_mode='edge')
    print(f"Spectral centroid shape: {spec_cent.shape}")

    spec_bw = librosa.feature.spectral_bandwidth(
        y=x_signals, 
        sr=hertz, 
        n_fft=samples_per_win_size, 
        hop_length=samples_per_hop_size
    )[:, :n_frames]
    spec_bw = align_spectral_features_length(spec_bw, n_frames, pad_mode='edge')
    print(f"Spectral bandwidth shape: {spec_bw.shape}")

    spec_flat = librosa.feature.spectral_flatness(
        y=x_signals, 
        n_fft=samples_per_win_size, 
        hop_length=samples_per_hop_size
    )[:, :n_frames]
    spec_flat = align_spectral_features_length(spec_flat, n_frames, pad_mode='edge')
    print(f"Spectral flatness shape: {spec_flat.shape}")

    spec_roll = librosa.feature.spectral_rolloff(
        y=x_signals, 
        sr=hertz, 
        n_fft=samples_per_win_size, 
        hop_length=samples_per_hop_size
    )[:, :n_frames]
    spec_roll = align_spectral_features_length(spec_roll, n_frames, pad_mode='edge')
    print(f"Spectral rolloff shape: {spec_roll.shape}")

    # add the newly computed spectographic and chromagraphic
    # features as columns
    subject_features = subject_features.append_column("zcr", [zcr.reshape(-1)])
    subject_features = subject_features.append_column("poly_feat_1", [poly_feats[0, :]])
    subject_features = subject_features.append_column("poly_feat_2", [poly_feats[1, :]])
    subject_features = subject_features.append_column("spec_cent", [spec_cent.reshape(-1)])
    subject_features = subject_features.append_column("spec_bw", [spec_bw.reshape(-1)])
    subject_features = subject_features.append_column("spec_flat", [spec_flat.reshape(-1)])
    subject_features = subject_features.append_column("spec_roll", [spec_roll.reshape(-1)])

    subject_features = subject_features.append_column("mel_spec_mean", [mel_spec_mean])
    subject_features = subject_features.append_column("mel_spec_median", [mel_spec_median])
    subject_features = subject_features.append_column("mel_spec_mode", [mel_spec_mode])
    subject_features = subject_features.append_column("mel_spec_mode_cnt", [mel_spec_mode_cnt])
    subject_features = subject_features.append_column("mel_spec_min", [mel_spec_min])
    subject_features = subject_features.append_column("mel_spec_max", [mel_spec_max])
    subject_features = subject_features.append_column("mel_spec_range", [mel_spec_range])
    subject_features = subject_features.append_column("mel_spec_var", [mel_spec_var])
    subject_features = subject_features.append_column("mel_spec_std", [mel_spec_std])
    subject_features = subject_features.append_column("mel_spec_first_quart", [mel_spec_first_quart])
    subject_features = subject_features.append_column("mel_spec_third_quart", [mel_spec_third_quart])
    subject_features = subject_features.append_column("mel_spec_inter_quart_range", [mel_spec_inter_quart_range])
    subject_features = subject_features.append_column("mel_spec_entropy", [mel_spec_entropy])
    subject_features = subject_features.append_column("mel_spec_kurt", [mel_spec_kurt])
    subject_features = subject_features.append_column("mel_spec_skew", [mel_spec_skew])

    subject_features = subject_features.append_column("mel_spec_db_mean", [mel_spec_db_mean])
    subject_features = subject_features.append_column("mel_spec_db_median", [mel_spec_db_median])
    subject_features = subject_features.append_column("mel_spec_db_mode", [mel_spec_db_mode])
    subject_features = subject_features.append_column("mel_spec_db_mode_cnt", [mel_spec_db_mode_cnt])
    subject_features = subject_features.append_column("mel_spec_db_min", [mel_spec_db_min])
    subject_features = subject_features.append_column("mel_spec_db_max", [mel_spec_db_max])
    subject_features = subject_features.append_column("mel_spec_db_range", [mel_spec_db_range])
    subject_features = subject_features.append_column("mel_spec_db_var", [mel_spec_db_var])
    subject_features = subject_features.append_column("mel_spec_db_std", [mel_spec_db_std])
    subject_features = subject_features.append_column("mel_spec_db_first_quart", [mel_spec_db_first_quart])
    subject_features = subject_features.append_column("mel_spec_db_third_quart", [mel_spec_db_third_quart])
    subject_features = subject_features.append_column("mel_spec_db_inter_quart_range", [mel_spec_db_inter_quart_range])
    subject_features = subject_features.append_column("mel_spec_db_entropy", [mel_spec_db_entropy])
    subject_features = subject_features.append_column("mel_spec_db_kurt", [mel_spec_db_kurt])
    subject_features = subject_features.append_column("mel_spec_db_skew", [mel_spec_db_skew])

    subject_features = subject_features.append_column("mfcc_mean", [mfcc_mean])
    subject_features = subject_features.append_column("mfcc_median", [mfcc_median])
    subject_features = subject_features.append_column("mfcc_mode", [mfcc_mode])
    subject_features = subject_features.append_column("mfcc_mode_cnt", [mfcc_mode_cnt])
    subject_features = subject_features.append_column("mfcc_min", [mfcc_min])
    subject_features = subject_features.append_column("mfcc_max", [mfcc_max])
    subject_features = subject_features.append_column("mfcc_range", [mfcc_range])
    subject_features = subject_features.append_column("mfcc_var", [mfcc_var])
    subject_features = subject_features.append_column("mfcc_std", [mfcc_std])
    subject_features = subject_features.append_column("mfcc_first_quart", [mfcc_first_quart])
    subject_features = subject_features.append_column("mfcc_third_quart", [mfcc_third_quart])
    subject_features = subject_features.append_column("mfcc_inter_quart_range", [mfcc_inter_quart_range])
    subject_features = subject_features.append_column("mfcc_entropy", [mfcc_entropy])
    subject_features = subject_features.append_column("mfcc_kurt", [mfcc_kurt])
    subject_features = subject_features.append_column("mfcc_skew", [mfcc_skew])

    subject_features = subject_features.append_column("spec_cont_mean", [spec_cont_mean])
    subject_features = subject_features.append_column("spec_cont_median", [spec_cont_median])
    subject_features = subject_features.append_column("spec_cont_mode", [spec_cont_mode])
    subject_features = subject_features.append_column("spec_cont_mode_cnt", [spec_cont_mode_cnt])
    subject_features = subject_features.append_column("spec_cont_min", [spec_cont_min])
    subject_features = subject_features.append_column("spec_cont_max", [spec_cont_max])
    subject_features = subject_features.append_column("spec_cont_range", [spec_cont_range])
    subject_features = subject_features.append_column("spec_cont_var", [spec_cont_var])
    subject_features = subject_features.append_column("spec_cont_std", [spec_cont_std])
    subject_features = subject_features.append_column("spec_cont_first_quart", [spec_cont_first_quart])
    subject_features = subject_features.append_column("spec_cont_third_quart", [spec_cont_third_quart])
    subject_features = subject_features.append_column("spec_cont_inter_quart_range", [spec_cont_inter_quart_range])
    subject_features = subject_features.append_column("spec_cont_entropy", [spec_cont_entropy])
    subject_features = subject_features.append_column("spec_cont_kurt", [spec_cont_kurt])
    subject_features = subject_features.append_column("spec_cont_skew", [spec_cont_skew])

    return subject_features


def transform_signals(
    signal_file_paths, 
    data_dir, 
    hertz: int=16000, 
    window_time: int=3, 
    hop_time: int=1, 
    storage_account_name: str=None, 
    credential: str=None,
):
    """
    concurrently extracts the features of each signal
    the first half of feature extraction involves using
    sql for computing statistical features of the subjects
    signals

    the second half involves using librosa for computing
    for instance spectral features of the sujects signals
    as there is not supported function to compute audio
    specific signal features like spectrograms, chromagrams,
    tempogram, etc.
    """
    
    # we calculate the window size of each segment or the
    # amount of samples it has to have based on the frequency
    samples_per_win_size = int(window_time * hertz)
    samples_per_hop_size = int(hop_time * hertz)

    # # connect to in memory db
    # conn = duckdb.connect()

    if storage_account_name and credential:
        handler = pa_adl.AccountHandler.from_account_name(storage_account_name, credential=credential)
        fs = pa.fs.PyFileSystem(handler)

    def helper(signal_file_path):
        
        try:
            # connect to in memory db
            conn = duckdb.connect()

            # extract subject name from file path
            subject_id = signal_file_path.split("/")[-2]
            subject_file_id = signal_file_path.split("/")[-1]
            subject_index = int(re.findall(r"\d+", signal_file_path)[-1]) if len(re.findall(r"\d+", signal_file_path)) != 0 else random.randint(1000, 9999)
            print(f"Subject {subject_id} with subject index {subject_index} is processing...")

            # read subjects table and it ssignals
            if storage_account_name and credential:
                # cloud
                subject_table = pq.read_table(signal_file_path, filesystem=fs)
            else:
                # local reads a path like this
                # '../../include/data/silver/stage-01/1337ad-20170321-ajg/signals_0.parquet'
                subject_table = pq.read_table(signal_file_path)
                
            x_signals = subject_table["signals"].to_numpy()

            # calculate statistical features
            subject_features = compute_statistical_features(
                conn,
                subject_table, 
                samples_per_win_size, 
                samples_per_hop_size
            )
            print(f"subject statistical features shape: {subject_features.shape}")

            # get the number of frames used using a window of 48000
            # and hop length of 16000
            n_frames = subject_features.shape[0]
            print(f"Number of frames: {n_frames}")

            # compute spectographic and chromagraphic features
            subject_features = compute_spectral_features(
                subject_features, 
                x_signals, 
                hertz, 
                samples_per_win_size, 
                samples_per_hop_size, 
                n_frames
            )
            
            # create dedicated folder of subject containing all
            # its features for each of its signals derived from
            # individual wav file
            # ../../include/data/silver/stage-02 + <subject_id>
            save_dir = os.path.join(data_dir, subject_id).replace("\\", "/")
            
            # create save path
            # ../../include/data/silver/stage-02/<subject_id>/features_0.parquet
            save_path = os.path.join(save_dir, f"features_{subject_index}.parquet").replace("\\", "/")
            
            if storage_account_name and credential:
                pq.write_table(subject_features, save_path, filesystem=fs)
            else:
                # make directory where subject features wil lbe saved
                os.makedirs(save_dir, exist_ok=True)
                
                # write table to a 2nd sub stage in silver staging layer 
                pq.write_table(subject_features, save_path)

        except Exception as e:
            print(f"error {e} occured on subject id {subject_id} and file {subject_file_id}")
            
            # return the last subjects features
            return subject_id, e

    # concurrently calculate statistical features and spectral
    # features of each subject using DuckDB SQL and librosa
    with ThreadPoolExecutor(max_workers=2) as exe:
        subjects_features_list = list(exe.map(helper, signal_file_paths))

    return subjects_features_list

# %%
# local
SAVE_DIR = SILVER_DATA_DIR.format(
    DATA_DIR=DATA_DIR,
    FOLDER_NAME=SILVER_FOLDER_NAME,
    SUB_FOLDER_NAME="stage-02"
)
SAVE_DIR

# # cloud
# SAVE_DIR = SILVER_DATA_DIR.format(
#     FOLDER_NAME=SILVER_FOLDER_NAME,
#     SUB_FOLDER_NAME="stage-02"
# )
# SAVE_DIR
# Out:
# '../../include/data/silver/stage-02'

# %%
signal_file_paths[7:10]
# Out:
# ['../../include/data/silver/stage-01/1028-20100710-hne/signals_7.parquet',
#  '../../include/data/silver/stage-01/1028-20100710-hne/signals_8.parquet',
#  '../../include/data/silver/stage-01/1028-20100710-hne/signals_9.parquet']

# %%
# local
subjects_features = transform_signals(signal_file_paths, SAVE_DIR, storage_account_name=None, credential=None)
# Out:
# Subject 1028-20100710-hne with subject index 0 is processing...
# Subject 1028-20100710-hne with subject index 1 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# ZCR shape: (1, 4)
# ZCR shape: (1, 4)
# [[0.059375]]
# Computing statistical features...
# Poly shape: (2, 4)
# subject statistical features shape: (7, 19)
# Number of frames: 7
# Calculating spectral features...
# ZCR shape: (1, 7)
# ZCR shape: (1, 7)
# [[0.079      0.07977083 0.09695833 0.0995625  0.08139583]]
# Poly shape: (2, 7)
# Mel Spectrogram shape: (90, 4)
# Mel Spectrogram DB shape: (90, 4)
# Mel Spectrogram shape: (90, 7)
# Mel Spectrogram DB shape: (90, 7)
# MFCC shape: (90, 4)
# spectral contrast shape: (1, 4)
# Spectral centroid shape: (1, 4)
# Spectral bandwidth shape: (1, 4)
# MFCC shape: (90, 7)
# Spectral flatness shape: (1, 4)
# Spectral rolloff shape: (1, 4)
# spectral contrast shape: (1, 7)
# Spectral centroid shape: (1, 7)
# Subject 1028-20100710-hne with subject index 2 is processing...
# Spectral bandwidth shape: (1, 7)
# Spectral flatness shape: (1, 7)
# Computing statistical features...
# Spectral rolloff shape: (1, 7)
# subject statistical features shape: (11, 19)
# Number of frames: 11
# Calculating spectral features...
# ZCR shape: (1, 11)
# ZCR shape: (1, 11)
# [[0.09516667 0.0924375  0.085125   0.1028125  0.07283333]]
# Poly shape: (2, 11)
# Subject 1028-20100710-hne with subject index 3 is processing...
# Computing statistical features...
# Mel Spectrogram shape: (90, 11)
# Mel Spectrogram DB shape: (90, 11)
# subject statistical features shape: (15, 19)
# Number of frames: 15
# Calculating spectral features...
# ZCR shape: (1, 15)
# ZCR shape: (1, 15)
# [[0.0898125  0.11229167 0.1269375  0.13870833 0.10222917]]
# Poly shape: (2, 15)
# MFCC shape: (90, 11)
# spectral contrast shape: (1, 11)
# Mel Spectrogram shape: (90, 15)
# Mel Spectrogram DB shape: (90, 15)
# Spectral centroid shape: (1, 11)
# Spectral bandwidth shape: (1, 11)
# Spectral flatness shape: (1, 11)
# Spectral rolloff shape: (1, 11)
# MFCC shape: (90, 15)
# Subject 1028-20100710-hne with subject index 4 is processing...
# spectral contrast shape: (1, 15)
# Spectral centroid shape: (1, 15)
# Computing statistical features...
# Spectral bandwidth shape: (1, 15)
# subject statistical features shape: (19, 19)
# Number of frames: 19
# Calculating spectral features...
# ZCR shape: (1, 19)
# ZCR shape: (1, 19)
# [[0.12516667 0.09633333 0.09785417 0.09364583 0.0750625 ]]
# Spectral flatness shape: (1, 15)
# Spectral rolloff shape: (1, 15)
# Poly shape: (2, 19)
# Subject 1028-20100710-hne with subject index 5 is processing...
# Mel Spectrogram shape: (90, 19)
# Mel Spectrogram DB shape: (90, 19)
# Computing statistical features...
# subject statistical features shape: (22, 19)
# Number of frames: 22
# Calculating spectral features...
# ZCR shape: (1, 22)
# ZCR shape: (1, 22)
# [[0.09364583 0.0918125  0.07739583 0.093375   0.065875  ]]
# MFCC shape: (90, 19)
# Poly shape: (2, 22)
# spectral contrast shape: (1, 19)
# Spectral centroid shape: (1, 19)
# Mel Spectrogram shape: (90, 22)
# Mel Spectrogram DB shape: (90, 22)
# Spectral bandwidth shape: (1, 19)
# Spectral flatness shape: (1, 19)
# MFCC shape: (90, 22)
# Spectral rolloff shape: (1, 19)
# spectral contrast shape: (1, 22)
# Subject 1028-20100710-hne with subject index 6 is processing...
# Spectral centroid shape: (1, 22)
# Computing statistical features...
# subject statistical features shape: (25, 19)
# Number of frames: 25
# Calculating spectral features...
# ZCR shape: (1, 24)
# ZCR shape: (1, 25)
# [[0.10247917 0.10316667 0.10870833 0.06710417 0.06710417]]
# Spectral bandwidth shape: (1, 22)
# Spectral flatness shape: (1, 22)
# Poly shape: (2, 25)
# Spectral rolloff shape: (1, 22)
# Mel Spectrogram shape: (90, 25)
# Subject 1028-20100710-hne with subject index 7 is processing...
# Mel Spectrogram DB shape: (90, 25)
# Computing statistical features...
# MFCC shape: (90, 25)
# subject statistical features shape: (28, 19)
# Number of frames: 28
# Calculating spectral features...
# ZCR shape: (1, 27)
# ZCR shape: (1, 28)
# [[0.1055     0.102875   0.11914583 0.07408333 0.07408333]]
# spectral contrast shape: (1, 25)
# Poly shape: (2, 28)
# Spectral centroid shape: (1, 25)
# Mel Spectrogram shape: (90, 28)
# Spectral bandwidth shape: (1, 25)
# Mel Spectrogram DB shape: (90, 28)
# Spectral flatness shape: (1, 25)
# Spectral rolloff shape: (1, 25)
# MFCC shape: (90, 28)
# Subject 1028-20100710-hne with subject index 8 is processing...
# spectral contrast shape: (1, 28)
# Computing statistical features...
# Spectral centroid shape: (1, 28)
# subject statistical features shape: (33, 19)
# Number of frames: 33
# Calculating spectral features...
# ZCR shape: (1, 31)
# ZCR shape: (1, 33)
# [[0.10072917 0.0833125  0.06589583 0.06589583 0.06589583]]
# Spectral bandwidth shape: (1, 28)
# Poly shape: (2, 33)
# Spectral flatness shape: (1, 28)
# Spectral rolloff shape: (1, 28)
# Mel Spectrogram shape: (90, 33)
# Mel Spectrogram DB shape: (90, 33)
# Subject 1028-20100710-hne with subject index 9 is processing...
# MFCC shape: (90, 33)
# Computing statistical features...
# subject statistical features shape: (35, 19)
# Number of frames: 35
# Calculating spectral features...
# ZCR shape: (1, 33)
# ZCR shape: (1, 35)
# [[0.08195833 0.0645     0.040625   0.040625   0.040625  ]]
# spectral contrast shape: (1, 33)
# Poly shape: (2, 35)
# Spectral centroid shape: (1, 33)
# Mel Spectrogram shape: (90, 35)
# Mel Spectrogram DB shape: (90, 35)
# Spectral bandwidth shape: (1, 33)
# Spectral flatness shape: (1, 33)
# Spectral rolloff shape: (1, 33)
# MFCC shape: (90, 35)
# Subject 1337ad-20170321-ajg with subject index 0 is processing...
# spectral contrast shape: (1, 35)Computing statistical features...
#
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# ZCR shape: (1, 3)
# ZCR shape: (1, 3)
# [[0.03866667 0.02910417]]
# Poly shape: (2, 3)
# Spectral centroid shape: (1, 35)
# Mel Spectrogram shape: (90, 3)
# Mel Spectrogram DB shape: (90, 3)
# MFCC shape: (90, 3)
# spectral contrast shape: (1, 3)
# Spectral centroid shape: (1, 3)
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=44032
#   warnings.warn(
# Spectral bandwidth shape: (1, 35)
# Spectral bandwidth shape: (1, 3)
# Spectral flatness shape: (1, 3)
# Spectral rolloff shape: (1, 3)
# Spectral flatness shape: (1, 35)
# Subject 1337ad-20170321-ajg with subject index 1 is processing...
# Computing statistical features...
# Spectral rolloff shape: (1, 35)
# subject statistical features shape: (9, 19)
# Number of frames: 9
# Calculating spectral features...
# ZCR shape: (1, 8)
# ZCR shape: (1, 9)
# [[0.06025    0.0638125  0.0581875  0.03789583 0.03789583]]
# Poly shape: (2, 9)
# Subject 1337ad-20170321-ajg with subject index 2 is processing...
# Computing statistical features...
# Mel Spectrogram shape: (90, 9)
# Mel Spectrogram DB shape: (90, 9)
# subject statistical features shape: (12, 19)
# Number of frames: 12
# Calculating spectral features...
# ZCR shape: (1, 11)
# ZCR shape: (1, 12)
# [[0.04625    0.04516667 0.03945833 0.03039583 0.03039583]]
# Poly shape: (2, 12)
# MFCC shape: (90, 9)
# spectral contrast shape: (1, 9)
# Spectral centroid shape: (1, 9)
# Mel Spectrogram shape: (90, 12)
# Mel Spectrogram DB shape: (90, 12)
# Spectral bandwidth shape: (1, 9)
# Spectral flatness shape: (1, 9)
# Spectral rolloff shape: (1, 9)
# MFCC shape: (90, 12)
# Subject 1337ad-20170321-ajg with subject index 3 is processing...
# spectral contrast shape: (1, 12)
# Computing statistical features...
# Spectral centroid shape: (1, 12)
# subject statistical features shape: (17, 19)
# Number of frames: 17
# Calculating spectral features...
# Spectral bandwidth shape: (1, 12)
# ZCR shape: (1, 15)
# ZCR shape: (1, 17)
# [[0.05341667 0.05179167 0.03779167 0.03779167 0.03779167]]
# Spectral flatness shape: (1, 12)
# Poly shape: (2, 17)
# Spectral rolloff shape: (1, 12)
# Subject 1337ad-20170321-ajg with subject index 4 is processing...
# Mel Spectrogram shape: (90, 17)
# Mel Spectrogram DB shape: (90, 17)
# Computing statistical features...
# MFCC shape: (90, 17)
# subject statistical features shape: (21, 19)
# Number of frames: 21
# Calculating spectral features...
# ZCR shape: (1, 18)
# ZCR shape: (1, 21)
# [[0.06958333 0.04725    0.04725    0.04725    0.04725   ]]
# spectral contrast shape: (1, 17)
# Poly shape: (2, 21)
# Spectral centroid shape: (1, 17)
# Spectral bandwidth shape: (1, 17)
# Mel Spectrogram shape: (90, 21)
# Mel Spectrogram DB shape: (90, 21)
# Spectral flatness shape: (1, 17)
# Spectral rolloff shape: (1, 17)
# MFCC shape: (90, 21)
# Subject 1337ad-20170321-ajg with subject index 5 is processing...
# spectral contrast shape: (1, 21)
# Computing statistical features...
# Spectral centroid shape: (1, 21)
# subject statistical features shape: (25, 19)
# Number of frames: 25
# Calculating spectral features...
# ZCR shape: (1, 21)
# ZCR shape: (1, 25)
# [[0.0351875 0.0351875 0.0351875 0.0351875 0.0351875]]
# Spectral bandwidth shape: (1, 21)
# Poly shape: (2, 25)
# Spectral flatness shape: (1, 21)
# Spectral rolloff shape: (1, 21)
# Mel Spectrogram shape: (90, 25)
# Mel Spectrogram DB shape: (90, 25)
# Subject 1337ad-20170321-ajg with subject index 6 is processing...
# Computing statistical features...
# MFCC shape: (90, 25)
# spectral contrast shape: (1, 25)
# subject statistical features shape: (28, 19)
# Number of frames: 28
# Calculating spectral features...
# ZCR shape: (1, 23)
# ZCR shape: (1, 28)
# [[0.02477083 0.02477083 0.02477083 0.02477083 0.02477083]]
# Spectral centroid shape: (1, 25)
# Poly shape: (2, 28)
# Spectral bandwidth shape: (1, 25)
# Spectral flatness shape: (1, 25)
# Mel Spectrogram shape: (90, 28)
# Mel Spectrogram DB shape: (90, 28)
# Spectral rolloff shape: (1, 25)
# Subject 1337ad-20170321-ajg with subject index 7 is processing...
# MFCC shape: (90, 28)
# spectral contrast shape: (1, 28)
# Computing statistical features...
# Spectral centroid shape: (1, 28)
# subject statistical features shape: (33, 19)
# Number of frames: 33
# Calculating spectral features...
# ZCR shape: (1, 28)
# ZCR shape: (1, 33)
# [[0.01552083 0.01552083 0.01552083 0.01552083 0.01552083]]
# Poly shape: (2, 33)
# Spectral bandwidth shape: (1, 28)
# Spectral flatness shape: (1, 28)
# Spectral rolloff shape: (1, 28)
# Mel Spectrogram shape: (90, 33)
# Mel Spectrogram DB shape: (90, 33)
# Subject 1337ad-20170321-ajg with subject index 8 is processing...
# Computing statistical features...
# MFCC shape: (90, 33)
# spectral contrast shape: (1, 33)
# subject statistical features shape: (38, 19)
# Number of frames: 38
# Calculating spectral features...
# ZCR shape: (1, 32)
# ZCR shape: (1, 38)
# [[0.03545833 0.03545833 0.03545833 0.03545833 0.03545833]]
# Spectral centroid shape: (1, 33)
# Poly shape: (2, 38)
# Spectral bandwidth shape: (1, 33)
# Mel Spectrogram shape: (90, 38)
# Mel Spectrogram DB shape: (90, 38)
# Spectral flatness shape: (1, 33)
# Spectral rolloff shape: (1, 33)
# MFCC shape: (90, 38)
# Subject 1337ad-20170321-ajg with subject index 9 is processing...
# spectral contrast shape: (1, 38)
# Computing statistical features...
# Spectral centroid shape: (1, 38)
# subject statistical features shape: (43, 19)
# Number of frames: 43
# Calculating spectral features...
# ZCR shape: (1, 36)
# ZCR shape: (1, 43)
# [[0.03666667 0.03666667 0.03666667 0.03666667 0.03666667]]
# Spectral bandwidth shape: (1, 38)
# Poly shape: (2, 43)
# Spectral flatness shape: (1, 38)
# Spectral rolloff shape: (1, 38)
# Mel Spectrogram shape: (90, 43)
# Mel Spectrogram DB shape: (90, 43)
# Subject 1337ad-20170321-tkg with subject index 0 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# ZCR shape: (1, 4)
# ZCR shape: (1, 4)
# [[0.03129167]]
# Poly shape: (2, 4)
# MFCC shape: (90, 43)
# Mel Spectrogram shape: (90, 4)
# Mel Spectrogram DB shape: (90, 4)
# spectral contrast shape: (1, 43)
# MFCC shape: (90, 4)
# spectral contrast shape: (1, 4)
# Spectral centroid shape: (1, 4)
# Spectral bandwidth shape: (1, 4)
# Spectral flatness shape: (1, 4)
# Spectral centroid shape: (1, 43)
# Spectral rolloff shape: (1, 4)
# Subject 1337ad-20170321-tkg with subject index 1 is processing...
# Computing statistical features...
# subject statistical features shape: (9, 19)
# Number of frames: 9
# Calculating spectral features...
# ZCR shape: (1, 8)
# ZCR shape: (1, 9)
# [[0.03808333 0.053      0.05739583 0.0449375  0.0449375 ]]
# Spectral bandwidth shape: (1, 43)
# Poly shape: (2, 9)
# Spectral flatness shape: (1, 43)
# Mel Spectrogram shape: (90, 9)
# Mel Spectrogram DB shape: (90, 9)
# Spectral rolloff shape: (1, 43)
# MFCC shape: (90, 9)
# Subject 1337ad-20170321-tkg with subject index 2 is processing...
# spectral contrast shape: (1, 9)
# Computing statistical features...
# Spectral centroid shape: (1, 9)
# subject statistical features shape: (14, 19)
# Number of frames: 14
# Calculating spectral features...
# Spectral bandwidth shape: (1, 9)
# ZCR shape: (1, 13)
# ZCR shape: (1, 14)
# [[0.04583333 0.04708333 0.04647917 0.0256875  0.0256875 ]]
# Spectral flatness shape: (1, 9)
# Spectral rolloff shape: (1, 9)
# Poly shape: (2, 14)
# Subject 1337ad-20170321-tkg with subject index 3 is processing...
# Mel Spectrogram shape: (90, 14)
# Mel Spectrogram DB shape: (90, 14)
# Computing statistical features...
# subject statistical features shape: (18, 19)
# Number of frames: 18
# Calculating spectral features...
# ZCR shape: (1, 17)
# ZCR shape: (1, 18)
# [[0.0563125  0.0645     0.05172917 0.02791667 0.02791667]]
# MFCC shape: (90, 14)
# Poly shape: (2, 18)
# spectral contrast shape: (1, 14)
# Spectral centroid shape: (1, 14)
# Mel Spectrogram shape: (90, 18)
# Mel Spectrogram DB shape: (90, 18)
# Spectral bandwidth shape: (1, 14)
# Spectral flatness shape: (1, 14)
# Spectral rolloff shape: (1, 14)
# MFCC shape: (90, 18)
# Subject 1337ad-20170321-tkg with subject index 4 is processing...
# spectral contrast shape: (1, 18)
# Computing statistical features...
# Spectral centroid shape: (1, 18)
# subject statistical features shape: (22, 19)
# Number of frames: 22
# Calculating spectral features...
# ZCR shape: (1, 20)
# ZCR shape: (1, 22)
# [[0.03445833 0.02585417 0.01358333 0.01358333 0.01358333]]
# Spectral bandwidth shape: (1, 18)
# Spectral flatness shape: (1, 18)
# Poly shape: (2, 22)
# Spectral rolloff shape: (1, 18)
# Mel Spectrogram shape: (90, 22)
# Subject 1337ad-20170321-tkg with subject index 5 is processing...
# Mel Spectrogram DB shape: (90, 22)
# Computing statistical features...
# MFCC shape: (90, 22)
# subject statistical features shape: (24, 19)
# Number of frames: 24
# Calculating spectral features...
# ZCR shape: (1, 22)
# ZCR shape: (1, 24)
# [[0.0465625 0.040875  0.032625  0.032625  0.032625 ]]
# spectral contrast shape: (1, 22)
# Poly shape: (2, 24)
# Spectral centroid shape: (1, 22)
# Spectral bandwidth shape: (1, 22)
# Mel Spectrogram shape: (90, 24)
# Mel Spectrogram DB shape: (90, 24)
# Spectral flatness shape: (1, 22)
# Spectral rolloff shape: (1, 22)
# MFCC shape: (90, 24)
# Subject 1337ad-20170321-tkg with subject index 6 is processing...
# spectral contrast shape: (1, 24)
# Computing statistical features...
# Spectral centroid shape: (1, 24)
# subject statistical features shape: (26, 19)
# Number of frames: 26
# Calculating spectral features...
# ZCR shape: (1, 23)
# ZCR shape: (1, 26)
# [[0.05591667 0.03239583 0.03239583 0.03239583 0.03239583]]
# Poly shape: (2, 26)
# Spectral bandwidth shape: (1, 24)
# Spectral flatness shape: (1, 24)
# Spectral rolloff shape: (1, 24)
# Mel Spectrogram shape: (90, 26)
# Mel Spectrogram DB shape: (90, 26)
# Subject 1337ad-20170321-tkg with subject index 7 is processing...
# MFCC shape: (90, 26)
# Computing statistical features...
# spectral contrast shape: (1, 26)
# subject statistical features shape: (31, 19)
# Number of frames: 31
# Calculating spectral features...
# ZCR shape: (1, 28)
# ZCR shape: (1, 31)
# [[0.0474375 0.0293125 0.0293125 0.0293125 0.0293125]]
# Spectral centroid shape: (1, 26)
# Poly shape: (2, 31)
# Spectral bandwidth shape: (1, 26)
# Spectral flatness shape: (1, 26)
# Mel Spectrogram shape: (90, 31)
# Spectral rolloff shape: (1, 26)
# Mel Spectrogram DB shape: (90, 31)
# Subject 1337ad-20170321-tkg with subject index 8 is processing...
# MFCC shape: (90, 31)
# Computing statistical features...
# spectral contrast shape: (1, 31)
# subject statistical features shape: (36, 19)
# Number of frames: 36
# Calculating spectral features...
# ZCR shape: (1, 32)
# ZCR shape: (1, 36)
# [[0.0323125 0.0323125 0.0323125 0.0323125 0.0323125]]
# Spectral centroid shape: (1, 31)
# Poly shape: (2, 36)
# Spectral bandwidth shape: (1, 31)
# Spectral flatness shape: (1, 31)
# Mel Spectrogram shape: (90, 36)
# Mel Spectrogram DB shape: (90, 36)
# Spectral rolloff shape: (1, 31)
# Subject 1337ad-20170321-tkg with subject index 9 is processing...
# MFCC shape: (90, 36)
# Computing statistical features...
# spectral contrast shape: (1, 36)
# subject statistical features shape: (40, 19)
# Number of frames: 40
# Calculating spectral features...
# ZCR shape: (1, 35)
# ZCR shape: (1, 40)
# [[0.03929167 0.03929167 0.03929167 0.03929167 0.03929167]]
# Spectral centroid shape: (1, 36)
# Poly shape: (2, 40)
# Spectral bandwidth shape: (1, 36)
# Mel Spectrogram shape: (90, 40)
# Mel Spectrogram DB shape: (90, 40)
# Spectral flatness shape: (1, 36)
# Spectral rolloff shape: (1, 36)
# MFCC shape: (90, 40)
# Subject 1snoke-20120412-hge with subject index 0 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# ZCR shape: (1, 4)
# ZCR shape: (1, 4)
# [[0.16345833]]
# Poly shape: (2, 4)
# spectral contrast shape: (1, 40)
# Mel Spectrogram shape: (90, 4)
# Mel Spectrogram DB shape: (90, 4)
# Spectral centroid shape: (1, 40)
# MFCC shape: (90, 4)
# spectral contrast shape: (1, 4)
# Spectral centroid shape: (1, 4)
# Spectral bandwidth shape: (1, 4)
# Spectral bandwidth shape: (1, 40)
# Spectral flatness shape: (1, 4)
# Spectral rolloff shape: (1, 4)
# Spectral flatness shape: (1, 40)
# Subject 1snoke-20120412-hge with subject index 1 is processing...
# Computing statistical features...
# subject statistical features shape: (9, 19)
# Number of frames: 9
# Calculating spectral features...
# Spectral rolloff shape: (1, 40)
# ZCR shape: (1, 9)
# ZCR shape: (1, 9)
# [[0.19254167 0.17191667 0.19835417 0.1654375  0.10958333]]
# Poly shape: (2, 9)
# Subject 1snoke-20120412-hge with subject index 2 is processing...
# Mel Spectrogram shape: (90, 9)
# Mel Spectrogram DB shape: (90, 9)
# Computing statistical features...
# subject statistical features shape: (17, 19)
# Number of frames: 17
# Calculating spectral features...
# ZCR shape: (1, 16)
# ZCR shape: (1, 17)
# [[0.1640625  0.16279167 0.17895833 0.11860417 0.11860417]]
# Poly shape: (2, 17)
# MFCC shape: (90, 9)
# spectral contrast shape: (1, 9)
# Spectral centroid shape: (1, 9)
# Mel Spectrogram shape: (90, 17)
# Spectral bandwidth shape: (1, 9)
# Mel Spectrogram DB shape: (90, 17)
# Spectral flatness shape: (1, 9)
# Spectral rolloff shape: (1, 9)
# MFCC shape: (90, 17)
# Subject 1snoke-20120412-hge with subject index 3 is processing...
# spectral contrast shape: (1, 17)
# Computing statistical features...
# Spectral centroid shape: (1, 17)
# subject statistical features shape: (22, 19)
# Number of frames: 22
# Calculating spectral features...
# ZCR shape: (1, 20)
# ZCR shape: (1, 22)
# [[0.19841667 0.2460625  0.23716667 0.23716667 0.23716667]]
# Spectral bandwidth shape: (1, 17)
# Poly shape: (2, 22)
# Spectral flatness shape: (1, 17)
# Spectral rolloff shape: (1, 17)
# Mel Spectrogram shape: (90, 22)
# Mel Spectrogram DB shape: (90, 22)
# Subject 1snoke-20120412-hge with subject index 4 is processing...
# MFCC shape: (90, 22)
# Computing statistical features...
# subject statistical features shape: (25, 19)
# Number of frames: 25
# Calculating spectral features...
# ZCR shape: (1, 23)
# ZCR shape: (1, 25)
# [[0.27420833 0.21647917 0.11435417 0.11435417 0.11435417]]
# spectral contrast shape: (1, 22)
# Spectral centroid shape: (1, 22)
# Poly shape: (2, 25)
# Spectral bandwidth shape: (1, 22)
# Mel Spectrogram shape: (90, 25)
# Mel Spectrogram DB shape: (90, 25)
# Spectral flatness shape: (1, 22)
# Spectral rolloff shape: (1, 22)
# MFCC shape: (90, 25)
# Subject 1snoke-20120412-hge with subject index 5 is processing...
# spectral contrast shape: (1, 25)
# Computing statistical features...
# Spectral centroid shape: (1, 25)
# subject statistical features shape: (30, 19)
# Number of frames: 30
# Calculating spectral features...
# ZCR shape: (1, 27)
# ZCR shape: (1, 30)
# [[0.18129167 0.1260625  0.1260625  0.1260625  0.1260625 ]]
# Spectral bandwidth shape: (1, 25)
# Poly shape: (2, 30)
# Spectral flatness shape: (1, 25)
# Spectral rolloff shape: (1, 25)
# Mel Spectrogram shape: (90, 30)
# Mel Spectrogram DB shape: (90, 30)
# Subject 1snoke-20120412-hge with subject index 6 is processing...
# Computing statistical features...
# MFCC shape: (90, 30)
# subject statistical features shape: (35, 19)
# Number of frames: 35
# Calculating spectral features...
# ZCR shape: (1, 31)
# ZCR shape: (1, 35)
# [[0.14910417 0.14910417 0.14910417 0.14910417 0.14910417]]
# spectral contrast shape: (1, 30)
# Poly shape: (2, 35)
# Spectral centroid shape: (1, 30)
# Spectral bandwidth shape: (1, 30)
# Mel Spectrogram shape: (90, 35)
# Mel Spectrogram DB shape: (90, 35)
# Spectral flatness shape: (1, 30)
# Spectral rolloff shape: (1, 30)
# MFCC shape: (90, 35)
# Subject 1snoke-20120412-hge with subject index 7 is processing...
# spectral contrast shape: (1, 35)
# Computing statistical features...
# Spectral centroid shape: (1, 35)
# subject statistical features shape: (38, 19)
# Number of frames: 38
# Calculating spectral features...
# ZCR shape: (1, 34)
# ZCR shape: (1, 38)
# [[0.12770833 0.12770833 0.12770833 0.12770833 0.12770833]]
# Spectral bandwidth shape: (1, 35)
# Poly shape: (2, 38)
# Spectral flatness shape: (1, 35)
# Spectral rolloff shape: (1, 35)
# Mel Spectrogram shape: (90, 38)
# Mel Spectrogram DB shape: (90, 38)
# Subject 1snoke-20120412-hge with subject index 8 is processing...
# Computing statistical features...
# MFCC shape: (90, 38)
# subject statistical features shape: (41, 19)
# Number of frames: 41
# Calculating spectral features...
# spectral contrast shape: (1, 38)
# ZCR shape: (1, 36)
# ZCR shape: (1, 41)
# [[0.1598125 0.1598125 0.1598125 0.1598125 0.1598125]]
# Poly shape: (2, 41)
# Spectral centroid shape: (1, 38)
# Spectral bandwidth shape: (1, 38)
# Mel Spectrogram shape: (90, 41)
# Mel Spectrogram DB shape: (90, 41)
# Spectral flatness shape: (1, 38)
# Spectral rolloff shape: (1, 38)
# MFCC shape: (90, 41)
# Subject 1snoke-20120412-hge with subject index 9 is processing...
# spectral contrast shape: (1, 41)
# Computing statistical features...
# Spectral centroid shape: (1, 41)
# subject statistical features shape: (44, 19)
# Number of frames: 44
# Calculating spectral features...
# ZCR shape: (1, 39)
# ZCR shape: (1, 44)
# [[0.07579167 0.07579167 0.07579167 0.07579167 0.07579167]]
# Spectral bandwidth shape: (1, 41)
# Poly shape: (2, 44)
# Spectral flatness shape: (1, 41)
# Spectral rolloff shape: (1, 41)
# Mel Spectrogram shape: (90, 44)
# Mel Spectrogram DB shape: (90, 44)
# Subject 23yipikaye-20100807-ujm with subject index 0 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# ZCR shape: (1, 4)
# ZCR shape: (1, 4)
# [[0.0724375]]
# Poly shape: (2, 4)
# Mel Spectrogram shape: (90, 4)
# Mel Spectrogram DB shape: (90, 4)
# MFCC shape: (90, 44)
# spectral contrast shape: (1, 44)
# MFCC shape: (90, 4)
# spectral contrast shape: (1, 4)
# Spectral centroid shape: (1, 4)
# Spectral bandwidth shape: (1, 4)
# Spectral flatness shape: (1, 4)
# Spectral rolloff shape: (1, 4)
# Spectral centroid shape: (1, 44)
# Subject 23yipikaye-20100807-ujm with subject index 1 is processing...
# Computing statistical features...
# subject statistical features shape: (10, 19)
# Number of frames: 10
# Calculating spectral features...
# ZCR shape: (1, 9)
# ZCR shape: (1, 10)
# [[0.1080625  0.12383333 0.10947917 0.08572917 0.08572917]]
# Poly shape: (2, 10)
# Spectral bandwidth shape: (1, 44)
# Spectral flatness shape: (1, 44)
# Mel Spectrogram shape: (90, 10)
# Mel Spectrogram DB shape: (90, 10)
# Spectral rolloff shape: (1, 44)
# MFCC shape: (90, 10)
# spectral contrast shape: (1, 10)
# Subject 23yipikaye-20100807-ujm with subject index 2 is processing...
# Spectral centroid shape: (1, 10)
# Spectral bandwidth shape: (1, 10)
# Computing statistical features...
# Spectral flatness shape: (1, 10)
# Spectral rolloff shape: (1, 10)
# subject statistical features shape: (13, 19)
# Number of frames: 13
# Calculating spectral features...
# ZCR shape: (1, 12)
# ZCR shape: (1, 13)
# [[0.095375   0.061125   0.04666667 0.0269375  0.0269375 ]]
# Poly shape: (2, 13)
# Subject 23yipikaye-20100807-ujm with subject index 3 is processing...
# Mel Spectrogram shape: (90, 13)
# Mel Spectrogram DB shape: (90, 13)
# Computing statistical features...
# subject statistical features shape: (17, 19)
# Number of frames: 17
# Calculating spectral features...
# ZCR shape: (1, 15)
# ZCR shape: (1, 17)
# [[0.11770833 0.1244375  0.0851875  0.0851875  0.0851875 ]]
# Poly shape: (2, 17)
# MFCC shape: (90, 13)
# spectral contrast shape: (1, 13)
# Spectral centroid shape: (1, 13)
# Mel Spectrogram shape: (90, 17)
# Mel Spectrogram DB shape: (90, 17)
# Spectral bandwidth shape: (1, 13)
# Spectral flatness shape: (1, 13)
# Spectral rolloff shape: (1, 13)
# MFCC shape: (90, 17)
# spectral contrast shape: (1, 17)
# Subject 23yipikaye-20100807-ujm with subject index 4 is processing...
# Spectral centroid shape: (1, 17)
# Computing statistical features...
# Spectral bandwidth shape: (1, 17)
# subject statistical features shape: (21, 19)
# Number of frames: 21
# Calculating spectral features...
# ZCR shape: (1, 19)
# ZCR shape: (1, 21)
# [[0.1071875  0.10389583 0.06933333 0.06933333 0.06933333]]
# Spectral flatness shape: (1, 17)
# Poly shape: (2, 21)
# Spectral rolloff shape: (1, 17)
# Subject 23yipikaye-20100807-ujm with subject index 5 is processing...
# Mel Spectrogram shape: (90, 21)
# Mel Spectrogram DB shape: (90, 21)
# Computing statistical features...
# MFCC shape: (90, 21)
# spectral contrast shape: (1, 21)
# subject statistical features shape: (26, 19)
# Number of frames: 26
# Calculating spectral features...
# ZCR shape: (1, 24)
# ZCR shape: (1, 26)
# [[0.11785417 0.13129167 0.1065625  0.1065625  0.1065625 ]]
# Spectral centroid shape: (1, 21)
# Poly shape: (2, 26)
# Spectral bandwidth shape: (1, 21)
# Spectral flatness shape: (1, 21)
# Mel Spectrogram shape: (90, 26)
# Mel Spectrogram DB shape: (90, 26)
# Spectral rolloff shape: (1, 21)
# Subject 23yipikaye-20100807-ujm with subject index 6 is processing...
# MFCC shape: (90, 26)
# spectral contrast shape: (1, 26)
# Computing statistical features...
# Spectral centroid shape: (1, 26)
# subject statistical features shape: (29, 19)
# Number of frames: 29
# Calculating spectral features...
# ZCR shape: (1, 26)
# ZCR shape: (1, 29)
# [[0.07458333 0.03841667 0.03841667 0.03841667 0.03841667]]
# Spectral bandwidth shape: (1, 26)
# Poly shape: (2, 29)
# Spectral flatness shape: (1, 26)
# Spectral rolloff shape: (1, 26)
# Mel Spectrogram shape: (90, 29)
# Mel Spectrogram DB shape: (90, 29)
# Subject 23yipikaye-20100807-ujm with subject index 7 is processing...
# MFCC shape: (90, 29)
# Computing statistical features...
# subject statistical features shape: (33, 19)
# Number of frames: 33
# Calculating spectral features...
# spectral contrast shape: (1, 29)
# ZCR shape: (1, 30)
# ZCR shape: (1, 33)
# [[0.07102083 0.04385417 0.04385417 0.04385417 0.04385417]]
# Spectral centroid shape: (1, 29)
# Poly shape: (2, 33)
# Spectral bandwidth shape: (1, 29)
# Mel Spectrogram shape: (90, 33)
# Mel Spectrogram DB shape: (90, 33)
# Spectral flatness shape: (1, 29)
# Spectral rolloff shape: (1, 29)
# MFCC shape: (90, 33)
# Subject 23yipikaye-20100807-ujm with subject index 8 is processing...
# spectral contrast shape: (1, 33)
# Computing statistical features...
# Spectral centroid shape: (1, 33)
# subject statistical features shape: (38, 19)
# Number of frames: 38
# Calculating spectral features...
# ZCR shape: (1, 35)
# ZCR shape: (1, 38)
# [[0.1130625 0.0846875 0.0846875 0.0846875 0.0846875]]
# Poly shape: (2, 38)
# Spectral bandwidth shape: (1, 33)
# Spectral flatness shape: (1, 33)
# Mel Spectrogram shape: (90, 38)
# Spectral rolloff shape: (1, 33)
# Mel Spectrogram DB shape: (90, 38)
# Subject 23yipikaye-20100807-ujm with subject index 9 is processing...
# MFCC shape: (90, 38)
# Computing statistical features...
# spectral contrast shape: (1, 38)
# subject statistical features shape: (42, 19)
# Number of frames: 42
# Calculating spectral features...
# Spectral centroid shape: (1, 38)
# ZCR shape: (1, 38)
# ZCR shape: (1, 42)
# [[0.0745 0.0745 0.0745 0.0745 0.0745]]
# Poly shape: (2, 42)
# Spectral bandwidth shape: (1, 38)
# Spectral flatness shape: (1, 38)
# Mel Spectrogram shape: (90, 42)
# Mel Spectrogram DB shape: (90, 42)
# Spectral rolloff shape: (1, 38)
# Subject Aaron-20080318-kdl with subject index 0 is processing...
# Computing statistical features...
# MFCC shape: (90, 42)
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# ZCR shape: (1, 3)
# ZCR shape: (1, 3)
# [[0.08322917 0.04260417]]
# Poly shape: (2, 3)
# Mel Spectrogram shape: (90, 3)
# Mel Spectrogram DB shape: (90, 3)
# spectral contrast shape: (1, 42)
# MFCC shape: (90, 3)
# Spectral centroid shape: (1, 42)
# spectral contrast shape: (1, 3)
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=37376
#   warnings.warn(
# Spectral centroid shape: (1, 3)
# Spectral bandwidth shape: (1, 3)
# Spectral flatness shape: (1, 3)
# Spectral rolloff shape: (1, 3)
# Subject Aaron-20080318-kdl with subject index 1 is processing...
# Computing statistical features...
# Spectral bandwidth shape: (1, 42)
# subject statistical features shape: (6, 19)
# Number of frames: 6
# Calculating spectral features...
# ZCR shape: (1, 6)
# ZCR shape: (1, 6)
# [[0.08708333 0.07179167 0.06783333 0.05752083 0.0321875 ]]
# Poly shape: (2, 6)
# Spectral flatness shape: (1, 42)
# Mel Spectrogram shape: (90, 6)
# Mel Spectrogram DB shape: (90, 6)
# Spectral rolloff shape: (1, 42)
# MFCC shape: (90, 6)
# spectral contrast shape: (1, 6)
# Subject Aaron-20080318-kdl with subject index 2 is processing...
# Spectral centroid shape: (1, 6)
# Computing statistical features...
# Spectral bandwidth shape: (1, 6)
# subject statistical features shape: (8, 19)
# Number of frames: 8
# Calculating spectral features...
# ZCR shape: (1, 7)
# ZCR shape: (1, 8)
# [[0.06783333 0.06966667 0.07935417 0.06139583 0.06139583]]
# Spectral flatness shape: (1, 6)
# Spectral rolloff shape: (1, 6)
# Poly shape: (2, 8)
# Subject Aaron-20080318-kdl with subject index 3 is processing...
# Mel Spectrogram shape: (90, 8)
# Mel Spectrogram DB shape: (90, 8)
# Computing statistical features...
# subject statistical features shape: (11, 19)
# Number of frames: 11
# Calculating spectral features...
# ZCR shape: (1, 9)
# ZCR shape: (1, 11)
# [[0.0775     0.07945833 0.05470833 0.05470833 0.05470833]]
# Poly shape: (2, 11)
# MFCC shape: (90, 8)
# spectral contrast shape: (1, 8)
# Spectral centroid shape: (1, 8)
# Mel Spectrogram shape: (90, 11)
# Mel Spectrogram DB shape: (90, 11)
# Spectral bandwidth shape: (1, 8)
# Spectral flatness shape: (1, 8)
# Spectral rolloff shape: (1, 8)
# MFCC shape: (90, 11)
# Subject Aaron-20080318-kdl with subject index 4 is processing...
# spectral contrast shape: (1, 11)
# Spectral centroid shape: (1, 11)
# Computing statistical features...
# Spectral bandwidth shape: (1, 11)
# subject statistical features shape: (14, 19)
# Number of frames: 14
# Calculating spectral features...
# Spectral flatness shape: (1, 11)
# ZCR shape: (1, 12)
# ZCR shape: (1, 14)
# [[0.06647917 0.05716667 0.03847917 0.03847917 0.03847917]]
# Spectral rolloff shape: (1, 11)
# Poly shape: (2, 14)
# Subject Aaron-20080318-kdl with subject index 5 is processing...
# Mel Spectrogram shape: (90, 14)
# Mel Spectrogram DB shape: (90, 14)
# Computing statistical features...
# subject statistical features shape: (17, 19)
# Number of frames: 17
# Calculating spectral features...
# ZCR shape: (1, 14)
# ZCR shape: (1, 17)
# [[0.0708125 0.0426875 0.0426875 0.0426875 0.0426875]]
# Poly shape: (2, 17)
# MFCC shape: (90, 14)
# spectral contrast shape: (1, 14)
# Spectral centroid shape: (1, 14)
# Mel Spectrogram shape: (90, 17)
# Mel Spectrogram DB shape: (90, 17)
# Spectral bandwidth shape: (1, 14)
# Spectral flatness shape: (1, 14)
# Spectral rolloff shape: (1, 14)
# MFCC shape: (90, 17)
# Subject Aaron-20080318-kdl with subject index 6 is processing...
# spectral contrast shape: (1, 17)
# Computing statistical features...
# Spectral centroid shape: (1, 17)
# subject statistical features shape: (19, 19)
# Number of frames: 19
# Calculating spectral features...
# ZCR shape: (1, 15)
# ZCR shape: (1, 19)
# [[0.05989583 0.05989583 0.05989583 0.05989583 0.05989583]]
# Spectral bandwidth shape: (1, 17)
# Poly shape: (2, 19)
# Spectral flatness shape: (1, 17)
# Spectral rolloff shape: (1, 17)
# Mel Spectrogram shape: (90, 19)
# Mel Spectrogram DB shape: (90, 19)
# Subject Aaron-20080318-kdl with subject index 7 is processing...
# Computing statistical features...
# MFCC shape: (90, 19)
# subject statistical features shape: (22, 19)
# Number of frames: 22
# Calculating spectral features...
# ZCR shape: (1, 17)
# ZCR shape: (1, 22)
# [[0.07508333 0.07508333 0.07508333 0.07508333 0.07508333]]
# spectral contrast shape: (1, 19)
# Poly shape: (2, 22)
# Spectral centroid shape: (1, 19)
# Spectral bandwidth shape: (1, 19)
# Mel Spectrogram shape: (90, 22)
# Mel Spectrogram DB shape: (90, 22)
# Spectral flatness shape: (1, 19)
# Spectral rolloff shape: (1, 19)
# MFCC shape: (90, 22)
# Subject Aaron-20080318-kdl with subject index 8 is processing...
# spectral contrast shape: (1, 22)
# Computing statistical features...
# Spectral centroid shape: (1, 22)
# subject statistical features shape: (25, 19)
# Number of frames: 25
# Calculating spectral features...
# Spectral bandwidth shape: (1, 22)
# ZCR shape: (1, 20)
# ZCR shape: (1, 25)
# [[0.05825 0.05825 0.05825 0.05825 0.05825]]
# Spectral flatness shape: (1, 22)
# Poly shape: (2, 25)
# Spectral rolloff shape: (1, 22)
# Mel Spectrogram shape: (90, 25)
# Mel Spectrogram DB shape: (90, 25)
# Subject Aaron-20080318-kdl with subject index 9 is processing...
# MFCC shape: (90, 25)
# Computing statistical features...
# spectral contrast shape: (1, 25)
# subject statistical features shape: (28, 19)
# Number of frames: 28
# Calculating spectral features...
# ZCR shape: (1, 23)
# ZCR shape: (1, 28)
# [[0.05570833 0.05570833 0.05570833 0.05570833 0.05570833]]
# Spectral centroid shape: (1, 25)
# Poly shape: (2, 28)
# Spectral bandwidth shape: (1, 25)
# Spectral flatness shape: (1, 25)
# Mel Spectrogram shape: (90, 28)
# Mel Spectrogram DB shape: (90, 28)
# Spectral rolloff shape: (1, 25)
# Subject Anniepoo-20140308-bft with subject index 0 is processing...
# Computing statistical features...
# MFCC shape: (90, 28)
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# ZCR shape: (1, 4)
# ZCR shape: (1, 4)
# [[0.11295833]]
# Poly shape: (2, 4)
# spectral contrast shape: (1, 28)
# Mel Spectrogram shape: (90, 4)
# Mel Spectrogram DB shape: (90, 4)
# Spectral centroid shape: (1, 28)
# MFCC shape: (90, 4)
# spectral contrast shape: (1, 4)
# Spectral centroid shape: (1, 4)
# Spectral bandwidth shape: (1, 4)
# Spectral flatness shape: (1, 4)
# Spectral bandwidth shape: (1, 28)
# Spectral rolloff shape: (1, 4)
# Spectral flatness shape: (1, 28)
# Subject Anniepoo-20140308-bft with subject index 1 is processing...
# Spectral rolloff shape: (1, 28)
# Computing statistical features...
# subject statistical features shape: (10, 19)
# Number of frames: 10
# Calculating spectral features...
# ZCR shape: (1, 10)
# ZCR shape: (1, 10)
# [[0.21810417 0.18145833 0.16458333 0.120625   0.06066667]]
# Poly shape: (2, 10)
# Subject Anniepoo-20140308-bft with subject index 2 is processing...
# Computing statistical features...
# Mel Spectrogram shape: (90, 10)
# Mel Spectrogram DB shape: (90, 10)
# subject statistical features shape: (15, 19)
# Number of frames: 15
# Calculating spectral features...
# ZCR shape: (1, 14)
# ZCR shape: (1, 15)
# [[0.17135417 0.21008333 0.18552083 0.13016667 0.13016667]]
# Poly shape: (2, 15)
# MFCC shape: (90, 10)
# spectral contrast shape: (1, 10)
# Mel Spectrogram shape: (90, 15)
# Spectral centroid shape: (1, 10)
# Mel Spectrogram DB shape: (90, 15)
# Spectral bandwidth shape: (1, 10)
# Spectral flatness shape: (1, 10)
# Spectral rolloff shape: (1, 10)
# MFCC shape: (90, 15)
# Subject Anniepoo-20140308-bft with subject index 3 is processing...
# spectral contrast shape: (1, 15)
# Computing statistical features...
# Spectral centroid shape: (1, 15)
# subject statistical features shape: (20, 19)
# Number of frames: 20
# Calculating spectral features...
# ZCR shape: (1, 19)
# ZCR shape: (1, 20)
# [[0.16641667 0.17702083 0.17725    0.12283333 0.12283333]]
# Spectral bandwidth shape: (1, 15)
# Poly shape: (2, 20)
# Spectral flatness shape: (1, 15)
# Spectral rolloff shape: (1, 15)
# Mel Spectrogram shape: (90, 20)
# Mel Spectrogram DB shape: (90, 20)
# Subject Anniepoo-20140308-bft with subject index 4 is processing...
# Computing statistical features...
# MFCC shape: (90, 20)
# subject statistical features shape: (23, 19)
# Number of frames: 23
# Calculating spectral features...
# spectral contrast shape: (1, 20)
# ZCR shape: (1, 22)
# ZCR shape: (1, 23)
# [[0.15489583 0.14241667 0.12870833 0.10364583 0.10364583]]
# Spectral centroid shape: (1, 20)
# Poly shape: (2, 23)
# Spectral bandwidth shape: (1, 20)
# Spectral flatness shape: (1, 20)
# Mel Spectrogram shape: (90, 23)
# Mel Spectrogram DB shape: (90, 23)
# Spectral rolloff shape: (1, 20)
# MFCC shape: (90, 23)
# Subject Anniepoo-20140308-bft with subject index 5 is processing...
# spectral contrast shape: (1, 23)
# Computing statistical features...
# Spectral centroid shape: (1, 23)
# subject statistical features shape: (28, 19)
# Number of frames: 28
# Calculating spectral features...
# ZCR shape: (1, 26)
# ZCR shape: (1, 28)
# [[0.197375   0.15833333 0.10489583 0.10489583 0.10489583]]
# Spectral bandwidth shape: (1, 23)
# Spectral flatness shape: (1, 23)
# Poly shape: (2, 28)
# Spectral rolloff shape: (1, 23)
# Mel Spectrogram shape: (90, 28)
# Subject Anniepoo-20140308-bft with subject index 6 is processing...
# Mel Spectrogram DB shape: (90, 28)
# Computing statistical features...
# MFCC shape: (90, 28)
# subject statistical features shape: (31, 19)
# Number of frames: 31
# Calculating spectral features...
# ZCR shape: (1, 28)
# ZCR shape: (1, 31)
# [[0.21983333 0.18470833 0.18470833 0.18470833 0.18470833]]
# spectral contrast shape: (1, 28)
# Poly shape: (2, 31)
# Spectral centroid shape: (1, 28)
# Mel Spectrogram shape: (90, 31)
# Spectral bandwidth shape: (1, 28)
# Mel Spectrogram DB shape: (90, 31)
# Spectral flatness shape: (1, 28)
# Spectral rolloff shape: (1, 28)
# MFCC shape: (90, 31)
# Subject Anniepoo-20140308-bft with subject index 7 is processing...
# spectral contrast shape: (1, 31)
# Computing statistical features...
# Spectral centroid shape: (1, 31)
# subject statistical features shape: (35, 19)
# Number of frames: 35
# Calculating spectral features...
# ZCR shape: (1, 31)
# ZCR shape: (1, 35)
# [[0.15416667 0.15416667 0.15416667 0.15416667 0.15416667]]
# Spectral bandwidth shape: (1, 31)
# Poly shape: (2, 35)
# Spectral flatness shape: (1, 31)
# Spectral rolloff shape: (1, 31)
# Mel Spectrogram shape: (90, 35)
# Mel Spectrogram DB shape: (90, 35)
# Subject Anniepoo-20140308-bft with subject index 8 is processing...
# MFCC shape: (90, 35)
# Computing statistical features...
# spectral contrast shape: (1, 35)
# subject statistical features shape: (40, 19)Spectral centroid shape: (1, 35)
#
# Number of frames: 40
# Calculating spectral features...
# ZCR shape: (1, 36)
# ZCR shape: (1, 40)
# [[0.0506875 0.0506875 0.0506875 0.0506875 0.0506875]]
# Poly shape: (2, 40)
# Spectral bandwidth shape: (1, 35)
# Spectral flatness shape: (1, 35)
# Mel Spectrogram shape: (90, 40)
# Mel Spectrogram DB shape: (90, 40)
# Spectral rolloff shape: (1, 35)
# Subject Anniepoo-20140308-bft with subject index 9 is processing...
# MFCC shape: (90, 40)
# spectral contrast shape: (1, 40)
# Computing statistical features...
# subject statistical features shape: (44, 19)
# Number of frames: 44
# Calculating spectral features...
# Spectral centroid shape: (1, 40)
# ZCR shape: (1, 40)
# ZCR shape: (1, 44)
# [[0.10170833 0.10170833 0.10170833 0.10170833 0.10170833]]
# Poly shape: (2, 44)
# Spectral bandwidth shape: (1, 40)
# Spectral flatness shape: (1, 40)
# Spectral rolloff shape: (1, 40)
# Mel Spectrogram shape: (90, 44)
# Mel Spectrogram DB shape: (90, 44)
# Subject Anniepoo-20140308-cqj with subject index 0 is processing...
# Computing statistical features...
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# ZCR shape: (1, 4)
# ZCR shape: (1, 4)
# [[0.12029167]]
# MFCC shape: (90, 44)
# Poly shape: (2, 4)
# Mel Spectrogram shape: (90, 4)
# Mel Spectrogram DB shape: (90, 4)
# spectral contrast shape: (1, 44)
# MFCC shape: (90, 4)
# Spectral centroid shape: (1, 44)
# spectral contrast shape: (1, 4)
# Spectral centroid shape: (1, 4)
# Spectral bandwidth shape: (1, 4)
# Spectral flatness shape: (1, 4)
# Spectral rolloff shape: (1, 4)
# Subject Anniepoo-20140308-cqj with subject index 1 is processing...
# Computing statistical features...
# Spectral bandwidth shape: (1, 44)
# subject statistical features shape: (9, 19)
# Number of frames: 9
# Calculating spectral features...
# ZCR shape: (1, 9)
# ZCR shape: (1, 9)
# [[0.17325    0.20245833 0.21141667 0.206      0.13266667]]
# Poly shape: (2, 9)
# Spectral flatness shape: (1, 44)
# Mel Spectrogram shape: (90, 9)
# Mel Spectrogram DB shape: (90, 9)
# Spectral rolloff shape: (1, 44)
# MFCC shape: (90, 9)
# Subject Anniepoo-20140308-cqj with subject index 2 is processing...
# spectral contrast shape: (1, 9)
# Spectral centroid shape: (1, 9)
# Computing statistical features...
# Spectral bandwidth shape: (1, 9)
# subject statistical features shape: (12, 19)
# Number of frames: 12
# Calculating spectral features...
# ZCR shape: (1, 11)
# ZCR shape: (1, 12)
# [[0.20972917 0.1825625  0.16352083 0.08802083 0.08802083]]
# Spectral flatness shape: (1, 9)
# Poly shape: (2, 12)
# Spectral rolloff shape: (1, 9)
# Subject Anniepoo-20140308-cqj with subject index 3 is processing...
# Mel Spectrogram shape: (90, 12)
# Mel Spectrogram DB shape: (90, 12)
# Computing statistical features...
# subject statistical features shape: (15, 19)
# Number of frames: 15
# Calculating spectral features...
# ZCR shape: (1, 14)
# ZCR shape: (1, 15)
# [[0.142      0.14533333 0.13460417 0.0713125  0.0713125 ]]
# Poly shape: (2, 15)
# MFCC shape: (90, 12)
# spectral contrast shape: (1, 12)
# Spectral centroid shape: (1, 12)
# Mel Spectrogram shape: (90, 15)
# Mel Spectrogram DB shape: (90, 15)
# Spectral bandwidth shape: (1, 12)
# Spectral flatness shape: (1, 12)
# Spectral rolloff shape: (1, 12)
# MFCC shape: (90, 15)
# spectral contrast shape: (1, 15)
# Subject Anniepoo-20140308-cqj with subject index 4 is processing...
# Spectral centroid shape: (1, 15)
# Computing statistical features...
# Spectral bandwidth shape: (1, 15)
# subject statistical features shape: (20, 19)
# Number of frames: 20
# Calculating spectral features...
# ZCR shape: (1, 18)
# ZCR shape: (1, 20)
# [[0.21077083 0.1399375  0.08008333 0.08008333 0.08008333]]
# Spectral flatness shape: (1, 15)
# Spectral rolloff shape: (1, 15)
# Poly shape: (2, 20)
# Mel Spectrogram shape: (90, 20)
# Subject Anniepoo-20140308-cqj with subject index 5 is processing...
# Mel Spectrogram DB shape: (90, 20)
# MFCC shape: (90, 20)
# Computing statistical features...
# subject statistical features shape: (25, 19)
# Number of frames: 25
# Calculating spectral features...
# ZCR shape: (1, 22)
# ZCR shape: (1, 25)
# [[0.26139583 0.15972917 0.15972917 0.15972917 0.15972917]]
# spectral contrast shape: (1, 20)
# Spectral centroid shape: (1, 20)
# Poly shape: (2, 25)
# Spectral bandwidth shape: (1, 20)
# Mel Spectrogram shape: (90, 25)
# Spectral flatness shape: (1, 20)
# Mel Spectrogram DB shape: (90, 25)
# Spectral rolloff shape: (1, 20)
# Subject Anniepoo-20140308-cqj with subject index 6 is processing...
# MFCC shape: (90, 25)
# Computing statistical features...
# spectral contrast shape: (1, 25)
# subject statistical features shape: (28, 19)
# Number of frames: 28
# Calculating spectral features...
# ZCR shape: (1, 25)
# ZCR shape: (1, 28)
# [[0.15725 0.1125  0.1125  0.1125  0.1125 ]]
# Spectral centroid shape: (1, 25)
# Poly shape: (2, 28)
# Spectral bandwidth shape: (1, 25)
# Spectral flatness shape: (1, 25)
# Mel Spectrogram shape: (90, 28)
# Mel Spectrogram DB shape: (90, 28)
# Spectral rolloff shape: (1, 25)
# Subject Anniepoo-20140308-cqj with subject index 7 is processing...
# MFCC shape: (90, 28)
# spectral contrast shape: (1, 28)
# Computing statistical features...
# subject statistical features shape: (31, 19)
# Number of frames: 31
# Calculating spectral features...
# ZCR shape: (1, 27)
# ZCR shape: (1, 31)
# [[0.1205 0.1205 0.1205 0.1205 0.1205]]
# Spectral centroid shape: (1, 28)
# Poly shape: (2, 31)
# Spectral bandwidth shape: (1, 28)
# Spectral flatness shape: (1, 28)
# Mel Spectrogram shape: (90, 31)
# Mel Spectrogram DB shape: (90, 31)
# Spectral rolloff shape: (1, 28)
# Subject Anniepoo-20140308-cqj with subject index 8 is processing...
# MFCC shape: (90, 31)
# Computing statistical features...
# spectral contrast shape: (1, 31)
# subject statistical features shape: (36, 19)
# Number of frames: 36
# Calculating spectral features...
# ZCR shape: (1, 31)
# ZCR shape: (1, 36)
# [[0.1180625 0.1180625 0.1180625 0.1180625 0.1180625]]
# Spectral centroid shape: (1, 31)
# Poly shape: (2, 36)
# Spectral bandwidth shape: (1, 31)
# Spectral flatness shape: (1, 31)
# Mel Spectrogram shape: (90, 36)
# Spectral rolloff shape: (1, 31)
# Mel Spectrogram DB shape: (90, 36)
# Subject Anniepoo-20140308-cqj with subject index 9 is processing...
# MFCC shape: (90, 36)
# Computing statistical features...
# spectral contrast shape: (1, 36)
# subject statistical features shape: (40, 19)
# Number of frames: 40
# Calculating spectral features...
# ZCR shape: (1, 35)
# ZCR shape: (1, 40)
# [[0.11527083 0.11527083 0.11527083 0.11527083 0.11527083]]
# Spectral centroid shape: (1, 36)
# Poly shape: (2, 40)
# Spectral bandwidth shape: (1, 36)
# Spectral flatness shape: (1, 36)
# Mel Spectrogram shape: (90, 40)
# Mel Spectrogram DB shape: (90, 40)
# Spectral rolloff shape: (1, 36)
# Subject Anniepoo-20140308-fcp with subject index 0 is processing...
# Computing statistical features...
# MFCC shape: (90, 40)
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# ZCR shape: (1, 3)
# ZCR shape: (1, 3)
# [[0.13904167 0.10385417]]
# Poly shape: (2, 3)
# spectral contrast shape: (1, 40)
# Mel Spectrogram shape: (90, 3)
# Mel Spectrogram DB shape: (90, 3)
# Spectral centroid shape: (1, 40)
# MFCC shape: (90, 3)
# spectral contrast shape: (1, 3)
# Spectral centroid shape: (1, 3)
# Spectral bandwidth shape: (1, 3)
# Spectral flatness shape: (1, 3)
# Spectral rolloff shape: (1, 3)
# Subject Anniepoo-20140308-fcp with subject index 1 is processing...
# Spectral bandwidth shape: (1, 40)
# Computing statistical features...
# subject statistical features shape: (6, 19)
# Number of frames: 6
# Calculating spectral features...
# ZCR shape: (1, 5)
# ZCR shape: (1, 6)
# [[0.14516667 0.15895833 0.15025    0.07808333 0.07808333]]
# Poly shape: (2, 6)
# Spectral flatness shape: (1, 40)
# Mel Spectrogram shape: (90, 6)
# Spectral rolloff shape: (1, 40)
# Mel Spectrogram DB shape: (90, 6)
# Subject Anniepoo-20140308-fcp with subject index 2 is processing...
# Computing statistical features...
# MFCC shape: (90, 6)
# subject statistical features shape: (9, 19)
# Number of frames: 9
# Calculating spectral features...
# ZCR shape: (1, 8)
# ZCR shape: (1, 9)
# [[0.17883333 0.19022917 0.17854167 0.08575    0.08575   ]]
# spectral contrast shape: (1, 6)
# Spectral centroid shape: (1, 6)
# Poly shape: (2, 9)
# Spectral bandwidth shape: (1, 6)
# Spectral flatness shape: (1, 6)
# Spectral rolloff shape: (1, 6)
# Mel Spectrogram shape: (90, 9)
# Mel Spectrogram DB shape: (90, 9)
# Subject Anniepoo-20140308-fcp with subject index 3 is processing...
# Computing statistical features...
# MFCC shape: (90, 9)
# subject statistical features shape: (12, 19)
# Number of frames: 12
# Calculating spectral features...
# ZCR shape: (1, 10)
# ZCR shape: (1, 12)
# [[0.15964583 0.18675    0.14329167 0.14329167 0.14329167]]
# spectral contrast shape: (1, 9)
# Spectral centroid shape: (1, 9)
# Poly shape: (2, 12)
# Spectral bandwidth shape: (1, 9)
# Spectral flatness shape: (1, 9)
# Spectral rolloff shape: (1, 9)
# Mel Spectrogram shape: (90, 12)
# Mel Spectrogram DB shape: (90, 12)
# Subject Anniepoo-20140308-fcp with subject index 4 is processing...
# MFCC shape: (90, 12)
# Computing statistical features...
# spectral contrast shape: (1, 12)
# subject statistical features shape: (16, 19)
# Number of frames: 16
# Calculating spectral features...
# ZCR shape: (1, 13)
# ZCR shape: (1, 16)
# [[0.22535417 0.1591875  0.1591875  0.1591875  0.1591875 ]]
# Spectral centroid shape: (1, 12)
# Poly shape: (2, 16)
# Spectral bandwidth shape: (1, 12)
# Spectral flatness shape: (1, 12)
# Spectral rolloff shape: (1, 12)
# Mel Spectrogram shape: (90, 16)
# Mel Spectrogram DB shape: (90, 16)
# ...
# Calculating spectral features...
# ZCR shape: (1, 11)
# ZCR shape: (1, 12)
# [[0.16125    0.189625   0.20539583 0.12258333 0.12258333]]
# Poly shape: (2, 12)
# MFCC shape: (90, 8)
# Mel Spectrogram shape: (90, 12)
# spectral contrast shape: (1, 8)
# Mel Spectrogram DB shape: (90, 12)
# Spectral centroid shape: (1, 8)
# Spectral bandwidth shape: (1, 8)
# Spectral flatness shape: (1, 8)
# Spectral rolloff shape: (1, 8)
# MFCC shape: (90, 12)
# spectral contrast shape: (1, 12)
# Subject Anniepoo-20140308-hns with subject index 3 is processing...
# Spectral centroid shape: (1, 12)
# Computing statistical features...
# Spectral bandwidth shape: (1, 12)
# subject statistical features shape: (16, 19)
# Number of frames: 16
# Calculating spectral features...
# ZCR shape: (1, 14)
# ZCR shape: (1, 16)
# [[0.1564375  0.12852083 0.09547917 0.09547917 0.09547917]]
# Spectral flatness shape: (1, 12)
# Poly shape: (2, 16)
# Spectral rolloff shape: (1, 12)
# Mel Spectrogram shape: (90, 16)
# Mel Spectrogram DB shape: (90, 16)
# Subject Anniepoo-20140308-hns with subject index 4 is processing...
# Computing statistical features...
# subject statistical features shape: (20, 19)
# Number of frames: 20
# Calculating spectral features...
# ZCR shape: (1, 17)
# ZCR shape: (1, 20)
# [[0.18425   0.1440625 0.1440625 0.1440625 0.1440625]]
# MFCC shape: (90, 16)
# spectral contrast shape: (1, 16)
# Poly shape: (2, 20)
# Spectral centroid shape: (1, 16)
# Mel Spectrogram shape: (90, 20)
# Spectral bandwidth shape: (1, 16)
# Mel Spectrogram DB shape: (90, 20)
# Spectral flatness shape: (1, 16)
# Spectral rolloff shape: (1, 16)
# MFCC shape: (90, 20)
# Subject Anniepoo-20140308-hns with subject index 5 is processing...
# spectral contrast shape: (1, 20)
# Computing statistical features...
# Spectral centroid shape: (1, 20)
# subject statistical features shape: (21, 19)
# Number of frames: 21
# Calculating spectral features...
# ZCR shape: (1, 18)
# ZCR shape: (1, 21)
# [[0.1648125  0.12335417 0.12335417 0.12335417 0.12335417]]
# Spectral bandwidth shape: (1, 20)
# Spectral flatness shape: (1, 20)
# Poly shape: (2, 21)
# Spectral rolloff shape: (1, 20)
# Mel Spectrogram shape: (90, 21)
# Mel Spectrogram DB shape: (90, 21)
# Subject Anniepoo-20140308-hns with subject index 6 is processing...
# Computing statistical features...
# MFCC shape: (90, 21)
# subject statistical features shape: (24, 19)
# Number of frames: 24
# Calculating spectral features...
# ZCR shape: (1, 21)
# ZCR shape: (1, 24)
# [[0.15375 0.1145  0.1145  0.1145  0.1145 ]]
# spectral contrast shape: (1, 21)
# Poly shape: (2, 24)
# Spectral centroid shape: (1, 21)
# Mel Spectrogram shape: (90, 24)
# Mel Spectrogram DB shape: (90, 24)
# Spectral bandwidth shape: (1, 21)
# Spectral flatness shape: (1, 21)
# Spectral rolloff shape: (1, 21)
# MFCC shape: (90, 24)
# Subject Anniepoo-20140308-hns with subject index 7 is processing...
# spectral contrast shape: (1, 24)
# Computing statistical features...
# Spectral centroid shape: (1, 24)
# subject statistical features shape: (28, 19)
# Number of frames: 28
# Calculating spectral features...
# ZCR shape: (1, 25)
# ZCR shape: (1, 28)
# [[0.1775     0.12354167 0.12354167 0.12354167 0.12354167]]
# Spectral bandwidth shape: (1, 24)
# Spectral flatness shape: (1, 24)
# Poly shape: (2, 28)
# Spectral rolloff shape: (1, 24)
# Mel Spectrogram shape: (90, 28)
# Subject Anniepoo-20140308-hns with subject index 8 is processing...
# Mel Spectrogram DB shape: (90, 28)
# Computing statistical features...
# MFCC shape: (90, 28)
# spectral contrast shape: (1, 28)
# subject statistical features shape: (30, 19)
# Number of frames: 30
# Calculating spectral features...
# ZCR shape: (1, 26)
# ZCR shape: (1, 30)
# [[0.0955 0.0955 0.0955 0.0955 0.0955]]
# Spectral centroid shape: (1, 28)
# Poly shape: (2, 30)
# Spectral bandwidth shape: (1, 28)
# Spectral flatness shape: (1, 28)Mel Spectrogram shape: (90, 30)
#
# Mel Spectrogram DB shape: (90, 30)
# Spectral rolloff shape: (1, 28)
# MFCC shape: (90, 30)
# Subject Anniepoo-20140308-hns with subject index 9 is processing...
# spectral contrast shape: (1, 30)
# Computing statistical features...
# Spectral centroid shape: (1, 30)
# subject statistical features shape: (34, 19)
# Number of frames: 34
# Calculating spectral features...
# ZCR shape: (1, 30)
# ZCR shape: (1, 34)
# [[0.08089583 0.08089583 0.08089583 0.08089583 0.08089583]]
# Spectral bandwidth shape: (1, 30)
# Spectral flatness shape: (1, 30)
# Poly shape: (2, 34)
# Spectral rolloff shape: (1, 30)
# Subject Anniepoo-20140308-nky with subject index 0 is processing...
# Mel Spectrogram shape: (90, 34)
# Computing statistical features...
# Mel Spectrogram DB shape: (90, 34)
# subject statistical features shape: (4, 19)
# Number of frames: 4
# Calculating spectral features...
# ZCR shape: (1, 4)
# ZCR shape: (1, 4)
# [[0.09141667]]
# Poly shape: (2, 4)
# Mel Spectrogram shape: (90, 4)
# Mel Spectrogram DB shape: (90, 4)
# MFCC shape: (90, 34)
# MFCC shape: (90, 4)
# spectral contrast shape: (1, 4)
# spectral contrast shape: (1, 34)
# Spectral centroid shape: (1, 4)
# Spectral bandwidth shape: (1, 4)
# Spectral flatness shape: (1, 4)
# Spectral rolloff shape: (1, 4)
# Spectral centroid shape: (1, 34)
# Subject Anniepoo-20140308-nky with subject index 1 is processing...
# Computing statistical features...
# subject statistical features shape: (7, 19)
# Number of frames: 7
# Calculating spectral features...
# ZCR shape: (1, 6)
# ZCR shape: (1, 7)
# [[0.1474375  0.1673125  0.1591875  0.12827083 0.12827083]]
# Poly shape: (2, 7)
# Spectral bandwidth shape: (1, 34)
# Mel Spectrogram shape: (90, 7)
# Mel Spectrogram DB shape: (90, 7)
# Spectral flatness shape: (1, 34)
# Spectral rolloff shape: (1, 34)
# MFCC shape: (90, 7)
# spectral contrast shape: (1, 7)
# Subject Anniepoo-20140308-nky with subject index 2 is processing...
# Spectral centroid shape: (1, 7)
# Computing statistical features...
# Spectral bandwidth shape: (1, 7)
# subject statistical features shape: (10, 19)
# Number of frames: 10
# Calculating spectral features...
# ZCR shape: (1, 8)
# ZCR shape: (1, 10)
# [[0.15633333 0.1436875  0.10495833 0.10495833 0.10495833]]
# Spectral flatness shape: (1, 7)
# Poly shape: (2, 10)
# Spectral rolloff shape: (1, 7)
# Subject Anniepoo-20140308-nky with subject index 3 is processing...
# Mel Spectrogram shape: (90, 10)
# Mel Spectrogram DB shape: (90, 10)
# Computing statistical features...
# MFCC shape: (90, 10)
# subject statistical features shape: (14, 19)
# Number of frames: 14
# Calculating spectral features...
# ZCR shape: (1, 12)
# ZCR shape: (1, 14)
# [[0.14783333 0.1276875  0.07141667 0.07141667 0.07141667]]
# spectral contrast shape: (1, 10)
# Poly shape: (2, 14)
# Spectral centroid shape: (1, 10)
# Spectral bandwidth shape: (1, 10)
# Spectral flatness shape: (1, 10)
# Spectral rolloff shape: (1, 10)
# Mel Spectrogram shape: (90, 14)
# Mel Spectrogram DB shape: (90, 14)
# Subject Anniepoo-20140308-nky with subject index 4 is processing...
# MFCC shape: (90, 14)
# Computing statistical features...
# spectral contrast shape: (1, 14)
# subject statistical features shape: (18, 19)
# Number of frames: 18
# Calculating spectral features...
# ZCR shape: (1, 15)
# ZCR shape: (1, 18)
# [[0.1925625 0.133125  0.133125  0.133125  0.133125 ]]
# Spectral centroid shape: (1, 14)
# Poly shape: (2, 18)
# Spectral bandwidth shape: (1, 14)
# Spectral flatness shape: (1, 14)
# Spectral rolloff shape: (1, 14)
# Mel Spectrogram shape: (90, 18)
# Mel Spectrogram DB shape: (90, 18)
# Subject Anniepoo-20140308-nky with subject index 5 is processing...
# Computing statistical features...
# MFCC shape: (90, 18)
# subject statistical features shape: (22, 19)
# Number of frames: 22
# Calculating spectral features...
# ZCR shape: (1, 19)
# ZCR shape: (1, 22)
# [[0.09170833 0.06197917 0.06197917 0.06197917 0.06197917]]
# spectral contrast shape: (1, 18)
# Spectral centroid shape: (1, 18)
# Poly shape: (2, 22)
# Spectral bandwidth shape: (1, 18)
# Spectral flatness shape: (1, 18)
# Mel Spectrogram shape: (90, 22)
# Mel Spectrogram DB shape: (90, 22)
# Spectral rolloff shape: (1, 18)
# Subject Anniepoo-20140308-nky with subject index 6 is processing...
# MFCC shape: (90, 22)
# spectral contrast shape: (1, 22)
# Computing statistical features...
# Spectral centroid shape: (1, 22)
# subject statistical features shape: (26, 19)
# Number of frames: 26
# Calculating spectral features...
# Spectral bandwidth shape: (1, 22)
# ZCR shape: (1, 23)
# ZCR shape: (1, 26)
# [[0.14358333 0.08008333 0.08008333 0.08008333 0.08008333]]
# Spectral flatness shape: (1, 22)
# Poly shape: (2, 26)
# Spectral rolloff shape: (1, 22)
# Subject Anniepoo-20140308-nky with subject index 7 is processing...
# Mel Spectrogram shape: (90, 26)
# Mel Spectrogram DB shape: (90, 26)
# Computing statistical features...
# MFCC shape: (90, 26)
# subject statistical features shape: (32, 19)
# Number of frames: 32
# Calculating spectral features...
# spectral contrast shape: (1, 26)
# ZCR shape: (1, 28)
# ZCR shape: (1, 32)
# [[0.04572917 0.04572917 0.04572917 0.04572917 0.04572917]]
# Spectral centroid shape: (1, 26)
# Poly shape: (2, 32)
# Spectral bandwidth shape: (1, 26)
# Spectral flatness shape: (1, 26)
# Mel Spectrogram shape: (90, 32)
# Mel Spectrogram DB shape: (90, 32)
# Spectral rolloff shape: (1, 26)
# Subject Anniepoo-20140308-nky with subject index 8 is processing...
# MFCC shape: (90, 32)
# spectral contrast shape: (1, 32)
# Computing statistical features...
# Spectral centroid shape: (1, 32)
# subject statistical features shape: (34, 19)
# Number of frames: 34
# Calculating spectral features...
# ZCR shape: (1, 29)
# ZCR shape: (1, 34)
# [[0.11710417 0.11710417 0.11710417 0.11710417 0.11710417]]
# Spectral bandwidth shape: (1, 32)
# Poly shape: (2, 34)
# Spectral flatness shape: (1, 32)
# Spectral rolloff shape: (1, 32)
# Mel Spectrogram shape: (90, 34)
# Mel Spectrogram DB shape: (90, 34)
# Subject Anniepoo-20140308-nky with subject index 9 is processing...
# MFCC shape: (90, 34)
# Computing statistical features...
# spectral contrast shape: (1, 34)
# subject statistical features shape: (39, 19)
# Number of frames: 39
# Calculating spectral features...
# ZCR shape: (1, 33)
# ZCR shape: (1, 39)
# [[0.12502083 0.12502083 0.12502083 0.12502083 0.12502083]]
# Spectral centroid shape: (1, 34)
# Poly shape: (2, 39)
# Spectral bandwidth shape: (1, 34)
# Spectral flatness shape: (1, 34)
# Mel Spectrogram shape: (90, 39)
# Mel Spectrogram DB shape: (90, 39)
# Spectral rolloff shape: (1, 34)
# Subject Coren-20141121-pxp with subject index 0 is processing...
# Computing statistical features...
# MFCC shape: (90, 39)
# subject statistical features shape: (3, 19)
# Number of frames: 3
# Calculating spectral features...
# ZCR shape: (1, 3)
# ZCR shape: (1, 3)
# [[0.13270833 0.10591667]]
# Poly shape: (2, 3)
# Mel Spectrogram shape: (90, 3)
# Mel Spectrogram DB shape: (90, 3)
# spectral contrast shape: (1, 39)
# c:\Users\larry.cueva\AppData\Local\anaconda3\envs\signal-gender-predictor\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=48000 is too large for input signal of length=34816
#   warnings.warn(
# Spectral centroid shape: (1, 39)
# MFCC shape: (90, 3)
# spectral contrast shape: (1, 3)
# Spectral centroid shape: (1, 3)
# Spectral bandwidth shape: (1, 3)
# Spectral flatness shape: (1, 3)
# Spectral rolloff shape: (1, 3)
# Spectral bandwidth shape: (1, 39)
# Subject Coren-20141121-pxp with subject index 1 is processing...
# Computing statistical features...
# subject statistical features shape: (8, 19)
# Number of frames: 8
# Calculating spectral features...
# ZCR shape: (1, 7)
# ZCR shape: (1, 8)
# [[0.11435417 0.07745833 0.06872917 0.032375   0.032375  ]]
# Spectral flatness shape: (1, 39)
# Poly shape: (2, 8)
# Spectral rolloff shape: (1, 39)
# Mel Spectrogram shape: (90, 8)
# Mel Spectrogram DB shape: (90, 8)
# Subject Coren-20141121-pxp with subject index 2 is processing...
# Computing statistical features...
# MFCC shape: (90, 8)
# spectral contrast shape: (1, 8)
# subject statistical features shape: (12, 19)
# Number of frames: 12
# Calculating spectral features...
# Spectral centroid shape: (1, 8)
# ZCR shape: (1, 10)
# ZCR shape: (1, 12)
# [[0.07129167 0.058125   0.01525    0.01525    0.01525   ]]
# Poly shape: (2, 12)
# Spectral bandwidth shape: (1, 8)
# Spectral flatness shape: (1, 8)
# Spectral rolloff shape: (1, 8)
# Mel Spectrogram shape: (90, 12)
# Mel Spectrogram DB shape: (90, 12)
# Subject Coren-20141121-pxp with subject index 3 is processing...
# Computing statistical features...
# MFCC shape: (90, 12)
# subject statistical features shape: (14, 19)
# Number of frames: 14
# Calculating spectral features...
# ZCR shape: (1, 12)
# ZCR shape: (1, 14)
# [[0.05020833 0.0881875  0.08525    0.08525    0.08525   ]]
# spectral contrast shape: (1, 12)
# Spectral centroid shape: (1, 12)
# Poly shape: (2, 14)
# Spectral bandwidth shape: (1, 12)
# Spectral flatness shape: (1, 12)
# Spectral rolloff shape: (1, 12)
# Mel Spectrogram shape: (90, 14)
# Mel Spectrogram DB shape: (90, 14)
# Subject Coren-20141121-pxp with subject index 4 is processing...
# MFCC shape: (90, 14)
# Computing statistical features...
# spectral contrast shape: (1, 14)
# subject statistical features shape: (18, 19)
# Number of frames: 18
# Calculating spectral features...
# ZCR shape: (1, 16)
# ZCR shape: (1, 18)
# [[0.18654167 0.112875   0.05935417 0.05935417 0.05935417]]
# Spectral centroid shape: (1, 14)
# Poly shape: (2, 18)
# Spectral bandwidth shape: (1, 14)
# Spectral flatness shape: (1, 14)
# Spectral rolloff shape: (1, 14)
# Mel Spectrogram shape: (90, 18)
# Mel Spectrogram DB shape: (90, 18)
# Subject Coren-20141121-pxp with subject index 5 is processing...
# MFCC shape: (90, 18)
# Computing statistical features...
# spectral contrast shape: (1, 18)
# subject statistical features shape: (24, 19)
# Number of frames: 24
# Calculating spectral features...
# ZCR shape: (1, 21)
# ZCR shape: (1, 24)
# [[0.149     0.0505625 0.0505625 0.0505625 0.0505625]]
# Spectral centroid shape: (1, 18)
# Poly shape: (2, 24)
# Spectral bandwidth shape: (1, 18)
# Spectral flatness shape: (1, 18)
# Spectral rolloff shape: (1, 18)
# Mel Spectrogram shape: (90, 24)
# Mel Spectrogram DB shape: (90, 24)
# Subject Coren-20141121-pxp with subject index 6 is processing...
# MFCC shape: (90, 24)
# Computing statistical features...
# spectral contrast shape: (1, 24)
# subject statistical features shape: (26, 19)
# Number of frames: 26
# Calculating spectral features...
# ZCR shape: (1, 23)
# ZCR shape: (1, 26)
# [[0.05175    0.03889583 0.03889583 0.03889583 0.03889583]]
# Spectral centroid shape: (1, 24)
# Poly shape: (2, 26)
# Spectral bandwidth shape: (1, 24)
# Spectral flatness shape: (1, 24)
# Mel Spectrogram shape: (90, 26)
# Mel Spectrogram DB shape: (90, 26)
# Spectral rolloff shape: (1, 24)
# MFCC shape: (90, 26)
# Subject Coren-20141121-pxp with subject index 7 is processing...
# spectral contrast shape: (1, 26)
# Computing statistical features...
# subject statistical features shape: (29, 19)
# Number of frames: 29
# Calculating spectral features...
# Spectral centroid shape: (1, 26)
# ZCR shape: (1, 26)
# ZCR shape: (1, 29)
# [[0.18933333 0.1130625  0.1130625  0.1130625  0.1130625 ]]
# Poly shape: (2, 29)
# Spectral bandwidth shape: (1, 26)
# Spectral flatness shape: (1, 26)
# Mel Spectrogram shape: (90, 29)
# Mel Spectrogram DB shape: (90, 29)
# Spectral rolloff shape: (1, 26)
# Subject Coren-20141121-pxp with subject index 8 is processing...
# MFCC shape: (90, 29)
# spectral contrast shape: (1, 29)
# Computing statistical features...
# Spectral centroid shape: (1, 29)
# subject statistical features shape: (33, 19)
# Number of frames: 33
# Calculating spectral features...
# ZCR shape: (1, 30)
# ZCR shape: (1, 33)
# [[0.06541667 0.01102083 0.01102083 0.01102083 0.01102083]]
# Spectral bandwidth shape: (1, 29)
# Poly shape: (2, 33)
# Spectral flatness shape: (1, 29)
# Spectral rolloff shape: (1, 29)
# Mel Spectrogram shape: (90, 33)
# Mel Spectrogram DB shape: (90, 33)
# Subject Coren-20141121-pxp with subject index 9 is processing...
# MFCC shape: (90, 33)
# Computing statistical features...
# subject statistical features shape: (37, 19)
# Number of frames: 37
# Calculating spectral features...
# ZCR shape: (1, 33)
# ZCR shape: (1, 37)
# [[0.024625 0.024625 0.024625 0.024625 0.024625]]
# spectral contrast shape: (1, 33)
# Poly shape: (2, 37)
# Spectral centroid shape: (1, 33)
# Spectral bandwidth shape: (1, 33)
# Mel Spectrogram shape: (90, 37)
# Mel Spectrogram DB shape: (90, 37)
# Spectral flatness shape: (1, 33)
# Spectral rolloff shape: (1, 33)
# MFCC shape: (90, 37)
# spectral contrast shape: (1, 37)
# Spectral centroid shape: (1, 37)
# Spectral bandwidth shape: (1, 37)
# Spectral flatness shape: (1, 37)
# Spectral rolloff shape: (1, 37)

# %%
# # cloud
# subjects_features = transform_signals(signal_file_paths, SAVE_DIR, storage_account_name=storage_account_name, credential=credential)
