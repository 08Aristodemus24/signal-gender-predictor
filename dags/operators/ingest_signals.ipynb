# %%
import os
import io
import pyarrow as pa
import pyarrow.parquet as pq
import pyarrowfs_adlgen2 as pa_adl
import numpy as np
import librosa
import datetime as dt
import logging

from deltalake import DeltaTable, write_deltalake
from typing import Callable
from dotenv import load_dotenv
from pathlib import Path

from azure.identity import DefaultAzureCredential, ClientSecretCredential
from azure.storage.filedatalake import DataLakeServiceClient
from azure.keyvault.secrets import SecretClient
from azure.core.exceptions import ResourceNotFoundError

from concurrent.futures import ThreadPoolExecutor

# %load_ext autoreload
# %autoreload 2

# %%
def setup_logging():
    logger = logging.getLogger('signal_gender_predictor')
    logger.setLevel(logging.DEBUG) # Catch everything at the logger level

    # 2. Console/Stream Handler (for user feedback)
    console_handler = logging.StreamHandler()
    console_handler.setLevel(logging.INFO) # Only show INFO, ERROR, CRITICAL
    console_formatter = logging.Formatter('%(levelname)s: %(message)s')
    console_handler.setFormatter(console_formatter)
    logger.addHandler(console_handler)

    return logger

# %%
logger = setup_logging()

# %%
# local
DATA_DIR = "../../include/data"

# %%
# local
BRONZE_FOLDER_NAME = "bronze"
BRONZE_DATA_DIR = os.path.join("{DATA_DIR}", "{FOLDER_NAME}").replace("\\", "/")
BRONZE_DATA_DIR

# %%
# Retrieve credentials from environment variables
# this is strictly used only in development
# load env variables
env_dir = Path('../../').resolve()
load_dotenv(os.path.join(env_dir, '.env'))
# Out:
# True

# %%
storage_account_name = os.environ.get("STORAGE_ACCOUNT_NAME")
storage_account_key = os.environ.get("STORAGE_ACCOUNT_KEY")
storage_account_conn_str = os.environ.get("STORAGE_ACCOUNT_CONN_STR")

# %%
# cloud
URL = "abfss://{FOLDER_NAME}@sgppipelinesa.dfs.core.windows.net"
BRONZE_FOLDER_NAME = "sgppipelinesa-bronze"
BRONZE_DATA_DIR = os.path.join(URL.format(FOLDER_NAME=BRONZE_FOLDER_NAME)).replace("\\", "/")
BRONZE_DATA_DIR
# Out:
# 'abfss://sgppipelinesa-bronze@sgppipelinesa.dfs.core.windows.net'

# %%
# cloud
# create client with generated sas token
datalake_service_client = DataLakeServiceClient(
    account_url=f"https://{storage_account_name}.dfs.core.windows.net", 
    credential=storage_account_key
)

# %%
# retrieves file system client/container client 
# to retrieve datalake client
bronze_container_client = datalake_service_client.get_file_system_client(f"{storage_account_name}-bronze")

# https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze
bronze_container_client_url = bronze_container_client.url

# %%
# https://sgppipelinesa.blob.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav
bronze_path_to_wavs = [
    path.name 
    for path in bronze_container_client.get_paths() 
    if ".wav" in path.name or ".flac" in path.name
]
bronze_path_to_wavs
# Out:
# ['1028-20100710-hne/wav/ar-01.wav',
#  '1028-20100710-hne/wav/ar-02.wav',
#  '1028-20100710-hne/wav/ar-03.wav',
#  '1028-20100710-hne/wav/ar-04.wav',
#  '1028-20100710-hne/wav/ar-05.wav',
#  '1028-20100710-hne/wav/ar-06.wav',
#  '1028-20100710-hne/wav/ar-07.wav',
#  '1028-20100710-hne/wav/rp-29.wav',
#  '1028-20100710-hne/wav/rp-30.wav',
#  '1028-20100710-hne/wav/rp-31.wav',
#  '1337ad-20170321-ajg/wav/en-0532.wav',
#  '1337ad-20170321-ajg/wav/en-0533.wav',
core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav
subject_folders = [
    path.name 
    for path in bronze_container_client.get_paths() if not "/" in path.name
]
subject_folders
# Out:
# ['1028-20100710-hne',
#  '1337ad-20170321-ajg',
#  '1337ad-20170321-tkg',
#  '1snoke-20120412-hge',
#  '23yipikaye-20100807-ujm',
#  'Aaron-20080318-kdl',
#  'Anniepoo-20140308-bft',
#  'Anniepoo-20140308-cqj',
#  'Anniepoo-20140308-fcp',
#  'Anniepoo-20140308-hns',
#  'Anniepoo-20140308-nky',
#  'Coren-20141121-pxp']

# %%
sample_path_to_wavs = [path.name for path in bronze_container_client.get_paths(path='1028-20100710-hne/wav')]
sample_path_to_wavs
# Out:
# ['1028-20100710-hne/wav/ar-01.wav',
#  '1028-20100710-hne/wav/ar-02.wav',
#  '1028-20100710-hne/wav/ar-03.wav',
#  '1028-20100710-hne/wav/ar-04.wav',
#  '1028-20100710-hne/wav/ar-05.wav',
#  '1028-20100710-hne/wav/ar-06.wav',
#  '1028-20100710-hne/wav/ar-07.wav',
#  '1028-20100710-hne/wav/rp-29.wav',
#  '1028-20100710-hne/wav/rp-30.wav',
#  '1028-20100710-hne/wav/rp-31.wav']

# %% [markdown]
# # Once all paths from bronze are extracted get only the ones that don't already exist in the paths silver/stage-01

# %%
# # cloud
# # URL = "abfss://{FOLDER_NAME}@sgppipelinesa.dfs.core.windows.net"
# URL = "{FOLDER_NAME}"
# SILVER_FOLDER_NAME = "sgppipelinesa-silver"
# SUB_FOLDER_NAME = "stage-01"
# SILVER_DATA_DIR = os.path.join(URL, "{SUB_FOLDER_NAME}").replace("\\", "/")
# SILVER_DATA_DIR

# local
SILVER_FOLDER_NAME = "silver"
SUB_FOLDER_NAME = "stage-01"
SILVER_DATA_DIR = os.path.join("{DATA_DIR}", "{FOLDER_NAME}", "{SUB_FOLDER_NAME}").replace("\\", "/")
SILVER_DATA_DIR
# Out:
# '{DATA_DIR}/{FOLDER_NAME}/{SUB_FOLDER_NAME}'

# %%
# cloud
# retrieves file system client/container client 
# to retrieve datalake client
silver_container_client = datalake_service_client.get_file_system_client(f"{storage_account_name}-silver")

# https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-silver
silver_container_client_url = silver_container_client.url

# https://sgppipelinesa.blob.core.windows.net/sgppipelinesa-silver/1028-20100710-hne/wav/ar-01.wav
subject_folders = [
    path.name 
    for path in silver_container_client.get_paths(path="stage-01/")
]
subject_folders
# Out:
# ['stage-01/labels',
#  'stage-01/labels/_delta_log',
#  'stage-01/labels/_delta_log/00000000000000000000.json',
#  'stage-01/labels/split=test',
#  'stage-01/labels/split=test/part-00000-44a56bbf-a721-474c-91ae-af82b8e81375-c000.snappy.parquet',
#  'stage-01/labels/split=train',
#  'stage-01/labels/split=train/part-00000-4aab14f0-15c5-491c-af1c-64608d2b688a-c000.snappy.parquet',
#  'stage-01/labels/split=val',
#  'stage-01/labels/split=val/part-00000-f862abcf-8479-4454-868f-ab802ec5b6f1-c000.snappy.parquet']

# %%
# # local
# signal_file_paths = [
#     str(signal_file_path).replace("\\", "/") for signal_file_path in Path(
#         SILVER_DATA_DIR.format(
#             DATA_DIR=DATA_DIR,
#             FOLDER_NAME=SILVER_FOLDER_NAME,
#             SUB_FOLDER_NAME=SUB_FOLDER_NAME
#         )
#     ).rglob('*')  
#     if signal_file_path.is_file() and "labels" not in str(signal_file_path)
# ]
# signal_file_paths

# cloud
signal_file_paths = [
    path.name
    for path in silver_container_client.get_paths(path="stage-01/")
    if ".parquet" in path.name and "labels" not in path.name
    # not path.is_directory #and "labels" not in path.name
]
signal_file_paths
# Out:
# ['stage-01/1snoke-20120412-hge/a0405.parquet',
#  'stage-01/1snoke-20120412-hge/a0406.parquet',
#  'stage-01/1snoke-20120412-hge/a0407.parquet',
#  'stage-01/1snoke-20120412-hge/a0408.parquet',
#  'stage-01/1snoke-20120412-hge/a0409.parquet',
#  'stage-01/1snoke-20120412-hge/a0410.parquet',
#  'stage-01/1snoke-20120412-hge/a0411.parquet',
#  'stage-01/1snoke-20120412-hge/a0412.parquet',
#  'stage-01/1snoke-20120412-hge/a0413.parquet',
#  'stage-01/1snoke-20120412-hge/a0414.parquet']

# %%
def filter_path_to_wavs(bronze_path_to_wavs, silver_stage_01_path_to_signals):
    """
    we compare this:
    
    ['1337ad-20170321-tkg/wav/en-0729.wav',
    '1337ad-20170321-tkg/wav/en-0730.wav',
    ...
    'Coren-20141121-pxp/wav/b0472.wav',
    'Coren-20141121-pxp/wav/b0473.wav',
    'Coren-20141121-pxp/wav/b0474.wav',
    'Coren-20141121-pxp/wav/b0475.wav',
    'Coren-20141121-pxp/wav/b0476.wav']
    
    to this:
    
    [ '../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0730.parquet',
    ...
    '../../include/data/silver/stage-01/Coren-20141121-pxp/b0472.parquet',
    '../../include/data/silver/stage-01/Coren-20141121-pxp/b0473.parquet',
    '../../include/data/silver/stage-01/Coren-20141121-pxp/b0474.parquet',
    '../../include/data/silver/stage-01/Coren-20141121-pxp/b0475.parquet',
    '../../include/data/silver/stage-01/Coren-20141121-pxp/b0476.parquet']
    
    or 
    
    ['stage-01/1snoke-20120412-hge/a0405.parquet',
    'stage-01/1snoke-20120412-hge/a0406.parquet',
    'stage-01/1snoke-20120412-hge/a0407.parquet',
    'stage-01/1snoke-20120412-hge/a0408.parquet',
    'stage-01/1snoke-20120412-hge/a0409.parquet',
    'stage-01/1snoke-20120412-hge/a0410.parquet',
    'stage-01/1snoke-20120412-hge/a0411.parquet',
    'stage-01/1snoke-20120412-hge/a0412.parquet',
    'stage-01/1snoke-20120412-hge/a0413.parquet',
    'stage-01/1snoke-20120412-hge/a0414.parquet']
    
    but we need to normalize both lists to be just the subject folder and its 
    corresponding wav file name without the extension, and conversely subject
    folder in silver/stage-01/ and its corresponding parquet file name 
    without the extension. E.g. 1337ad-20170321-tkg/wav/en-0729.wav becomes
    1337ad-20170321-tkg/en-0729 and 
    ../../include/data/silver/stage-01/1337ad-20170321-tkg/en-0730.parquet 
    becomes 1337ad-20170321-tkg/en-0730
    """
    
    normalized_bronze_path_to_wavs_map = dict(zip(
        bronze_path_to_wavs,
        [
            os.path.join(
                # '1snoke-20120412-hge/wav/a0414.wav' is for instance
                # built into '1snoke-20120412-hge/a0414'
                path.split("/")[-3],
                path.split("/")[-1].replace(".wav", "").replace(".flac", "")    
            ).replace("\\", "/")
            for path in bronze_path_to_wavs
        ],
    ))

    normalized_silver_stage_01_path_to_signals = [
        # 'stage-01/1snoke-20120412-hge/a0414.parquet' for instance
        # is built into '1snoke-20120412-hge/a0414'
        os.path.join(
            path.split("/")[-2],
            path.split("/")[-1].replace(".parquet", "")
        ).replace("\\", "/")
        for path in silver_stage_01_path_to_signals
    ]

    return [
        key for key, normalized_path_to_wav in normalized_bronze_path_to_wavs_map.items()
        if normalized_path_to_wav not in normalized_silver_stage_01_path_to_signals
    ]

# %%
# # append test .wav path to see if it gets filtered out 
# # since it won't have a corresponding parquet file in 
# # silver/stage-01
# path_to_wavs.append("test_subject/wav/test.wav")
# path_to_wavs.pop()

# %%
path_to_wavs_filt = filter_path_to_wavs(bronze_path_to_wavs, signal_file_paths)
path_to_wavs_filt
# Out:
# ['1028-20100710-hne/wav/ar-01.wav',
#  '1028-20100710-hne/wav/ar-02.wav',
#  '1028-20100710-hne/wav/ar-03.wav',
#  '1028-20100710-hne/wav/ar-04.wav',
#  '1028-20100710-hne/wav/ar-05.wav',
#  '1028-20100710-hne/wav/ar-06.wav',
#  '1028-20100710-hne/wav/ar-07.wav',
#  '1028-20100710-hne/wav/rp-29.wav',
#  '1028-20100710-hne/wav/rp-30.wav',
#  '1028-20100710-hne/wav/rp-31.wav',
#  '1337ad-20170321-ajg/wav/en-0532.wav',
#  '1337ad-20170321-ajg/wav/en-0533.wav',
#  '1337ad-20170321-ajg/wav/en-0534.wav',
#  '1337ad-20170321-ajg/wav/en-0535.wav',
#  '1337ad-20170321-ajg/wav/en-0536.wav',
#  '1337ad-20170321-ajg/wav/en-0537.wav',
#  '1337ad-20170321-ajg/wav/en-0538.wav',
#  '1337ad-20170321-ajg/wav/en-0539.wav',
#  '1337ad-20170321-ajg/wav/en-0540.wav',
#  '1337ad-20170321-ajg/wav/en-0541.wav',
#  '1337ad-20170321-tkg/wav/en-0726.wav',
#  '1337ad-20170321-tkg/wav/en-0727.wav',
#  '1337ad-20170321-tkg/wav/en-0728.wav',
#  '1337ad-20170321-tkg/wav/en-0729.wav',
#  '1337ad-20170321-tkg/wav/en-0730.wav',
#  '1337ad-20170321-tkg/wav/en-0731.wav',
#  '1337ad-20170321-tkg/wav/en-0732.wav',
#  '1337ad-20170321-tkg/wav/en-0733.wav',
#  '1337ad-20170321-tkg/wav/en-0734.wav',
#  '1337ad-20170321-tkg/wav/en-0735.wav',
#  '23yipikaye-20100807-ujm/wav/b0312.wav',
#  '23yipikaye-20100807-ujm/wav/b0313.wav',
#  '23yipikaye-20100807-ujm/wav/b0314.wav',
#  '23yipikaye-20100807-ujm/wav/b0315.wav',
#  '23yipikaye-20100807-ujm/wav/b0316.wav',
#  '23yipikaye-20100807-ujm/wav/b0317.wav',
#  '23yipikaye-20100807-ujm/wav/b0318.wav',
#  '23yipikaye-20100807-ujm/wav/b0319.wav',
#  '23yipikaye-20100807-ujm/wav/b0320.wav',
#  '23yipikaye-20100807-ujm/wav/b0321.wav',
#  'Aaron-20080318-kdl/wav/b0019.wav',
#  'Aaron-20080318-kdl/wav/b0020.wav',
#  'Aaron-20080318-kdl/wav/b0021.wav',
#  'Aaron-20080318-kdl/wav/b0022.wav',
#  'Aaron-20080318-kdl/wav/b0023.wav',
#  'Aaron-20080318-kdl/wav/b0024.wav',
#  'Aaron-20080318-kdl/wav/b0025.wav',
#  'Coren-20141121-pxp/wav/b0470.wav',
#  'Coren-20141121-pxp/wav/b0471.wav',
#  'Coren-20141121-pxp/wav/b0472.wav',
#  'Coren-20141121-pxp/wav/b0473.wav',
#  'Coren-20141121-pxp/wav/b0474.wav',
#  'Coren-20141121-pxp/wav/b0475.wav',
#  'Coren-20141121-pxp/wav/b0476.wav']

# %%
def ingest_signals(path_to_wavs: list[str], DATA_DIR: str=None, credential=None):
    """
    ingests signals from .wav files, trims the audio signal to 
    remove silence, and writes the trimmed signal as a parquet 
    file in azure data lake or locally depending on where 
    this function is being run.

    Args:
        path_to_wavs (list[str]): _description_
        DATA_DIR (str, optional): _description_. Defaults to None.
    """
    def helper(path_to_wav):
        
        # # local
        # # # lists out the files containing the .wav files in
        # # # a subjects folder. Note also that using double backslash
        # # # is not accepted by azure and will raise `path does not exist
        # # # or `files can not exist on the root account level` that's
        # # # why we replace it always with forward slashes
        # # wavs_dir = os.path.join(DATA_DIR, "bronze", subject_folder, "wav").replace("\\", "/")
        # # path_to_wavs = os.listdir(wavs_dir)

        # wavs_dir = os.path.join(subject_folder, "wav").replace("\\", "/")
        # path_to_wavs = [
        #     path.name 
        #     for path in bronze_container_client.get_paths(path=wavs_dir)
        # ]
        try:
            # get meta data and replace file extension to be 
            # .parquet for later writing as parquet file
            subject_folder = path_to_wav.split("/")[-3]
            new_wav_file_name = path_to_wav.split("/")[-1].replace(".wav", "").replace(".flac", "")
            print(new_wav_file_name)
            
            # create storage for list of signals to all be 
            # concatenated later
            signal_list = []
            
            # create storage list for the ordinal positioning
            # of signals to all be concatenated later
            file_row_num_list = []
            file_name_list = []
            loaded_at_list = []
            
            # cloud
            wav_file_client = bronze_container_client.get_file_client(path_to_wav)

            # Download the file content
            download_result = wav_file_client.download_file()
            downloaded_bytes = download_result.readall()
            audio_buff = io.BytesIO(downloaded_bytes)

            # # local
            # audio_buff = os.path.join(wavs_dir, wav)

            # let librosa read the audio buffer containing t+he content
            # of the binary audio file
            y, sr = librosa.load(audio_buff, sr=16000)

            # audio recordings can have different length
            print(f"shape of audio signals {y.shape}")
            print(f"sampling rate of audio signals after interpolation: {sr}")

            # top_db is set to 20 representing any signal belows
            # 20 decibels will be considered silence
            y_trimmed, _ = librosa.effects.trim(y, top_db=20)
            
            # get how many elements/signals there are in the trimmed
            # version
            # >>> y_trimmed, _ = librosa.effects.trim(np.array([[1, 2, 3, 4, 0, 0, 0]]), top_db=20)
            # >>> y_trimmed.shape
            # (1, 7)
            # ordinal positioning will be 0, 1, 2, 3, 4, 5, 6, 7
            ordinal_positioning = np.arange(y_trimmed.shape[0])
            # print(ordinal_positioning)

            # append y to ys 
            signal_list.append(y_trimmed)
            file_row_num_list.append(ordinal_positioning)
            file_name_list.append(np.array(
                [os.path.join(bronze_container_client.url, path_to_wav).replace("\\", "/")] * y_trimmed.shape[0],
            ))
            loaded_at_list.append(np.array(
                [dt.datetime.now()] * y_trimmed.shape[0], 
                dtype='datetime64[us]'
            ))

            # concatenate all audio signals into one final signal as 
            # this is all anyway recorded in the voice of the same gender
            signals = np.concatenate(signal_list, axis=0)
            file_row_num = np.concatenate(file_row_num_list, axis=0)
            file_name = np.concatenate(file_name_list, axis=0)
            loaded_at = np.concatenate(loaded_at_list, axis=0)

            # create pyarrow table so we can write this table as
            # parquet file format later
            table = pa.table({
                "signals": pa.array(signals), 
                "subject_id": pa.array([subject_folder] * signals.shape[0], type=pa.string()),
                "file_row_number": pa.array(file_row_num),
                "file_name": pa.array(file_name), 
                "loaded_at": pa.array(loaded_at)
            })

            print(subject_folder, file_name)
            # cloud
            # write the pyarrow table to azure data lake using
            # pyarrow azure file system using the credential we
            # retrieved which uses the function apps system assigned 
            # managed identity
            SILVER_FOLDER_NAME = f"{storage_account_name}-silver"
            SUB_FOLDER_NAME = f"stage-01/{subject_folder}"
            FILE_NAME = f"{new_wav_file_name}.parquet"

            SILVER_DATA_PATH = os.path.join(SILVER_FOLDER_NAME, SUB_FOLDER_NAME, FILE_NAME).replace("\\", "/")
            handler = pa_adl.AccountHandler.from_account_name(storage_account_name, credential=credential)
            fs = pa.fs.PyFileSystem(handler)
            pq.write_table(table, SILVER_DATA_PATH, filesystem=fs)

            # # local
            # SILVER_FOLDER_NAME = f"silver"
            # SUB_FOLDER_NAME = f"stage-01"
            # FILE_NAME = f"{new_wav_file_name}.parquet"
            
            # # make directory where the numpyfied signals
            # # will live
            # SILVER_DATA_DIR = os.path.join(DATA_DIR, SILVER_FOLDER_NAME, SUB_FOLDER_NAME, subject_folder)
            # os.makedirs(SILVER_DATA_DIR, exist_ok=True)
            
            # # 
            # SILVER_DATA_PATH = os.path.join(DATA_DIR, SILVER_FOLDER_NAME, SUB_FOLDER_NAME, subject_folder, FILE_NAME).replace("\\", "/")
            # pq.write_table(table, SILVER_DATA_PATH)
        
        except (ResourceNotFoundError, FileNotFoundError):
            print(f"file not found for subject {path_to_wav}, skipping...")
            
                
        return
            
    # concurrently load .wav files and trim  each .wav files
    # audio signal and combine into one signal for each subject 
    with ThreadPoolExecutor(max_workers=2) as exe:
        print("running")
        exe.map(helper, path_to_wavs)

# %%
DATA_DIR
# Out:
# '../../include/data'

# %%
azure_creds = {
    'azure_storage_account_name': storage_account_name,
    'azure_storage_account_key': storage_account_key
}

# %%
subject_folders[:1]
# Out:
# ['stage-01/labels']

# %%
# # local
# ingest_signals(
#     path_to_wavs_filt,  
#     DATA_DIR=DATA_DIR,
# )

# %%
# cloud
ingest_signals(path_to_wavs_filt, DATA_DIR=None, credential=azure_creds["azure_storage_account_key"])
# Out:
# running
# ar-01
# ar-02
# shape of audio signals (86000,)
# sampling rate of audio signals after interpolation: 16000
# 1028-20100710-hne ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-02.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-02.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-02.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-02.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-02.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-02.wav']
# shape of audio signals (100000,)
# sampling rate of audio signals after interpolation: 16000
# 1028-20100710-hne ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-01.wav']
# ar-03
# ar-04
# shape of audio signals (94000,)
# sampling rate of audio signals after interpolation: 16000
# 1028-20100710-hne ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-04.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-04.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-04.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-04.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-04.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-04.wav']
# shape of audio signals (104000,)
# sampling rate of audio signals after interpolation: 16000
# ar-05
# 1028-20100710-hne ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-03.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-03.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-03.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-03.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-03.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-03.wav']
# ar-06
# shape of audio signals (72000,)
# sampling rate of audio signals after interpolation: 16000
# 1028-20100710-hne ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-06.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-06.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-06.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-06.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-06.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-06.wav']
# shape of audio signals (106000,)
# sampling rate of audio signals after interpolation: 16000
# 1028-20100710-hne ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-05.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-05.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-05.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-05.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-05.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-05.wav']
# ar-07
# rp-29
# shape of audio signals (82000,)
# sampling rate of audio signals after interpolation: 16000
# 1028-20100710-hne ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/rp-29.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/rp-29.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/rp-29.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/rp-29.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/rp-29.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/rp-29.wav']
# shape of audio signals (86000,)
# sampling rate of audio signals after interpolation: 16000
# 1028-20100710-hne ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-07.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-07.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-07.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-07.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-07.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/ar-07.wav']
# rp-30
# rp-31
# shape of audio signals (66000,)
# sampling rate of audio signals after interpolation: 16000
# 1028-20100710-hne ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/rp-31.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/rp-31.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/rp-31.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/rp-31.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/rp-31.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/rp-31.wav']
# en-0532
# shape of audio signals (74000,)
# sampling rate of audio signals after interpolation: 16000
# 1337ad-20170321-ajg ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0532.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0532.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0532.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0532.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0532.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0532.wav']
# shape of audio signals (102000,)
# sampling rate of audio signals after interpolation: 16000
# 1028-20100710-hne ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/rp-30.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/rp-30.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/rp-30.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/rp-30.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/rp-30.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1028-20100710-hne/wav/rp-30.wav']
# en-0533
# en-0534
# shape of audio signals (68000,)
# sampling rate of audio signals after interpolation: 16000
# 1337ad-20170321-ajg ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0534.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0534.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0534.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0534.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0534.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0534.wav']
# en-0535
# shape of audio signals (96000,)
# sampling rate of audio signals after interpolation: 16000
# 1337ad-20170321-ajg ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0535.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0535.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0535.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0535.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0535.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0535.wav']
# shape of audio signals (110000,)
# sampling rate of audio signals after interpolation: 16000
# 1337ad-20170321-ajg ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0533.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0533.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0533.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0533.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0533.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0533.wav']
# en-0536
# en-0537
# shape of audio signals (74000,)
# sampling rate of audio signals after interpolation: 16000
# shape of audio signals (64000,)
# sampling rate of audio signals after interpolation: 16000
# 1337ad-20170321-ajg ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0537.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0537.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0537.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0537.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0537.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0537.wav']
# 1337ad-20170321-ajg ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0536.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0536.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0536.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0536.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0536.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0536.wav']
# en-0538en-0539
#
# shape of audio signals (88000,)
# sampling rate of audio signals after interpolation: 16000
# 1337ad-20170321-ajg ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0539.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0539.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0539.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0539.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0539.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0539.wav']
# shape of audio signals (56000,)
# sampling rate of audio signals after interpolation: 16000
# 1337ad-20170321-ajg ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0538.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0538.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0538.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0538.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0538.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0538.wav']
# en-0540
# en-0541
# shape of audio signals (94000,)
# sampling rate of audio signals after interpolation: 16000
# 1337ad-20170321-ajg ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0541.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0541.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0541.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0541.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0541.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0541.wav']
# shape of audio signals (88000,)
# sampling rate of audio signals after interpolation: 16000
# 1337ad-20170321-ajg ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0540.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0540.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0540.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0540.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0540.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-ajg/wav/en-0540.wav']
# en-0726
# en-0727
# shape of audio signals (90000,)
# sampling rate of audio signals after interpolation: 16000
# 1337ad-20170321-tkg ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0727.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0727.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0727.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0727.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0727.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0727.wav']
# shape of audio signals (76000,)
# sampling rate of audio signals after interpolation: 16000
# 1337ad-20170321-tkg ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0726.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0726.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0726.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0726.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0726.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0726.wav']
# en-0728
# en-0729
# shape of audio signals (82000,)
# sampling rate of audio signals after interpolation: 16000
# 1337ad-20170321-tkg ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0729.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0729.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0729.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0729.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0729.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0729.wav']
# shape of audio signals (102000,)
# sampling rate of audio signals after interpolation: 16000
# 1337ad-20170321-tkg ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0728.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0728.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0728.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0728.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0728.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0728.wav']
# en-0730
# en-0731
# shape of audio signals (62000,)
# sampling rate of audio signals after interpolation: 16000
# 1337ad-20170321-tkg ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0731.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0731.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0731.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0731.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0731.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0731.wav']
# shape of audio signals (60000,)
# sampling rate of audio signals after interpolation: 16000
# 1337ad-20170321-tkg ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0730.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0730.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0730.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0730.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0730.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0730.wav']
# en-0732
# en-0733
# shape of audio signals (96000,)
# sampling rate of audio signals after interpolation: 16000
# 1337ad-20170321-tkg ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0733.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0733.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0733.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0733.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0733.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0733.wav']
# shape of audio signals (82000,)
# sampling rate of audio signals after interpolation: 16000
# 1337ad-20170321-tkg ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0732.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0732.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0732.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0732.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0732.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0732.wav']
# en-0734
# en-0735
# shape of audio signals (86000,)
# sampling rate of audio signals after interpolation: 16000
# 1337ad-20170321-tkg ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0735.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0735.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0735.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0735.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0735.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0735.wav']
# b0312
# shape of audio signals (104000,)
# sampling rate of audio signals after interpolation: 16000
# 1337ad-20170321-tkg ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0734.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0734.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0734.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0734.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0734.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/1337ad-20170321-tkg/wav/en-0734.wav']
# shape of audio signals (122000,)
# sampling rate of audio signals after interpolation: 16000
# 23yipikaye-20100807-ujm ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0312.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0312.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0312.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0312.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0312.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0312.wav']
# b0313
# b0314
# shape of audio signals (136000,)
# sampling rate of audio signals after interpolation: 16000
# 23yipikaye-20100807-ujm ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0313.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0313.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0313.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0313.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0313.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0313.wav']
# b0315
# shape of audio signals (94000,)
# sampling rate of audio signals after interpolation: 16000
# 23yipikaye-20100807-ujm ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0315.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0315.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0315.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0315.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0315.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0315.wav']
# shape of audio signals (80000,)
# sampling rate of audio signals after interpolation: 16000
# 23yipikaye-20100807-ujm ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0314.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0314.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0314.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0314.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0314.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0314.wav']
# b0316
# b0317
# shape of audio signals (114000,)
# sampling rate of audio signals after interpolation: 16000
# 23yipikaye-20100807-ujm ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0317.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0317.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0317.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0317.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0317.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0317.wav']
# b0318
# shape of audio signals (76000,)
# sampling rate of audio signals after interpolation: 16000
# 23yipikaye-20100807-ujm ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0318.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0318.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0318.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0318.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0318.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0318.wav']
# shape of audio signals (108000,)
# sampling rate of audio signals after interpolation: 16000
# 23yipikaye-20100807-ujm ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0316.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0316.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0316.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0316.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0316.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0316.wav']
# b0319
# b0320
# shape of audio signals (112000,)
# sampling rate of audio signals after interpolation: 16000
# 23yipikaye-20100807-ujm ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0320.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0320.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0320.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0320.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0320.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0320.wav']
# shape of audio signals (100000,)
# sampling rate of audio signals after interpolation: 16000
# 23yipikaye-20100807-ujm ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0319.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0319.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0319.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0319.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0319.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0319.wav']
# b0321
# b0019
# shape of audio signals (55979,)
# sampling rate of audio signals after interpolation: 16000
# Aaron-20080318-kdl ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0019.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0019.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0019.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0019.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0019.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0019.wav']
# shape of audio signals (84000,)
# sampling rate of audio signals after interpolation: 16000
# 23yipikaye-20100807-ujm ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0321.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0321.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0321.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0321.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0321.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/23yipikaye-20100807-ujm/wav/b0321.wav']
# b0020
# b0021
# shape of audio signals (42326,)
# sampling rate of audio signals after interpolation: 16000
# Aaron-20080318-kdl ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0021.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0021.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0021.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0021.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0021.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0021.wav']
# b0022
# shape of audio signals (64171,)
# sampling rate of audio signals after interpolation: 16000
# Aaron-20080318-kdl ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0022.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0022.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0022.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0022.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0022.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0022.wav']
# shape of audio signals (80555,)
# sampling rate of audio signals after interpolation: 16000
# Aaron-20080318-kdl ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0020.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0020.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0020.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0020.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0020.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0020.wav']
# b0023
# b0024
# shape of audio signals (61440,)
# sampling rate of audio signals after interpolation: 16000
# Aaron-20080318-kdl ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0024.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0024.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0024.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0024.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0024.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0024.wav']
# shape of audio signals (57344,)
# sampling rate of audio signals after interpolation: 16000
# Aaron-20080318-kdl ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0023.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0023.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0023.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0023.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0023.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0023.wav']
# b0025
# b0026
# shape of audio signals (54614,)
# sampling rate of audio signals after interpolation: 16000
# Aaron-20080318-kdl ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0026.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0026.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0026.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0026.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0026.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0026.wav']
# shape of audio signals (55979,)
# sampling rate of audio signals after interpolation: 16000
# Aaron-20080318-kdl ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0025.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0025.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0025.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0025.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0025.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0025.wav']
# b0027
# b0028
# shape of audio signals (70998,)
# sampling rate of audio signals after interpolation: 16000
# Aaron-20080318-kdl ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0028.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0028.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0028.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0028.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0028.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0028.wav']
# rb-04
# shape of audio signals (75094,)
# sampling rate of audio signals after interpolation: 16000
# shape of audio signals (92000,)Aaron-20080318-kdl ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0027.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0027.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0027.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0027.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0027.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Aaron-20080318-kdl/wav/b0027.wav']
#
# sampling rate of audio signals after interpolation: 16000
# Anniepoo-20140308-bft ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-04.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-04.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-04.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-04.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-04.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-04.wav']
# rb-05
# rb-06
# shape of audio signals (140000,)
# sampling rate of audio signals after interpolation: 16000
# shape of audio signals (122000,)
# sampling rate of audio signals after interpolation: 16000
# Anniepoo-20140308-bft ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-05.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-05.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-05.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-05.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-05.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-05.wav']
# Anniepoo-20140308-bft ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-06.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-06.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-06.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-06.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-06.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-06.wav']
# rb-07rb-08
#
# shape of audio signals (84000,)
# sampling rate of audio signals after interpolation: 16000
# Anniepoo-20140308-bft ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-08.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-08.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-08.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-08.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-08.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-08.wav']
# rb-09
# shape of audio signals (126000,)
# sampling rate of audio signals after interpolation: 16000
# Anniepoo-20140308-bft ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-09.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-09.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-09.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-09.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-09.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-09.wav']
# shape of audio signals (124000,)
# sampling rate of audio signals after interpolation: 16000
# Anniepoo-20140308-bft ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-07.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-07.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-07.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-07.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-07.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-07.wav']
# rb-10
# rb-11
# shape of audio signals (92000,)
# sampling rate of audio signals after interpolation: 16000
# Anniepoo-20140308-bft ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-11.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-11.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-11.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-11.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-11.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-11.wav']
# shape of audio signals (74000,)
# sampling rate of audio signals after interpolation: 16000
# Anniepoo-20140308-bft ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-10.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-10.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-10.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-10.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-10.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-10.wav']
# rb-12
# rb-13
# shape of audio signals (124000,)
# sampling rate of audio signals after interpolation: 16000
# Anniepoo-20140308-bft ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-13.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-13.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-13.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-13.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-13.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-13.wav']
# a0116
# shape of audio signals (110000,)
# sampling rate of audio signals after interpolation: 16000
# Anniepoo-20140308-bft ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-12.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-12.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-12.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-12.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-12.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-bft/wav/rb-12.wav']
# a0117
# shape of audio signals (114000,)
# sampling rate of audio signals after interpolation: 16000
# Anniepoo-20140308-cqj ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0117.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0117.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0117.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0117.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0117.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0117.wav']
# shape of audio signals (96000,)
# sampling rate of audio signals after interpolation: 16000
# Anniepoo-20140308-cqj ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0116.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0116.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0116.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0116.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0116.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0116.wav']
# a0118
# a0119
# shape of audio signals (84000,)
# sampling rate of audio signals after interpolation: 16000
# Anniepoo-20140308-cqj ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0119.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0119.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0119.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0119.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0119.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0119.wav']
# shape of audio signals (88000,)
# sampling rate of audio signals after interpolation: 16000
# Anniepoo-20140308-cqj ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0118.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0118.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0118.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0118.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0118.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0118.wav']
# a0120
# a0121
# shape of audio signals (100000,)
# sampling rate of audio signals after interpolation: 16000
# Anniepoo-20140308-cqj ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0121.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0121.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0121.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0121.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0121.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-cqj/wav/a0121.wav']
# a0122
# shape of audio signals (80000,)
# ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-hns/wav/a0290.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-hns/wav/a0290.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-hns/wav/a0290.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-hns/wav/a0290.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-hns/wav/a0290.wav']
# a0291
# shape of audio signals (104000,)
# sampling rate of audio signals after interpolation: 16000
# Anniepoo-20140308-hns ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-hns/wav/a0291.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-hns/wav/a0291.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-hns/wav/a0291.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-hns/wav/a0291.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-hns/wav/a0291.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-hns/wav/a0291.wav']
# b0069
# shape of audio signals (110000,)
# sampling rate of audio signals after interpolation: 16000
# Anniepoo-20140308-nky ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0069.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0069.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0069.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0069.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0069.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0069.wav']
# b0070
# shape of audio signals (86000,)
# sampling rate of audio signals after interpolation: 16000
# Anniepoo-20140308-nky ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0070.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0070.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0070.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0070.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0070.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0070.wav']
# b0071
# shape of audio signals (74000,)
# sampling rate of audio signals after interpolation: 16000
# Anniepoo-20140308-nky ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0071.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0071.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0071.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0071.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0071.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0071.wav']
# b0072
# shape of audio signals (84000,)
# sampling rate of audio signals after interpolation: 16000
# Anniepoo-20140308-nky ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0072.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0072.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0072.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0072.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0072.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0072.wav']
# b0073
# shape of audio signals (104000,)
# sampling rate of audio signals after interpolation: 16000
# Anniepoo-20140308-nky ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0073.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0073.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0073.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0073.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0073.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0073.wav']
# b0074
# shape of audio signals (110000,)
# sampling rate of audio signals after interpolation: 16000
# Anniepoo-20140308-nky ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0074.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0074.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0074.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0074.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0074.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0074.wav']
# b0075
# shape of audio signals (92000,)
# sampling rate of audio signals after interpolation: 16000
# Anniepoo-20140308-nky ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0075.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0075.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0075.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0075.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0075.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0075.wav']
# b0076
# shape of audio signals (116000,)
# sampling rate of audio signals after interpolation: 16000
# Anniepoo-20140308-nky ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0076.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0076.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0076.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0076.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0076.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0076.wav']
# b0077
# shape of audio signals (66000,)
# sampling rate of audio signals after interpolation: 16000
# Anniepoo-20140308-nky ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0077.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0077.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0077.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0077.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0077.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0077.wav']
# b0078
# shape of audio signals (102000,)
# sampling rate of audio signals after interpolation: 16000
# Anniepoo-20140308-nky ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0078.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0078.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0078.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0078.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0078.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Anniepoo-20140308-nky/wav/b0078.wav']
# b0467
# shape of audio signals (60000,)
# sampling rate of audio signals after interpolation: 16000
# Coren-20141121-pxp ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0467.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0467.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0467.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0467.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0467.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0467.wav']
# b0468
# shape of audio signals (74000,)
# sampling rate of audio signals after interpolation: 16000
# b0469
# Coren-20141121-pxp ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0468.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0468.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0468.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0468.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0468.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0468.wav']
# shape of audio signals (66000,)
# sampling rate of audio signals after interpolation: 16000
# Coren-20141121-pxp ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0469.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0469.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0469.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0469.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0469.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0469.wav']
# b0470
# b0471
# shape of audio signals (58000,)
# sampling rate of audio signals after interpolation: 16000
# Coren-20141121-pxp ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0470.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0470.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0470.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0470.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0470.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0470.wav']
# shape of audio signals (70000,)
# sampling rate of audio signals after interpolation: 16000
# Coren-20141121-pxp ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0471.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0471.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0471.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0471.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0471.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0471.wav']
# b0472
# b0473
# shape of audio signals (46000,)
# sampling rate of audio signals after interpolation: 16000
# shape of audio signals (96000,)
# sampling rate of audio signals after interpolation: 16000
# Coren-20141121-pxp ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0473.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0473.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0473.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0473.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0473.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0473.wav']
# Coren-20141121-pxp ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0472.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0472.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0472.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0472.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0472.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0472.wav']
# b0474
# shape of audio signals (72000,)
# sampling rate of audio signals after interpolation: 16000
# Coren-20141121-pxp ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0474.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0474.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0474.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0474.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0474.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0474.wav']
# b0475
# shape of audio signals (66000,)
# sampling rate of audio signals after interpolation: 16000
# Coren-20141121-pxp ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0475.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0475.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0475.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0475.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0475.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0475.wav']
# b0476
# shape of audio signals (90000,)
# sampling rate of audio signals after interpolation: 16000
# Coren-20141121-pxp ['https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0476.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0476.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0476.wav'
#  ...
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0476.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0476.wav'
#  'https://sgppipelinesa.dfs.core.windows.net/sgppipelinesa-bronze/Coren-20141121-pxp/wav/b0476.wav']
